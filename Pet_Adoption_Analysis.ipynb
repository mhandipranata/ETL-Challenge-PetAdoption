# %%
# Dependencies
import json
import requests
import pandas as pd
from config import petfinder_api_key, petfinder_secret_key

# %%
# Request token for the Petfinder API
data = {
  'grant_type': 'client_credentials',
  'client_id': petfinder_api_key,
  'client_secret': petfinder_secret_key
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=data)
token_response_json = token_response.json()

print(json.dumps(token_response_json, indent = 4))
# Out:
# {
#     "token_type": "Bearer",
#     "expires_in": 3600,
#     "access_token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjZmNGFiNThjNjM2MDQ5NDY2MmQyNWI1NzY3YjU4MzBjZTRiNzY3YTJlOWExZTVjNDg0NzY3ZTZhMGI2M2VlMmRmNjE5YjJmMTYwNzI2ZTg4In0..a7OcEtaYCoIWb6Oh5e6t3GI2_x3cjrnQ2uj2HUCl2q6vJNTN36nNsuDtwRXF21xzhM5D1wMnlU33vhecsAm86hv5o5Z8uaVIOcSHxoR2_uRv8k6-1B__l5mvbdBhB9ekuAdybxNNmFPVxuwzk4b9TknMIhrmeGbwnUHMKKw4N4gmKMB-JTivcPsO03IOiW73WFW3VaTEOaN1rno72Kl6SWMD261PXArUW45BKulTxqIWb-KcrB2RGwJ9iSJRglTZ1DUhLQkuwOtWq5IrFW5pQbrpi-OLVGWbRtMdxQZDprb2QVBFkhHMjDPaTOhMaiqKevQ26ZDavBjAK411KoEvxA"
# }

# %%
# Pull data from petfinder.com API 
headers = {'Authorization': f"Bearer {token_response_json['access_token']}"}
url = "https://api.petfinder.com/v2/animals?"
response = requests.get(url, headers=headers)
response_json = response.json()

print(json.dumps(response_json, indent = 4))
# Out:
# {
#     "animals": [
#         {
#             "id": 47414548,
#             "organization_id": "CA2420",
#             "url": "https://www.petfinder.com/dog/grizz-47414548/ca/novato/bay-area-german-shepherd-rescue-ca2420/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "German Shepherd Dog",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Yellow / Tan / Blond / Fawn",
#                 "secondary": "Black",
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Large",
#             "coat": "Medium",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": true,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Grizz",
#             "description": "Hi! I\u2019m Grizz! I\u2019m a 7 year old black and tan GSD. My new friends got me out of the...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/1/?bust=1582081816&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/1/?bust=1582081816&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/1/?bust=1582081816&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/1/?bust=1582081816"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/2/?bust=1582081823&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/2/?bust=1582081823&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/2/?bust=1582081823&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/2/?bust=1582081823"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/3/?bust=1582081825&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/3/?bust=1582081825&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/3/?bust=1582081825&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/3/?bust=1582081825"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/4/?bust=1582081827&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/4/?bust=1582081827&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/4/?bust=1582081827&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/4/?bust=1582081827"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/5/?bust=1582081831&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/5/?bust=1582081831&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/5/?bust=1582081831&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414548/5/?bust=1582081831"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:13:50+0000",
#             "published_at": "2020-02-19T03:13:50+0000",
#             "distance": null,
#             "contact": {
#                 "email": "info@bayareagsr.org",
#                 "phone": "(855) 473-5683",
#                 "address": {
#                     "address1": "PO Box 2846",
#                     "address2": null,
#                     "city": "Novato",
#                     "state": "CA",
#                     "postcode": "94948",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414548"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca2420"
#                 }
#             }
#         },
#         {
#             "id": 47414525,
#             "organization_id": "CA2684",
#             "url": "https://www.petfinder.com/dog/fredo-47414525/ca/moorpark/smiley-tails-rescue-ca2684/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "German Shepherd Dog",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black",
#                 "secondary": "Yellow / Tan / Blond / Fawn",
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": null
#             },
#             "tags": [
#                 "Puppy",
#                 "loving",
#                 "sweet",
#                 "playful",
#                 "german shepherd"
#             ],
#             "name": "Fredo",
#             "description": "Although I may be the smallest in my litter, I am the mightiest!  I&#039;m so loving, too! \nDo you have...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/1/?bust=1582081699&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/1/?bust=1582081699&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/1/?bust=1582081699&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/1/?bust=1582081699"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/2/?bust=1582081708&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/2/?bust=1582081708&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/2/?bust=1582081708&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/2/?bust=1582081708"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/3/?bust=1582081714&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/3/?bust=1582081714&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/3/?bust=1582081714&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/3/?bust=1582081714"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/4/?bust=1582081822&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/4/?bust=1582081822&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/4/?bust=1582081822&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/4/?bust=1582081822"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/5/?bust=1582081880&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/5/?bust=1582081880&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/5/?bust=1582081880&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/5/?bust=1582081880"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/6/?bust=1582081908&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/6/?bust=1582081908&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/6/?bust=1582081908&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414525/6/?bust=1582081908"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:13:49+0000",
#             "published_at": "2020-02-19T03:13:49+0000",
#             "distance": null,
#             "contact": {
#                 "email": "info@smileytailsrescue.org",
#                 "phone": "(805) 334-0098",
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Moorpark",
#                     "state": "CA",
#                     "postcode": "93020",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414525"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca2684"
#                 }
#             }
#         },
#         {
#             "id": 47414599,
#             "organization_id": "MN351",
#             "url": "https://www.petfinder.com/dog/maxine-47414599/mn/zimmerman/arrows-heart-animal-rescue-mn351/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "American Bulldog",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Senior",
#             "gender": "Female",
#             "size": "Large",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Maxine",
#             "description": null,
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414599/1/?bust=1582082000&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414599/1/?bust=1582082000&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414599/1/?bust=1582082000&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414599/1/?bust=1582082000"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:13:46+0000",
#             "published_at": "2020-02-19T03:13:46+0000",
#             "distance": null,
#             "contact": {
#                 "email": "arrowsheart2012@gmail.com",
#                 "phone": null,
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Zimmerman",
#                     "state": "MN",
#                     "postcode": "55398",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414599"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/mn351"
#                 }
#             }
#         },
#         {
#             "id": 47414556,
#             "organization_id": "CA1263",
#             "url": "https://www.petfinder.com/cat/aidan-47414556/ca/huntington-beach/the-cat-cause-foundation-ca1263/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Siamese",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Large",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Aidan",
#             "description": "Aidan is a beautiful, flame point Siamese kitty who was born in 2015.  He and his brothers, Tom and George...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414556/1/?bust=1582081813&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414556/1/?bust=1582081813&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414556/1/?bust=1582081813&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414556/1/?bust=1582081813"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:12:37+0000",
#             "published_at": "2020-02-19T03:12:37+0000",
#             "distance": null,
#             "contact": {
#                 "email": "info@catcause.com",
#                 "phone": " ",
#                 "address": {
#                     "address1": "PO Box 8123",
#                     "address2": null,
#                     "city": "Huntington Beach",
#                     "state": "CA",
#                     "postcode": "92646",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414556"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1263"
#                 }
#             }
#         },
#         {
#             "id": 47414558,
#             "organization_id": "VA117",
#             "url": "https://www.petfinder.com/dog/leo-47414558/va/arlington/lost-dog-and-cat-rescue-foundation-va117/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Catahoula Leopard Dog",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Male",
#             "size": "Large",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Leo",
#             "description": "Leo is a big, heartfelt pup from Halifax County, Virginia who has very cool colors and a cool demeanor about...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/1/?bust=1582081838&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/1/?bust=1582081838&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/1/?bust=1582081838&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/1/?bust=1582081838"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/2/?bust=1582081897&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/2/?bust=1582081897&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/2/?bust=1582081897&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/2/?bust=1582081897"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/3/?bust=1582081907&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/3/?bust=1582081907&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/3/?bust=1582081907&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414558/3/?bust=1582081907"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:12:31+0000",
#             "published_at": "2020-02-19T03:12:31+0000",
#             "distance": null,
#             "contact": {
#                 "email": "dogs@lostdogrescue.org",
#                 "phone": null,
#                 "address": {
#                     "address1": "P.O. Box 223953",
#                     "address2": null,
#                     "city": "Arlington",
#                     "state": "VA",
#                     "postcode": "22205",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414558"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/va117"
#                 }
#             }
#         },
#         {
#             "id": 47414557,
#             "organization_id": "MN351",
#             "url": "https://www.petfinder.com/dog/ruger-47414557/mn/zimmerman/arrows-heart-animal-rescue-mn351/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Pit Bull Terrier",
#                 "secondary": "Great Dane",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Large",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Ruger",
#             "description": null,
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414557/1/?bust=1582081906&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414557/1/?bust=1582081906&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414557/1/?bust=1582081906&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414557/1/?bust=1582081906"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:12:10+0000",
#             "published_at": "2020-02-19T03:12:10+0000",
#             "distance": null,
#             "contact": {
#                 "email": "arrowsheart2012@gmail.com",
#                 "phone": null,
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Zimmerman",
#                     "state": "MN",
#                     "postcode": "55398",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414557"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/mn351"
#                 }
#             }
#         },
#         {
#             "id": 47414549,
#             "organization_id": "AZ646",
#             "url": "https://www.petfinder.com/dog/pinto-47414549/az/marana/cherished-tails-senior-sanctuary-az646/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Jack Russell Terrier",
#                 "secondary": "Chihuahua",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Harlequin",
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Small",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [
#                 "Loving",
#                 "Active",
#                 "Well Behaved"
#             ],
#             "name": "PINTO",
#             "description": "Pinto is a 6 -7 year old Rat Terrier mix.  This little black and white cutie weighs in at around...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414549/1/?bust=1582081806&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414549/1/?bust=1582081806&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414549/1/?bust=1582081806&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414549/1/?bust=1582081806"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:11:14+0000",
#             "published_at": "2020-02-19T03:11:14+0000",
#             "distance": null,
#             "contact": {
#                 "email": "cherishedtails@yahoo.com",
#                 "phone": "520-616-0171",
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Marana",
#                     "state": "AZ",
#                     "postcode": "85658",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414549"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/az646"
#                 }
#             }
#         },
#         {
#             "id": 47414526,
#             "organization_id": "FL43",
#             "url": "https://www.petfinder.com/dog/max-47414526/fl/jupiter/great-dane-rescue-of-south-florida-fl43/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Great Dane",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black",
#                 "secondary": "White / Cream",
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Extra Large",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Max",
#             "description": "Max is a very mellow well behaved boy. Sweet boy. He is 4 years old.",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/1/?bust=1582081644&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/1/?bust=1582081644&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/1/?bust=1582081644&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/1/?bust=1582081644"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/2/?bust=1582081700&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/2/?bust=1582081700&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/2/?bust=1582081700&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/2/?bust=1582081700"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/3/?bust=1582081786&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/3/?bust=1582081786&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/3/?bust=1582081786&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414526/3/?bust=1582081786"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:11:02+0000",
#             "published_at": "2020-02-19T03:11:02+0000",
#             "distance": null,
#             "contact": {
#                 "email": "A82380@aol.com",
#                 "phone": "(561) 748-4017",
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Jupiter",
#                     "state": "FL",
#                     "postcode": "33478",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414526"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/fl43"
#                 }
#             }
#         },
#         {
#             "id": 47414542,
#             "organization_id": "NC282",
#             "url": "https://www.petfinder.com/cat/zada-47414542/nc/smithfield/johnston-co-animal-protection-league-nc282/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": "Tuxedo",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black & White / Tuxedo",
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Medium",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": null,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Zada",
#             "description": "Hi my name is Zada. I am a shy girl at first. But wait until I get to meet you!...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/1/?bust=1582081657&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/1/?bust=1582081657&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/1/?bust=1582081657&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/1/?bust=1582081657"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/2/?bust=1582081660&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/2/?bust=1582081660&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/2/?bust=1582081660&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/2/?bust=1582081660"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/3/?bust=1582081662&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/3/?bust=1582081662&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/3/?bust=1582081662&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/3/?bust=1582081662"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/4/?bust=1582081664&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/4/?bust=1582081664&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/4/?bust=1582081664&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47414542/4/?bust=1582081664"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:25+0000",
#             "published_at": "2020-02-19T03:10:25+0000",
#             "distance": null,
#             "contact": {
#                 "email": "help@jcapl.org",
#                 "phone": "(919) 989-7601",
#                 "address": {
#                     "address1": "P.O. Box 607",
#                     "address2": null,
#                     "city": "Smithfield",
#                     "state": "NC",
#                     "postcode": "27577",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414542"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/nc282"
#                 }
#             }
#         },
#         {
#             "id": 47414594,
#             "organization_id": "TX487",
#             "url": "https://www.petfinder.com/dog/yucca-47414594/tx/san-antonio/animal-care-services-division-city-of-san-antonio-tx487/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Yorkshire Terrier",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "YUCCA",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:15+0000",
#             "published_at": "2020-02-19T03:10:15+0000",
#             "distance": null,
#             "contact": {
#                 "email": "ACSAdoptions@sanantonio.gov",
#                 "phone": "(210) 207-6666",
#                 "address": {
#                     "address1": "4710 State Hwy 151",
#                     "address2": null,
#                     "city": "San Antonio",
#                     "state": "TX",
#                     "postcode": "78227",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414594"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx487"
#                 }
#             }
#         },
#         {
#             "id": 47414581,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/cat/rumm-47414581/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Female",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "RUMM",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414581"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414582,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/cat/pina-colada-47414582/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "PINA COLADA",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414582"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414583,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/dog/lacy-lou-47414583/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "LACY LOU",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414583"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414584,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/dog/ettie-47414584/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "ETTIE",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414584"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414585,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/dog/luben-47414585/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "LUBEN",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414585"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414586,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/cat/alexis-47414586/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "ALEXIS",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414586"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414587,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/dog/rudo-47414587/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "RUDO",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414587"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414588,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/cat/coco-fizz-47414588/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "COCO FIZZ",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414588"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414589,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/cat/lemondrop-47414589/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "LEMONDROP",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414589"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         },
#         {
#             "id": 47414590,
#             "organization_id": "OH73",
#             "url": "https://www.petfinder.com/dog/eros-47414590/oh/bowling-green/wood-county-humane-society-oh73/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "EROS",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-19T03:10:13+0000",
#             "published_at": "2020-02-19T03:10:13+0000",
#             "distance": null,
#             "contact": {
#                 "email": "woodcountyhumanesociety@gmail.com",
#                 "phone": "(419) 352-7339",
#                 "address": {
#                     "address1": "801 Van Camp Road",
#                     "address2": null,
#                     "city": "Bowling Green",
#                     "state": "OH",
#                     "postcode": "43402",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47414590"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/oh73"
#                 }
#             }
#         }
#     ],
#     "pagination": {
#         "count_per_page": 20,
#         "total_count": 8002734,
#         "current_page": 1,
#         "total_pages": 400137,
#         "_links": {
#             "next": {
#                 "href": "/v2/animals?page=2"
#             }
#         }
#     }
# }

# %%
# Extract out list of animal dictionaries (also known as records)
animal_records = response_json['animals']
animal_records

# %%
# Use Pandas to directly convert list of records to DataFrame
animals_df = pd.DataFrame(animal_records)
animals_df

# %%
# API has record limit for each pages and need to loop through multiple pages 
current_page_number = 0
num_pages_to_fetch = 10
is_first_page = False
all_pet_records = []

print('--- Data Processing Started! ---')

while current_page_number < num_pages_to_fetch:
    # Increment count
    current_page_number += 1
    print(f"Processing batch #{current_page_number}")
    
    # Perform API call
    # Configure search parameters
    params = {
        # Can add any more search parameters found at: https://www.petfinder.com/developers/v2/docs/#get-animals
        'limit': 100 # default is 20, increased to 100 items per page
    }
    
    # Pull data from petfinder.com API 
    url = f"https://api.petfinder.com/v2/animals?page={current_page_number}"
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

    # Print out each API call's 'pagination' dictionary that describes if there is a next page, other info
    print(response_json['pagination'])
    
    # Pull out records and add them to our list (app_pet_records)
    animal_records = response_json['animals']
    all_pet_records += animal_records

print('--- Data Processing Completed! ---')

# %%
len(all_pet_records)

# %%
large_animals_df = pd.DataFrame(all_pet_records)

# Show number of rows/columns
large_animals_df.shape

# %%
# Look at first 5 records
large_animals_df.head(5)

# %%
list(large_animals_df.columns)

# %%
# Perform data cleaning by filtering and keeping necessary column only
petfinder_adoption = large_animals_df.loc[:, ["id",
                                             "organization_id",
                                             "url",
                                             "type",
                                             "breeds",
                                             "colors",
                                             "age",
                                             "gender",
                                             "name",
                                             "status",
                                             "contact",
                                             "_links"]]

petfinder_adoption.head()

# %%
# Export data frame to csv file
large_animals_df.to_csv(animal_data.csv, encoding='utf-8', index=False)

# %%
# Export and save json data to json file
with open('petfinder_data_v2.json', 'w') as outfile:
    json.dump(response_json, outfile)

# %%
# Put the json file to dataframe
# json_file = "./petfinder_data_v2.json"
petfinder_data_df = pd.read_json("./petfinder_data_v2.json")
petfinder_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-7f9cf13a10a7> in <module>
#       1 # Put the json file to dataframe
#       2 # json_file = "./petfinder_data_v2.json"
# ----> 3 petfinder_data_df = pd.read_json("./petfinder_data_v2.json")
#       4 petfinder_data_df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     737         obj = None
#     738         if typ == "frame":
# --> 739             obj = FrameParser(json, **kwargs).parse()
#     740
#     741         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     847
#     848         else:
# --> 849             self._parse_no_numpy()
#     850
#     851         if self.obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1091         if orient == "columns":
#    1092             self.obj = DataFrame(
# -> 1093                 loads(json, precise_float=self.precise_float), dtype=None
#    1094             )
#    1095         elif orient == "split":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      75     # figure out the index, if necessary
#      76     if index is None:
# ---> 77         index = extract_index(arrays)
#      78     else:
#      79         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     370             if have_dicts:
#     371                 raise ValueError(
# --> 372                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     373                 )
#     374
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %% [markdown]
# ## Web Scraping

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = "http://dog.rescueme.org/California"

# %%
response = requests.get(url)
print(response.text)
# Out:
# <div class="mobile-ad-banner listing-page"><ins class="adsbygoogle" style="display:inline-block;width:320px;height:100px" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="pager-wrapper pager-bottom"><div class="row"><div class="large-12 columns paging"><div class="pagination-container p-bottom"><div class="field-bottom"></div></div></div></div></div><div class="ad-banner"><ins class="adsbygoogle" style="display:inline-block;width:728px;height:90px" data-ad-client="ca-pub-5804483683327821" data-ad-slot="5314684630"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="row"><div class="large-12 columns map-col listing-map-col"><div class="desktop-map-heading us-listing-page"><h2 class="map-heading">This map shows how many Dogs are posted in other states.</h2><p class="bold">Click on a number to view those needing rescue in that state.</p><div class="country-selection"><select id="loc-country"><option value="selected" selected="selected">- Select Different Country -</option><option value="" disabled></option></select></div></div><div class="load-counts"></div><div class="listing-map-wrapper"><div class="recent-wrapper recent-us-page"><div class="recent-adoptions"><a href=/blog><div class="title">Recent Adoptions</div><div class="recent-slides"></div><div class="link">Read Success Stories</div></a></div></div><div class="text">VIEW POSTS IN OTHER STATES BY<br>CLICKING TOP OF SCREEN MENU<br>OR ZOOM <span class="amp">&</span> DOUBLE-CLICK MAP            </div><div class="svg-map"></div></div></div></div><div class="ad-banner"><ins class="adsbygoogle" style="display:inline-block;width:728px;height:90px" data-ad-client="ca-pub-5804483683327821" data-ad-slot="5314684630"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="mobile-ad-banner listing-page"><ins class="adsbygoogle" style="display:inline-block;width:320px;height:100px" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906"></ins><script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div><div class="rescue-links listing-page"><a href=http://dog.rescueme.org/>Dog Rescue</a> <span class="sep">&#8226;</span> <a href=http://animal.rescueme.org/California>California Animal Rescue</a></div><div class="listing-terms"><picture><source media="(min-width: 1200px)" srcset="http://images.rescueme.org/assets/img/terms_desktop-lg.png"><source media="(min-width: 1024px)" srcset="http://images.rescueme.org/assets/img/terms_desktop.png"><source media="(min-width: 748px)" srcset="http://images.rescueme.org/assets/img/terms_tab.png"><source media="(min-width: 500px)" srcset="http://images.rescueme.org/assets/img/terms_mob-med.png"><source media="(max-width: 499px)" srcset="http://images.rescueme.org/assets/img/terms_mob.png"><img src="http://images.rescueme.org/assets/img/terms_desktop0.png"></picture></div><div class="ad-collection"></div></div><div class="footer-wrapper"><footer><div class="row"><div class="large-12 columns"><p class="text-small">Copyright &copy; 1999-2018 World Organization. All rights reserved. Rescue Me, RescueMe.Org, and the paw logo are registered trademarks of WO.</p></div></div></footer></div></div><div class="mobile-nav-overlay"></div><div class="inner-mobile-nav-overlay"></div><div class="modal-overlay"></div><div class="modal-wrapper"><div class="modal-content-box"><div class="modal-close modal-close-button"></div><div class="modal-content"><div class="modal-loading"><img src="http://images.rescueme.org/assets/img/loader.svg" alt="loading"></div></div></div></div><div class="modal-alert"><div class="modal-close modal-close-alert modal-close-alert-button"></div><div class="modal-alert-content"></div><a class="button modal-close-alert-button">OK</a></div><div class="modal-confirm"><div class="modal-confirm-content"></div></div><div class="modal-confirm-action"> ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    - California Dog Rescue - ADOPTIONS - Rescue Me!
#   </title>
#   <meta content='"Click here to view Dogs in California for adoption. Individuals &amp; rescue groups can post animals free." - ♥ RESCUE ME! ♥ ۬' name="description">
#    <meta content="► Dog Rescue ► California" property="og:title"/>
#    <link href="http://www.rescueme.org/favicon-rescueme.ico" rel="shortcut icon"/>
#    <meta content="http://images.rescueme.org/pn/dog-fb.png" property="og:image"/>
#    <meta content="http://dog.rescueme.org/California" property="og:url"/>
#    <meta content='"Click here to view Dogs for adoption, or post one in need." - ♥ RESCUE ME! ♥ ۬' property="og:description"/>
#    <meta content="website" property="og:type"/>
#    <meta content="714916561" property="fb:admins"/>
#    <meta content="216191288408620" property="fb:app_id"/>
#    <link href="https://images.rescueme.org/assets/css/app.css" rel="stylesheet"/>
#    <script>
#     if(window.location.hash){history.pushState({},"",window.location.href.replace(window.location.hash,''))}
#    </script>
#   </meta>
#  </head>
#  <body class="secondary">
#   <script>
#    var reqPage='';
#   </script>
#   <div class="page-wrapper">
#    <div class="main-wrapper">
#     <div id="fb-root">
#     </div>
#     <script>
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <header class="header-innerpage">
#      <div class="mobile-controls">
#       <a class="mobile-nav-toggle ra-nav-toggle">
#        <span class="span-1">
#        </span>
#        <span class="span-2">
#        </span>
#        <span class="span-3">
#        </span>
#       </a>
#       <div class="listing-page-top">
#        <div class="logo-wrapper innerpage-logo inner-mobile-logo breedpage-logo">
#         <a href="http://www.rescueme.org">
#          <img alt="Rescue Me!" class="logo" src="http://images.rescueme.org/assets/img/logo-rescueme-paw.png"/>
#          <span class="logo-text">
#           Rescue Me!
#           <sup>
#            ®
#           </sup>
#          </span>
#         </a>
#        </div>
#        <a class="button donate" href="https://donate.rescueme.org/dog">
#         Donate
#        </a>
#       </div>
#      </div>
#      <div class="mobile-breed-heading">
#       <div class="row breed-heading">
#        <div class="small-4 columns breed-photo">
#         <a href="http://dog.rescueme.org">
#          <img alt="California Dog Rescue" src="http://images.rescueme.org/p2/dog.jpg"/>
#         </a>
#        </div>
#        <div class="small-8 columns breed-title">
#         <h1 class="title-heading">
#          <div class="title-content">
#           <span class="location">
#            California
#           </span>
#           Dog Rescue
#           <div class="fb-like facebook-like" data-action="like" data-href="http://www.facebook.com/dog.rescueme.org" data-layout="button_count" data-share="false" data-show-faces="false" data-size="small">
#           </div>
#          </div>
#          <span class="total-rescue bold">
#           <span class="_ac">
#           </span>
#           Adopted!
#          </span>
#         </h1>
#        </div>
#       </div>
#      </div>
#      <div class="row header-row-desktop">
#       <div class="medium-2 large-3 columns memorial-pic">
#        <div class="photo">
#         <a href="http://dog.rescueme.org">
#          <img src="http://images.rescueme.org/p2/dog.jpg"/>
#         </a>
#        </div>
#       </div>
#       <div class="medium-6 large-5 columns main-title state-breed-main-title">
#        <div class="breed-title-wrapper">
#         <h1 class="state-breed-title desktop-breed-title">
#          <span class="location">
#           <span class="stateface">
#           </span>
#           California
#          </span>
#          Dog Rescue
#         </h1>
#        </div>
#       </div>
#       <div class="medium-4 large-4 columns logo-wrapper-large state-breed-logo-wrapper-large">
#        <div class="logo-wrapper innerpage-logo">
#         <a href="http://www.rescueme.org">
#          <img alt="Rescue Me!" class="logo" src="http://images.rescueme.org/assets/img/logo-rescueme-paw.png"/>
#          <span class="logo-text">
#           Rescue Me!
#           <sup>
#            ®
#           </sup>
#          </span>
#         </a>
#        </div>
#        <div class="fb-like facebook-like" data-action="like" data-href="http://www.facebook.com/dog.rescueme.org" data-layout="button_count" data-share="false" data-show-faces="false" data-size="small">
#        </div>
#       </div>
#      </div>
#      <div class="mobile-select-spacer">
#      </div>
#      <div class="mobile-buttons">
#       <div class="row">
#        <div class="small-12 columns buttons-wrapper">
#         <div class="nav-buttons">
#          <a class="button find-home" href="#">
#           Find home for an animal
#          </a>
#          <a class="button alerts sm" href="#">
#           Alerts
#          </a>
#          <a class="button alerts lg" href="#">
#           Get Alerts
#          </a>
#          <div class="mobile-select mobile-select-alt listingpage-filter-select">
#           <div class="select-subtext filter-subtext">
#            Filter
#           </div>
#           <ul class="display-filters-select">
#            <li data-value="all">
#             Show All
#            </li>
#            <li data-value="female">
#             Female
#            </li>
#            <li data-value="male">
#             Male
#            </li>
#            <li data-value="urgent">
#             Urgent
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="mobile-select mobile-select-alt listingpage-select">
#          <div class="select-subtext location-subtext">
#           Change Location
#          </div>
#          <ul class="mobile-state loc-select" id="mobile-loc-select">
#           <li class="standout nonus no-cookie" data-value="change-country">
#            <a href="#">
#             Change Country
#            </a>
#           </li>
#           <li class="no-cookie" data-value="NONE">
#            <span class="italic">
#             All States
#            </span>
#           </li>
#          </ul>
#          <ul class="mobile-country loc-select">
#          </ul>
#         </div>
#         <div class="mobile-select mobile-select-alt listingpage-select">
#          <div class="select-subtext breed-subtext">
#           Change Breed
#          </div>
#          <ul class="mobile-animals-select">
#           <li data-value="">
#           </li>
#          </ul>
#         </div>
#         <div class="scroll-instructions">
#          Scroll to view
#          <span class="count">
#          </span>
#          available
#          <span class="type">
#          </span>
#          .
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#     <nav class="mobile">
#      <div class="nav-mobile-close modal-close">
#       x
#      </div>
#      <ul>
#       <li class="home-search">
#        <form action="http://www.rescueme.org/search" id="cse-search-box" onsubmit="return idl()" style="margin:0">
#         <input name="cx" type="hidden" value="partner-pub-5804483683327821:xixxogzaibk"/>
#         <input name="cof" type="hidden" value="FORID:9"/>
#         <input name="ie" type="hidden" value="ISO-8859-1"/>
#         <input id="sq" name="q" onchange="idl()" onmouseover="focus()" placeholder="Search Website or By ID" type="text"/>
#         <input type="submit" value="submit"/>
#        </form>
#       </li>
#       <li class="li-find-home">
#        <a class="find-home" href="#">
#         Log into Posting Account
#        </a>
#       </li>
#       <li>
#        <a href="http://www.rescueme.org/RescueGroups">
#         Help for Shelters/Rescues
#        </a>
#       </li>
#       <li>
#        <a class="nav-success" href="/blog">
#         Success Stories
#        </a>
#       </li>
#       <li>
#        <a class="nav-facebook" href="https://www.facebook.com/dog.rescueme.org">
#         Facebook
#        </a>
#       </li>
#       <li>
#        <a href="http://www.rescueme.org/staff">
#         About Us
#        </a>
#       </li>
#       <li>
#        <a class="nav-donate" href="https://donate.rescueme.org/dog">
#         Donate
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <script>
#      function idl() {x=document.getElementById("sq").value;x=x.replace(/[^\d]/g,"");if (x.length==11) {document.location="http://post.rescueme.org/"+x.slice(0,2)+"-"+x.slice(2,4)+"-"+x.slice(4,6)+"-"+x.slice(6,11);return false;}else {return true;}}
#     </script>
#     <nav class="inner">
#      <div class="row">
#       <div class="medium-0 large-3 columns">
#        <span class="spacer">
#        </span>
#       </div>
#       <div class="medium-9 large-7 columns inner-nav-wrapper">
#        <ul class="primary-inner-nav state-breed-inner-nav">
#         <li>
#          <a class="find-home" href="#">
#           Find a Home for an Animal
#          </a>
#         </li>
#         <li>
#          <a class="alerts" href="#">
#           Alerts
#          </a>
#         </li>
#         <li>
#          <a class="change-location" href="#">
#           Change Location
#          </a>
#         </li>
#         <li>
#          <a class="change-breed" href="#">
#           Change Breed
#          </a>
#         </li>
#         <li>
#          <a class="mobile-nav" href="#">
#           More
#          </a>
#         </li>
#        </ul>
#        <div class="total-rescue bold">
#         <span class="_ac">
#         </span>
#         Dogs adopted on Rescue Me!
#        </div>
#       </div>
#       <div class="medium-3 large-2 columns">
#        <div class="search-wrapper">
#         <form action="http://www.rescueme.org/search" id="site-search-box" style="margin:0">
#          <input name="cx" type="hidden" value="partner-pub-5804483683327821:xixxogzaibk"/>
#          <input name="cof" type="hidden" value="FORID:9"/>
#          <input name="ie" type="hidden" value="ISO-8859-1"/>
#          <input name="q" placeholder="Keyword or ID" type="text"/>
#          <input type="submit" value="submit"/>
#         </form>
#        </div>
#        <a class="button donate" href="https://donate.rescueme.org/dog">
#         Donate
#        </a>
#       </div>
#      </div>
#     </nav>
#     <script>
#      var url=document.querySelector('meta[property="og:url"]').getAttribute("content"),listingLoc=url.substring(url.lastIndexOf("/")+1,url.indexOf("#"));-1===url.indexOf("#")&&(listingLoc=url.substring(url.lastIndexOf("/")+1,url.length));var RMLocName,RMBreed=url.slice(url.indexOf("://")+3,url.indexOf(".rescueme"));RMloc="http://"+RMBreed+".rescueme.org/"+listingLoc,detail_time=(new Date).getTime();var setPageClosed=function(){document.cookie="listingpage_open=; expires=Thu, 01 Jan 1970 00:00:01 GMT; path=/; domain=rescueme.org",detail_time=(new Date).getTime()};window.addEventListener("beforeunload",function(e){setPageClosed()}),window.addEventListener("pagehide",function(e){setPageClosed()});
#     </script>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({google_ad_client: "ca-pub-5804483683327821",enable_page_level_ads: true,overlays: {bottom: true}});
#     </script>
#     <header class="row header-content">
#      <div class="medium-10 columns">
#       <h1 class="page-title listing-title">
#        Adopt Dogs in California
#       </h1>
#      </div>
#      <div class="medium-2 columns filter-select">
#       <div class="select-subtext filter-subtext">
#        Filter
#       </div>
#       <select class="display-filter">
#        <option value="all">
#         Show All
#        </option>
#        <option value="female">
#         Female
#        </option>
#        <option value="male">
#         Male
#        </option>
#        <option value="urgent">
#         Urgent
#        </option>
#       </select>
#      </div>
#     </header>
#     <div class="ad-banner">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="5314684630" style="display:inline-block;width:728px;height:90px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="pager-wrapper pager-top">
#      <div class="row">
#       <div class="large-12 columns">
#        <div class="pagination-container p-top">
#         <div class="field-top">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl empty">
#     </div>
#     <div class="card _cl _fa _fm _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00501
#          </span>
#          <span class="_rbc hidden">
#           D008
#          </span>
#          <span class="_cpn">
#           MAX
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00501">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             American Staffordshire Terrier
#            </span>
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Van Nuys, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1904893
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00501.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           You can maximize your life if you adopt/rescue Max (#A1904893)! He's waiting for his forever family at the East
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00482
#          </span>
#          <span class="_rbc hidden">
#           D062
#          </span>
#          <span class="_cpn">
#           Groot,Milo Adopt Toget
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00482">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Dutch Shepherd
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Van Nuys, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1926213,A1926214
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00482.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Another bully landlord broke up a loving family. GROOT (#A1926213), a 3-year-old female, and MILO (#A1926214), a 6
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-ad-banner listing-page">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906" style="display:inline-block;width:320px;height:100px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="card _cl _fa _fm">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00465
#          </span>
#          <span class="_rbc hidden">
#           D048
#          </span>
#          <span class="_cpn">
#           Bravo
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00465">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Chihuahua
#            </span>
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Chatsworth, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1924204
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00465.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           10 years.6 pounds
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00457
#          </span>
#          <span class="_rbc hidden">
#           D048
#          </span>
#          <span class="_cpn">
#           Pancho
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00457">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Chihuahua
#            </span>
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Chatsworth, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1926495
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00457.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Dumped at shelter this 15year old 5 pound angel!
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-ad-banner listing-page">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906" style="display:inline-block;width:320px;height:100px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="card _cl _fa _ff">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00454
#          </span>
#          <span class="_rbc hidden">
#           D074
#          </span>
#          <span class="_cpn">
#           Autumn
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00454">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             German Shepherd
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Sierra Madre, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00454
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00454.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Autumns was found as a stray over a year ago and has been in foster care every since. She is one of the best dogs
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00442
#          </span>
#          <span class="_rbc hidden">
#           D092
#          </span>
#          <span class="_cpn">
#           Milo
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00442">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Jack Russell
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Sierra Madre, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00442
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00442.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Milo was found as a stray and owners never came for him. He's a very sweet tempered dog, quiet, and independent. He
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00435
#          </span>
#          <span class="_rbc hidden">
#           D147
#          </span>
#          <span class="_cpn">
#           Captain
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00435">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Siberian Husky
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, Sierra Madre, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00435
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00435.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Captain was found as a stray and owners never came. He's a very sweet, smart, and playful boy. He's roughly 5
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00420
#          </span>
#          <span class="_rbc hidden">
#           D055
#          </span>
#          <span class="_cpn">
#           Toby
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00420">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Corgi
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Orange County, Orange, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00420
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00420.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           This boy is so much fun. He likes to cuddle and snuggle and ready to play when you are. He is a very quiet boy.
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00408
#          </span>
#          <span class="_rbc hidden">
#           D074
#          </span>
#          <span class="_cpn">
#           Angel
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00408">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             German Shepherd
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, los Angeles, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1896321
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00408.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           ANGEL - ID#A1896321 My name is Angel and I am a spayed female, black mixed breed.  The shelter thinks I am about 4
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00380
#          </span>
#          <span class="_rbc hidden">
#           D099
#          </span>
#          <span class="_cpn">
#           Chocomax
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00380">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Lab
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, los Angeles, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1822792
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00380.jpg"/>
#         </a>
#         <div class="_cv _vy">
#          <iframe allowfullscreen="" frameborder="0" id="video-iframe" src="https://www.youtube.com/embed/mAotwbSz5Yc?rel=0&amp;showinfo=0" width="100%">
#          </iframe>
#         </div>
#         <div class="_si">
#          <a class="_scv _syv" href="#">
#           <img class="youtube" src="http://images.rescueme.org/assets/img/youtube-sm.png"/>
#          </a>
#          <a class="_scv _sfv" href="#">
#           <img class="youtube" src="http://images.rescueme.org/assets/img/facebookvideo-sm.png"/>
#          </a>
#          <a class="_scp" href="#">
#           Back to Photo
#          </a>
#         </div>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           CHOCOMAX - ID#A1822792 My name is Chocomax and I am a neutered male, chocolate and white Mixed breed. The shelter
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00374
#          </span>
#          <span class="_rbc hidden">
#           D147
#          </span>
#          <span class="_cpn">
#           Aurora
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00374">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Siberian Husky
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            San Bernardino County, Rancho Cucamonga, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00374
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00374.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           Hi my name is aurora I was found in Whittier running loose and some very nice dog groomers picked me up , we can't
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00371
#          </span>
#          <span class="_rbc hidden">
#           D168
#          </span>
#          <span class="_cpn">
#           Macie
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00371">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Yorkie
#            </span>
#           </div>
#           <span class="_clo _clom">
#            San Diego County, San Diego, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00371
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00371.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           [
#           <a href="http://dog.rescueme.org/incontinence" target="_nhealth">
#            <u>
#             Read About Natural Incontinence Care
#            </u>
#           </a>
#           ]
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _fm _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00360
#          </span>
#          <span class="_rbc hidden">
#           D074
#          </span>
#          <span class="_cpn">
#           Max
#          </span>
#          <span class="_csx _csxm">
#           (m)
#          </span>
#          <span class="_csx _csxd">
#           (male)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00360">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             German Shepherd
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Los Angeles County, los Angeles, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A1762754
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00360.jpg"/>
#         </a>
#         <div class="_cv _vy">
#          <iframe allowfullscreen="" frameborder="0" id="video-iframe" src="https://www.youtube.com/embed/z6ps4wj1GXA?rel=0&amp;showinfo=0" width="100%">
#          </iframe>
#         </div>
#         <div class="_si">
#          <a class="_scv _syv" href="#">
#           <img class="youtube" src="http://images.rescueme.org/assets/img/youtube-sm.png"/>
#          </a>
#          <a class="_scv _sfv" href="#">
#           <img class="youtube" src="http://images.rescueme.org/assets/img/facebookvideo-sm.png"/>
#          </a>
#          <a class="_scp" href="#">
#           Back to Photo
#          </a>
#         </div>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           SOS! Max is an adorable guy who is URGENTLY AT RISK! A three-year-old mixed breed (possibly Shepherd and Rottie).
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00332
#          </span>
#          <span class="_rbc hidden">
#           D083
#          </span>
#          <span class="_cpn">
#           Sable
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-18-00332">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Greyhound
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Orange County, Orange, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            20-02-18-00332
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/18/20-02-18-00332.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           We have no idea what breed Sable is but she is so adorable.  Sable is about 1 - 2 years old and weighs 15 pounds.
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff">
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-18-00329
#          </span>
#          <span class="_rbc hidden">
#           D168
#          </span>
#          <span class="_cpn">
#           Molly
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
# ...
#          <p>
#           I am described as a female, gray and white Terrier.  The shelter thinks I am about 1 year.  I weigh approximately
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-12-00221
#          </span>
#          <span class="_rbc hidden">
#           D048
#          </span>
#          <span class="_cpn">
#           URGENT AFTER 2/22
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-12-00221">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Chihuahua
#            </span>
#           </div>
#           <span class="_clo _clom">
#            Riverside County, Moreno Valley, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A503849
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/12/20-02-12-00221.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           am described as a female, white and black Chihuahua - Smooth Coated.  The shelter thinks I am about 3 years old.  I
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-12-00219
#          </span>
#          <span class="_rbc hidden">
#           D148
#          </span>
#          <span class="_cpn">
#           URGENT AFTER 2/19
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-12-00219">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Silky Terrier
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Riverside County, Moreno Valley, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A503848
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/12/20-02-12-00219.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           I am described as a female, black and gray Terrier mix.  The shelter thinks I am about 1 year.  I weigh
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-12-00218
#          </span>
#          <span class="_rbc hidden">
#           D127
#          </span>
#          <span class="_cpn">
#           URGENT AFTER 2/18
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-12-00218">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             Poodle
#            </span>
#           </div>
#           <span class="_clo _clom">
#            Riverside County, Moreno Valley, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A503837
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/12/20-02-12-00218.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           I am described as a female, white and cream Poodle - Miniature.  The shelter thinks I am about 1 year.  I weigh
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="card _cl _fa _ff _fu">
#      <div class="_cu _ud">
#       URGENT: This animal could be euthanized if not adopted soon.
#      </div>
#      <div class="_cu _um">
#       URGENT: Animal could be euthanized soon.
#      </div>
#      <div class="row">
#       <div class="large-12 columns _ccl">
#        <div class="_ch _chm">
#         <h2 class="_cn">
#          <div class="_cct">
#          </div>
#          <span class="_cs">
#          </span>
#          <span class="_rid hidden">
#           20-02-12-00214
#          </span>
#          <span class="_rbc hidden">
#           D074
#          </span>
#          <span class="_cpn">
#           URGENT AFTER 2/18
#          </span>
#          <span class="_csx _csxm">
#           (f)
#          </span>
#          <span class="_csx _csxd">
#           (female)
#          </span>
#          <a class="_cdlk" href="http://post.rescueme.org/20-02-12-00214">
#           <div class="_ct _ctm">
#            <span class="_sbbr">
#             German Shepherd
#            </span>
#            mix
#           </div>
#           <span class="_clo _clom">
#            Riverside County, Moreno Valley, CA
#           </span>
#          </a>
#          <span class="_cid">
#           <span class="_rmt">
#            ID:
#           </span>
#           <span class="_aid">
#            A503832
#           </span>
#          </span>
#         </h2>
#        </div>
#        <div class="_cm">
#         <div class="media-loader">
#          <div class="modal-loading">
#           <img src="http://images.rescueme.org/assets/img/loader.svg"/>
#          </div>
#         </div>
#         <span class="_cs _sa">
#         </span>
#         <a class="_cpl" href="#">
#          <img class="_pp" data-original="http://images.rescueme.org/20/02/12/20-02-12-00214.jpg"/>
#         </a>
#        </div>
#        <div class="_cd">
#         <div class="_ch _chd">
#          <h2 class="_cn">
#          </h2>
#         </div>
#         <div class="_cdc">
#          <span class="_ct _ctd">
#          </span>
#          <div class="_cdl">
#           <div class="small-loading">
#            <img src="http://images.rescueme.org/assets/img/loading.gif"/>
#           </div>
#          </div>
#          <p>
#           I am described as a female, black and tan German Shepherd Dog mix.  The shelter thinks I am about 3 years old.  I
#          </p>
#          <span class="_clo _clod">
#          </span>
#          <a class="_rm" href="#">
#           Read more »
#          </a>
#         </div>
#         <a class="button _cdt" href="#">
#          Details / Contact
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-ad-banner listing-page">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906" style="display:inline-block;width:320px;height:100px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="pager-wrapper pager-bottom">
#      <div class="row">
#       <div class="large-12 columns paging">
#        <div class="pagination-container p-bottom">
#         <div class="field-bottom">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="ad-banner">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="5314684630" style="display:inline-block;width:728px;height:90px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="row">
#      <div class="large-12 columns map-col listing-map-col">
#       <div class="desktop-map-heading us-listing-page">
#        <h2 class="map-heading">
#         This map shows how many Dogs are posted in other states.
#        </h2>
#        <p class="bold">
#         Click on a number to view those needing rescue in that state.
#        </p>
#        <div class="country-selection">
#         <select id="loc-country">
#          <option selected="selected" value="selected">
#           - Select Different Country -
#          </option>
#          <option disabled="" value="">
#          </option>
#         </select>
#        </div>
#       </div>
#       <div class="load-counts">
#       </div>
#       <div class="listing-map-wrapper">
#        <div class="recent-wrapper recent-us-page">
#         <div class="recent-adoptions">
#          <a href="/blog">
#           <div class="title">
#            Recent Adoptions
#           </div>
#           <div class="recent-slides">
#           </div>
#           <div class="link">
#            Read Success Stories
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="text">
#         VIEW POSTS IN OTHER STATES BY
#         <br/>
#         CLICKING TOP OF SCREEN MENU
#         <br/>
#         OR ZOOM
#         <span class="amp">
#          &amp;
#         </span>
#         DOUBLE-CLICK MAP
#        </div>
#        <div class="svg-map">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="ad-banner">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="5314684630" style="display:inline-block;width:728px;height:90px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="mobile-ad-banner listing-page">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5804483683327821" data-ad-slot="2905877906" style="display:inline-block;width:320px;height:100px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="rescue-links listing-page">
#      <a href="http://dog.rescueme.org/">
#       Dog Rescue
#      </a>
#      <span class="sep">
#       •
#      </span>
#      <a href="http://animal.rescueme.org/California">
#       California Animal Rescue
#      </a>
#     </div>
#     <div class="listing-terms">
#      <picture>
#       <source media="(min-width: 1200px)" srcset="http://images.rescueme.org/assets/img/terms_desktop-lg.png"/>
#       <source media="(min-width: 1024px)" srcset="http://images.rescueme.org/assets/img/terms_desktop.png"/>
#       <source media="(min-width: 748px)" srcset="http://images.rescueme.org/assets/img/terms_tab.png"/>
#       <source media="(min-width: 500px)" srcset="http://images.rescueme.org/assets/img/terms_mob-med.png"/>
#       <source media="(max-width: 499px)" srcset="http://images.rescueme.org/assets/img/terms_mob.png"/>
#       <img src="http://images.rescueme.org/assets/img/terms_desktop0.png"/>
#      </picture>
#     </div>
#     <div class="ad-collection">
#     </div>
#    </div>
#    <div class="footer-wrapper">
#     <footer>
#      <div class="row">
#       <div class="large-12 columns">
#        <p class="text-small">
#         Copyright © 1999-2018 World Organization. All rights reserved. Rescue Me, RescueMe.Org, and the paw logo are registered trademarks of WO.
#        </p>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <div class="mobile-nav-overlay">
#   </div>
#   <div class="inner-mobile-nav-overlay">
#   </div>
#   <div class="modal-overlay">
#   </div>
#   <div class="modal-wrapper">
#    <div class="modal-content-box">
#     <div class="modal-close modal-close-button">
#     </div>
#     <div class="modal-content">
#      <div class="modal-loading">
#       <img alt="loading" src="http://images.rescueme.org/assets/img/loader.svg"/>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal-alert">
#    <div class="modal-close modal-close-alert modal-close-alert-button">
#    </div>
#    <div class="modal-alert-content">
#    </div>
#    <a class="button modal-close-alert-button">
#     OK
#    </a>
#   </div>
#   <div class="modal-confirm">
#    <div class="modal-confirm-content">
#    </div>
#   </div>
#   <div class="modal-confirm-action">
#    <div class="modal-close modal-close-confirm-action modal-close-confirm-action-button">
#    </div>
#    <div class="modal-confirm-action-content">
#    </div>
#    <a class="button modal-ok-confirm-action-button">
#     OK
#    </a>
#    <a class="button modal-close-confirm-action-button">
#     Cancel
#    </a>
#   </div>
#   <a class="scroll-up" href="#">
#    <img src="http://images.rescueme.org/assets/img/up-arrow.png"/>
#   </a>
#   <script src="https://images.rescueme.org/assets/js/app.js">
#   </script>
#  </body>
# </html>
# <!-- END -->

# %%
names = soup.find_all('span', class_= '_cpn')

for name in names:
    print(name.text)
# Out:
# MAX
# Groot,Milo Adopt Toget
# Bravo
# Pancho
# Autumn
# Milo
# Captain
# Toby
# Angel
# Chocomax
# Aurora
# Macie
# Max
# Sable
# Molly
# Brianna
# Oliver
# Leta
# Charley
# URGENT AFTER 2/25
# LUCKY-URGENT 3/3
# Grover
# Portia
# Naomi
# Zuzu
# Puppy
# Fredo
# Cuddles
# Alice
# Oreo
# Cali
# Copper
#
# Walker
# Sheba
# Max
# Buddy
# mack
# Ned Pepper
# Sweet tea
# Tank
# Midnight
# Frankie
# Rhiannon
# Honey biscuit
# Roger
# Velvet / Violet
# Whiskey a go go
# Storm
# Fox
# Doe
# Badger
# Taz
# Hawk
# Coon
# Bear
# URGENT AFTER 2/25
# URGENT AFTER 2/25
# Sonny 4 lbs
# Henri
# Bella
# Buck
# Cowboy
# Shadow
# Max
# Copper
# George
# Axel
# Kuhio
# Tank
# Princess
# Milo
# Klaus
# Bruno
# Princ Harry
# Pippa
# Spencer
# Frankie
# Milo
# Pancho
# Elizabeth
# Roxy
# Ally
# MADDIE
# COOPER
# COWBOY
# Arturo
# Poldi
# Smalls
# Mia
# Bruno
# Zeus
# URGENT AFTER 2/22
# Captain & Clifford
# Henry is a shy Doxie
# Rocky
# Benji
# Phoebe
# Vladimir
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# Sasha
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# URGENT AFTER 2/21
# Chance
# URGENT AFTER 2/22
# URGENT AFTER 2/26
# Georgie
# URGENT AFTER 2/19
# URGENT AFTER 2/19
# URGENT AFTER 2/19
# Nala
# URGENT AFTER 2/19
# URGENT AFTER 2/20
# Olivia
# Lilikoi
# Mojo
# Noki
# Theo
# Rocky
# Minnie
# Mia
# Codey and Luna
# Beverly
# Reggie
# Many names
# Many names
# Zully
# Skye
# Jack
# Bunny
# URGENT - HEATH
# URGENT - LUNA
# URGENT - RAT TERRIER
# Mickey
# Mickey
# URGENT - SANDY
# Twinkie
# URGENT - SPIKE
# Oakley
# URGENT - ROCKY
# URGENT - MELVIN
# Pepper
# Smokey
# Dillon
# Chloe
# Hooey
# Wrangler
# Ryder
# Hazel
# Dooby
# Titus
# Shyloh
#
# Ollie
# Grayson
# Tonka
#
# Feagan
# Sariya
# Sunny
# Rambo
# Hera
# Love Bug
# River
# Lilith
# Rocky
# Moo Moo
# Misty
# Lucky
# Kodak
# Elvis
# Cupid
# Cherub
# Bruno
# Roxy
# Ringo
# Sammie
# LUCARIO-URGENT NOW
# URGENT AFTER 2/20
# URGENT AFTER 2/20
# SPARKY-URGENT 2/27
# URGENT AFTER 2/20
# Rhett
# Rosie
# Simba
# Tulipa
# Happy
# VENUS
#
#
# Puppies 7
# Finn
# Leia
# Lulu
# Brusier
# KING KONG
# Boomy
# Frenchie
# Hulk
# Tanker
# Luka
# Lexi
# CONRAD
# Elsa and Ollie
# A1678644
# Wiley
# Jack
# Tatum
# Koda
# Biscuit
# Sabstian
# Bailey
# Rose
# Gypsy
# Chuvasco
# Josefina
# Velvet & Violet
# Beau
# OLIVER *URGENT* PUPPY
# Riggs
# Rodeo
# Howie
# Mia
# Baby
# Tyson
# Loki
# Abbie
# Dixie
# Paco and Rudy
#
# Bella
# Noale (no-all-ee)
# Ivy
# Titan
# Scruffy
# Godiva
# URGENT AFTER 2/22
# URGENT AFTER 2/22
# URGENT AFTER 2/19
# URGENT AFTER 2/18
# URGENT AFTER 2/18
