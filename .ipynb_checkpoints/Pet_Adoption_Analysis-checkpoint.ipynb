# %%
# Dependencies
import json
import requests
import pandas as pd
from config import petfinder_api_key, petfinder_secret_key

# %%
# Request token for the Petfinder API
data = {
  'grant_type': 'client_credentials',
  'client_id': petfinder_api_key,
  'client_secret': petfinder_secret_key
}

token_response = requests.post('https://api.petfinder.com/v2/oauth2/token', data=data)
token_response_json = token_response.json()

print(json.dumps(token_response_json, indent = 4))
# Out:
# {
#     "token_type": "Bearer",
#     "expires_in": 3600,
#     "access_token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6Ijk0MTcyNWU0YmJmYTA5YWNmZmJhN2ExNWM4NTI1YmUyZjM1MzE3ODE5OTc2YjJmYTExYTlkMWQ0MjNiYTA1YzQ4M2FhMWMxZGVkNGFkMjNkIn0..qNKAZQwHwVgcNwAFgX5VkW4K-FqQmiCjQ9V7bs37ErJJJIWYXw2HqERkRZ52f18pYTdmExmMKYVGM7gDxyvRaQbWQZ4mMPnfvqyajHzcGRp9go7Zyt98RUk0rDcudjFIi8b6ipZxNyjS1RC40n4Bi_pcWu7jYpxCsCjdXM3bJaex0cU3AcQsFoeQO7eitSTaMrxncm6H1VcFhBX5-ITvUByWQ8FWTH3TkoHevllXmdUSHsYECt7_pwnsrBL7bSLgFtoe9lxWXTPNEKLkS_1Q-YfyxPQB8UCcMpDw4nOdpStrS35siRaJluAaiXe3WV3OblaDLmzaFpll8LrIhhwuew"
# }

# %%
# Pull data from petfinder.com API 
headers = {'Authorization': f"Bearer {token_response_json['access_token']}"}
url = "https://api.petfinder.com/v2/animals?"
response = requests.get(url, headers=headers)
response_json = response.json()

print(json.dumps(response_json, indent = 4))
# Out:
# {
#     "animals": [
#         {
#             "id": 47441916,
#             "organization_id": "FL185",
#             "url": "https://www.petfinder.com/cat/beau-47441916/fl/clearwater/humane-society-of-pinellas-fl185/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Medium Hair",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Orange & White",
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Beau",
#             "description": "For further information please visit our website at www.humanesocietyofpinellas.org which is live and if an animal is still posted, he/she...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441916/1/?bust=1582334529&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441916/1/?bust=1582334529&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441916/1/?bust=1582334529&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441916/1/?bust=1582334529"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:22:22+0000",
#             "published_at": "2020-02-22T01:22:22+0000",
#             "distance": null,
#             "contact": {
#                 "email": "adoptions@humanepinellas.org",
#                 "phone": "(727) 797-7722",
#                 "address": {
#                     "address1": "3040 State Road 590",
#                     "address2": null,
#                     "city": "Clearwater",
#                     "state": "FL",
#                     "postcode": "33759",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441916"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/fl185"
#                 }
#             }
#         },
#         {
#             "id": 47441817,
#             "organization_id": "FL551",
#             "url": "https://www.petfinder.com/dog/cybil-47441817/fl/bradenton/underdog-rescue-of-florida-fl551/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Shih Tzu",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "White / Cream",
#                 "secondary": "Yellow / Tan / Blond / Fawn",
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Small",
#             "coat": "Medium",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Cybil",
#             "description": "Cybil is a an exceptionally sweet, well behaved 13 pound 4 year old Shih Tzu. She gets along with adults,...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441817/1/?bust=1582334478&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441817/1/?bust=1582334478&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441817/1/?bust=1582334478&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441817/1/?bust=1582334478"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:22:11+0000",
#             "published_at": "2020-02-22T01:22:11+0000",
#             "distance": null,
#             "contact": {
#                 "email": "mail@underdogrescueofflorida.com",
#                 "phone": "(941) 746-9663",
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Bradenton",
#                     "state": "FL",
#                     "postcode": "34208",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441817"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/fl551"
#                 }
#             }
#         },
#         {
#             "id": 47441913,
#             "organization_id": "FL318",
#             "url": "https://www.petfinder.com/dog/chance-47441913/fl/fernandina-beach/nassau-humane-society-fl318/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black",
#                 "secondary": "White / Cream",
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "CHANCE",
#             "description": "Chance is an affectionate youngster whose sweet brown eyes say it all! He has great leash manners for such a...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/1/?bust=1582334458&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/1/?bust=1582334458&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/1/?bust=1582334458&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/1/?bust=1582334458"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/2/?bust=1582334468&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/2/?bust=1582334468&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/2/?bust=1582334468&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/2/?bust=1582334468"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/3/?bust=1582334478&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/3/?bust=1582334478&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/3/?bust=1582334478&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441913/3/?bust=1582334478"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:21:51+0000",
#             "published_at": "2020-02-22T01:21:51+0000",
#             "distance": null,
#             "contact": {
#                 "email": "info@nassauhumane.org",
#                 "phone": "(904) 321-1647",
#                 "address": {
#                     "address1": "639 Airport Road",
#                     "address2": null,
#                     "city": "Fernandina Beach",
#                     "state": "FL",
#                     "postcode": "32034",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441913"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/fl318"
#                 }
#             }
#         },
#         {
#             "id": 47441918,
#             "organization_id": "CA1028",
#             "url": "https://www.petfinder.com/cat/caroline-47441918/ca/redwood-city/nine-lives-foundation-ca1028/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Caroline",
#             "description": "Caroline (DOB 2012) is a very pretty calico",
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:21:08+0000",
#             "published_at": "2020-02-22T01:21:08+0000",
#             "distance": null,
#             "contact": {
#                 "email": "ninelivesfoundation@gmail.com",
#                 "phone": "650-368-1365",
#                 "address": {
#                     "address1": "3016 Rolison Road",
#                     "address2": null,
#                     "city": "Redwood City",
#                     "state": "CA",
#                     "postcode": "94063",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441918"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1028"
#                 }
#             }
#         },
#         {
#             "id": 47441917,
#             "organization_id": "CA1028",
#             "url": "https://www.petfinder.com/cat/hoot-47441917/ca/redwood-city/nine-lives-foundation-ca1028/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black & White / Tuxedo",
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Hoot",
#             "description": "Caroline (DOB 2012) is a very pretty calico",
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:21:07+0000",
#             "published_at": "2020-02-22T01:21:07+0000",
#             "distance": null,
#             "contact": {
#                 "email": "ninelivesfoundation@gmail.com",
#                 "phone": "650-368-1365",
#                 "address": {
#                     "address1": "3016 Rolison Road",
#                     "address2": null,
#                     "city": "Redwood City",
#                     "state": "CA",
#                     "postcode": "94063",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441917"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1028"
#                 }
#             }
#         },
#         {
#             "id": 47441915,
#             "organization_id": "NC1040",
#             "url": "https://www.petfinder.com/dog/roadster-47441915/nc/bostic/lee-shore-rescue-inc-nc1040/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "American Bulldog",
#                 "secondary": "Boxer",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Roadster",
#             "description": "Roadster is an handsome male Boxer/American Bully mix. He was born on 012/9/2019. He is expected to be a medium...",
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:20:36+0000",
#             "published_at": "2020-02-22T01:20:36+0000",
#             "distance": null,
#             "contact": {
#                 "email": "elizabethatleeshore@gmail.com",
#                 "phone": "(828) 817-9147",
#                 "address": {
#                     "address1": null,
#                     "address2": null,
#                     "city": "Bostic",
#                     "state": "NC",
#                     "postcode": "28018",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441915"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/nc1040"
#                 }
#             }
#         },
#         {
#             "id": 47441858,
#             "organization_id": "FL185",
#             "url": "https://www.petfinder.com/cat/raven-47441858/fl/clearwater/humane-society-of-pinellas-fl185/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Black",
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "Raven",
#             "description": "For further information please visit our website at www.humanesocietyofpinellas.org which is live and if an animal is still posted, he/she...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441858/1/?bust=1582334370&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441858/1/?bust=1582334370&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441858/1/?bust=1582334370&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441858/1/?bust=1582334370"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:19:47+0000",
#             "published_at": "2020-02-22T01:19:47+0000",
#             "distance": null,
#             "contact": {
#                 "email": "adoptions@humanepinellas.org",
#                 "phone": "(727) 797-7722",
#                 "address": {
#                     "address1": "3040 State Road 590",
#                     "address2": null,
#                     "city": "Clearwater",
#                     "state": "FL",
#                     "postcode": "33759",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441858"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/fl185"
#                 }
#             }
#         },
#         {
#             "id": 47441810,
#             "organization_id": "WA219",
#             "url": "https://www.petfinder.com/dog/rogue-47441810/wa/ocean-shores/north-beach-paws-wa219/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "American Bulldog",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": "Brown / Chocolate",
#                 "secondary": "White / Cream",
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Large",
#             "coat": "Short",
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": true
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": false
#             },
#             "tags": [],
#             "name": "Rogue",
#             "description": "Rogue is a very pretty 3 year old American Bulldog who weighs about 75 pounds. Great with kids and dogs,...",
#             "photos": [
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/1/?bust=1582334064&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/1/?bust=1582334064&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/1/?bust=1582334064&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/1/?bust=1582334064"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/2/?bust=1582334097&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/2/?bust=1582334097&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/2/?bust=1582334097&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/2/?bust=1582334097"
#                 },
#                 {
#                     "small": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/3/?bust=1582334144&width=100",
#                     "medium": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/3/?bust=1582334144&width=300",
#                     "large": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/3/?bust=1582334144&width=600",
#                     "full": "https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/47441810/3/?bust=1582334144"
#                 }
#             ],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:19:33+0000",
#             "published_at": "2020-02-22T01:19:33+0000",
#             "distance": null,
#             "contact": {
#                 "email": "nobeachpawsjohn@gmail.com",
#                 "phone": "360-660-4660",
#                 "address": {
#                     "address1": "PO Box 962",
#                     "address2": null,
#                     "city": "Ocean Shores",
#                     "state": "WA",
#                     "postcode": "98569",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441810"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/wa219"
#                 }
#             }
#         },
#         {
#             "id": 47441912,
#             "organization_id": "AZ108",
#             "url": "https://www.petfinder.com/dog/zena-47441912/az/phoenix/az-small-dog-rescue-az108/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Terrier",
#                 "secondary": null,
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Female",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": true,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": true,
#                 "dogs": true,
#                 "cats": true
#             },
#             "tags": [],
#             "name": "Zena",
#             "description": "Zena is an outgoing 4 year old Terrier mix looking for her forever home. She weighs 9.4 pounds and is...",
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:19:04+0000",
#             "published_at": "2020-02-22T01:19:04+0000",
#             "distance": null,
#             "contact": {
#                 "email": "info@azsmalldog.org",
#                 "phone": "602-944-2440",
#                 "address": {
#                     "address1": "1102 W Hatcher Road",
#                     "address2": null,
#                     "city": "Phoenix",
#                     "state": "AZ",
#                     "postcode": "85021",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441912"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/az108"
#                 }
#             }
#         },
#         {
#             "id": 47441898,
#             "organization_id": "CA768",
#             "url": "https://www.petfinder.com/dog/precious-47441898/ca/san-pedro/city-of-los-angeles-harbor-animal-shelter-ca768/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Mixed Breed",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "PRECIOUS",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": null,
#                 "phone": "(888) 452-7381",
#                 "address": {
#                     "address1": "957 North Gaffey St",
#                     "address2": null,
#                     "city": "San Pedro",
#                     "state": "CA",
#                     "postcode": "90731",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441898"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca768"
#                 }
#             }
#         },
#         {
#             "id": 47441900,
#             "organization_id": "CA672",
#             "url": "https://www.petfinder.com/dog/a5353952-47441900/ca/castaic/l-dot-a-county-animal-care-control-castaic-shelter-ca672/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Lhasa Apso",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Adult",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A5353952",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": null,
#                 "phone": "661-257-3191",
#                 "address": {
#                     "address1": "31044 N. Charlie Canyon Rd.",
#                     "address2": null,
#                     "city": "Castaic",
#                     "state": "CA",
#                     "postcode": "91384",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441900"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca672"
#                 }
#             }
#         },
#         {
#             "id": 47441899,
#             "organization_id": "TX447",
#             "url": "https://www.petfinder.com/cat/miley-47441899/tx/waco/humane-society-of-central-tx-tx447/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Cat",
#             "species": "Cat",
#             "breeds": {
#                 "primary": "Domestic Short Hair",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": true,
#                 "house_trained": false,
#                 "declawed": false,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "MILEY",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "hsctapplications@gmail.com",
#                 "phone": "254-754-1454",
#                 "address": {
#                     "address1": "2032 Circle Rd",
#                     "address2": null,
#                     "city": "Waco",
#                     "state": "TX",
#                     "postcode": "76706",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441899"
#                 },
#                 "type": {
#                     "href": "/v2/types/cat"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx447"
#                 }
#             }
#         },
#         {
#             "id": 47441909,
#             "organization_id": "CA1110",
#             "url": "https://www.petfinder.com/dog/a538366-47441909/ca/modesto/stanislaus-animal-services-agency-ca1110/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Miniature Pinscher",
#                 "secondary": null,
#                 "mixed": false,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A538366",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "champostmaster@stancounty.com",
#                 "phone": "(209) 558-7387",
#                 "address": {
#                     "address1": "3647 Cornucopia Way",
#                     "address2": null,
#                     "city": "Modesto",
#                     "state": "CA",
#                     "postcode": "95354",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441909"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1110"
#                 }
#             }
#         },
#         {
#             "id": 47441910,
#             "organization_id": "CA1110",
#             "url": "https://www.petfinder.com/dog/buster-47441910/ca/modesto/stanislaus-animal-services-agency-ca1110/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Chihuahua",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "BUSTER",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "champostmaster@stancounty.com",
#                 "phone": "(209) 558-7387",
#                 "address": {
#                     "address1": "3647 Cornucopia Way",
#                     "address2": null,
#                     "city": "Modesto",
#                     "state": "CA",
#                     "postcode": "95354",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441910"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1110"
#                 }
#             }
#         },
#         {
#             "id": 47441911,
#             "organization_id": "CA1110",
#             "url": "https://www.petfinder.com/dog/chiweinie-47441911/ca/modesto/stanislaus-animal-services-agency-ca1110/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Dachshund",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Young",
#             "gender": "Male",
#             "size": "Medium",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "CHIWEINIE",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "champostmaster@stancounty.com",
#                 "phone": "(209) 558-7387",
#                 "address": {
#                     "address1": "3647 Cornucopia Way",
#                     "address2": null,
#                     "city": "Modesto",
#                     "state": "CA",
#                     "postcode": "95354",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441911"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/ca1110"
#                 }
#             }
#         },
#         {
#             "id": 47441907,
#             "organization_id": "TX424",
#             "url": "https://www.petfinder.com/dog/a550796-47441907/tx/houston/harris-county-pets-tx424/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Labrador Retriever",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A550796",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "webmaster@countypets.com",
#                 "phone": "(281) 999-3191",
#                 "address": {
#                     "address1": "612 Canino Rd",
#                     "address2": null,
#                     "city": "Houston",
#                     "state": "TX",
#                     "postcode": "77076",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441907"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx424"
#                 }
#             }
#         },
#         {
#             "id": 47441908,
#             "organization_id": "TX424",
#             "url": "https://www.petfinder.com/dog/a550794-47441908/tx/houston/harris-county-pets-tx424/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Labrador Retriever",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A550794",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:58+0000",
#             "published_at": "2020-02-22T01:18:58+0000",
#             "distance": null,
#             "contact": {
#                 "email": "webmaster@countypets.com",
#                 "phone": "(281) 999-3191",
#                 "address": {
#                     "address1": "612 Canino Rd",
#                     "address2": null,
#                     "city": "Houston",
#                     "state": "TX",
#                     "postcode": "77076",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441908"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx424"
#                 }
#             }
#         },
#         {
#             "id": 47441901,
#             "organization_id": "TX424",
#             "url": "https://www.petfinder.com/dog/a550793-47441901/tx/houston/harris-county-pets-tx424/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Labrador Retriever",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A550793",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:57+0000",
#             "published_at": "2020-02-22T01:18:57+0000",
#             "distance": null,
#             "contact": {
#                 "email": "webmaster@countypets.com",
#                 "phone": "(281) 999-3191",
#                 "address": {
#                     "address1": "612 Canino Rd",
#                     "address2": null,
#                     "city": "Houston",
#                     "state": "TX",
#                     "postcode": "77076",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441901"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx424"
#                 }
#             }
#         },
#         {
#             "id": 47441902,
#             "organization_id": "TX424",
#             "url": "https://www.petfinder.com/dog/a550797-47441902/tx/houston/harris-county-pets-tx424/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Labrador Retriever",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Male",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A550797",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:57+0000",
#             "published_at": "2020-02-22T01:18:57+0000",
#             "distance": null,
#             "contact": {
#                 "email": "webmaster@countypets.com",
#                 "phone": "(281) 999-3191",
#                 "address": {
#                     "address1": "612 Canino Rd",
#                     "address2": null,
#                     "city": "Houston",
#                     "state": "TX",
#                     "postcode": "77076",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441902"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx424"
#                 }
#             }
#         },
#         {
#             "id": 47441903,
#             "organization_id": "TX424",
#             "url": "https://www.petfinder.com/dog/a550795-47441903/tx/houston/harris-county-pets-tx424/?referrer_id=96f6bcc2-4d0b-4971-9351-30a7a4f94a88",
#             "type": "Dog",
#             "species": "Dog",
#             "breeds": {
#                 "primary": "Labrador Retriever",
#                 "secondary": "Mixed Breed",
#                 "mixed": true,
#                 "unknown": false
#             },
#             "colors": {
#                 "primary": null,
#                 "secondary": null,
#                 "tertiary": null
#             },
#             "age": "Baby",
#             "gender": "Female",
#             "size": "Small",
#             "coat": null,
#             "attributes": {
#                 "spayed_neutered": false,
#                 "house_trained": false,
#                 "declawed": null,
#                 "special_needs": false,
#                 "shots_current": false
#             },
#             "environment": {
#                 "children": null,
#                 "dogs": null,
#                 "cats": null
#             },
#             "tags": [],
#             "name": "A550795",
#             "description": null,
#             "photos": [],
#             "status": "adoptable",
#             "status_changed_at": "2020-02-22T01:18:57+0000",
#             "published_at": "2020-02-22T01:18:57+0000",
#             "distance": null,
#             "contact": {
#                 "email": "webmaster@countypets.com",
#                 "phone": "(281) 999-3191",
#                 "address": {
#                     "address1": "612 Canino Rd",
#                     "address2": null,
#                     "city": "Houston",
#                     "state": "TX",
#                     "postcode": "77076",
#                     "country": "US"
#                 }
#             },
#             "_links": {
#                 "self": {
#                     "href": "/v2/animals/47441903"
#                 },
#                 "type": {
#                     "href": "/v2/types/dog"
#                 },
#                 "organization": {
#                     "href": "/v2/organizations/tx424"
#                 }
#             }
#         }
#     ],
#     "pagination": {
#         "count_per_page": 20,
#         "total_count": 8009951,
#         "current_page": 1,
#         "total_pages": 400498,
#         "_links": {
#             "next": {
#                 "href": "/v2/animals?page=2"
#             }
#         }
#     }
# }

# %%
# Extract out list of animal dictionaries (also known as records)
animal_records = response_json['animals']
animal_records

# %%
# Use Pandas to directly convert list of records to DataFrame
animals_df = pd.DataFrame(animal_records)
animals_df

# %%
# API has record limit for each pages and need to loop through multiple pages 
current_page_number = 600
num_pages_to_fetch = 1100
is_first_page = False
all_pet_records = []

print('--- Data Processing Started! ---')

while current_page_number < num_pages_to_fetch:
    # Increment count
    current_page_number += 1
    print(f"Processing batch #{current_page_number}")
    
    # Perform API call
    # Configure headers and search parameters
    headers = {'Authorization': f"Bearer {token_response_json['access_token']}"}
               
    params = {
        # Can add any more search parameters found at: https://www.petfinder.com/developers/v2/docs/#get-animals
        'limit': 100 # default is 20, increased to 100 items per page
    }
    
    # Pull data from petfinder.com API 
    url = f"https://api.petfinder.com/v2/animals?page={current_page_number}"
    response = requests.get(url, headers=headers, params=params)
    response_json = response.json()

    # Print out each API call's 'pagination' dictionary that describes if there is a next page, other info
    print(response_json['pagination'])
    
    # Pull out records and add them to our list (app_pet_records)
    animal_records = response_json['animals']
    all_pet_records += animal_records

print('--- Data Processing Completed! ---')
# Out:
# --- Data Processing Started! ---
# Processing batch #601
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 601, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=600'}, 'next': {'href': '/v2/animals?limit=100&page=602'}}}
# Processing batch #602
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 602, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=601'}, 'next': {'href': '/v2/animals?limit=100&page=603'}}}
# Processing batch #603
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 603, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=602'}, 'next': {'href': '/v2/animals?limit=100&page=604'}}}
# Processing batch #604
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 604, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=603'}, 'next': {'href': '/v2/animals?limit=100&page=605'}}}
# Processing batch #605
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 605, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=604'}, 'next': {'href': '/v2/animals?limit=100&page=606'}}}
# Processing batch #606
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 606, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=605'}, 'next': {'href': '/v2/animals?limit=100&page=607'}}}
# Processing batch #607
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 607, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=606'}, 'next': {'href': '/v2/animals?limit=100&page=608'}}}
# Processing batch #608
# {'count_per_page': 100, 'total_count': 8009951, 'current_page': 608, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=607'}, 'next': {'href': '/v2/animals?limit=100&page=609'}}}
# Processing batch #609
# {'count_per_page': 100, 'total_count': 8009953, 'current_page': 609, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=608'}, 'next': {'href': '/v2/animals?limit=100&page=610'}}}
# Processing batch #610
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 610, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=609'}, 'next': {'href': '/v2/animals?limit=100&page=611'}}}
# Processing batch #611
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 611, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=610'}, 'next': {'href': '/v2/animals?limit=100&page=612'}}}
# Processing batch #612
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 612, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=611'}, 'next': {'href': '/v2/animals?limit=100&page=613'}}}
# Processing batch #613
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 613, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=612'}, 'next': {'href': '/v2/animals?limit=100&page=614'}}}
# Processing batch #614
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 614, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=613'}, 'next': {'href': '/v2/animals?limit=100&page=615'}}}
# Processing batch #615
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 615, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=614'}, 'next': {'href': '/v2/animals?limit=100&page=616'}}}
# Processing batch #616
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 616, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=615'}, 'next': {'href': '/v2/animals?limit=100&page=617'}}}
# Processing batch #617
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 617, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=616'}, 'next': {'href': '/v2/animals?limit=100&page=618'}}}
# Processing batch #618
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 618, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=617'}, 'next': {'href': '/v2/animals?limit=100&page=619'}}}
# Processing batch #619
# {'count_per_page': 100, 'total_count': 8009955, 'current_page': 619, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=618'}, 'next': {'href': '/v2/animals?limit=100&page=620'}}}
# Processing batch #620
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 620, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=619'}, 'next': {'href': '/v2/animals?limit=100&page=621'}}}
# Processing batch #621
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 621, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=620'}, 'next': {'href': '/v2/animals?limit=100&page=622'}}}
# Processing batch #622
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 622, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=621'}, 'next': {'href': '/v2/animals?limit=100&page=623'}}}
# Processing batch #623
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 623, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=622'}, 'next': {'href': '/v2/animals?limit=100&page=624'}}}
# Processing batch #624
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 624, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=623'}, 'next': {'href': '/v2/animals?limit=100&page=625'}}}
# Processing batch #625
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 625, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=624'}, 'next': {'href': '/v2/animals?limit=100&page=626'}}}
# Processing batch #626
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 626, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=625'}, 'next': {'href': '/v2/animals?limit=100&page=627'}}}
# Processing batch #627
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 627, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=626'}, 'next': {'href': '/v2/animals?limit=100&page=628'}}}
# Processing batch #628
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 628, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=627'}, 'next': {'href': '/v2/animals?limit=100&page=629'}}}
# Processing batch #629
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 629, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=628'}, 'next': {'href': '/v2/animals?limit=100&page=630'}}}
# Processing batch #630
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 630, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=629'}, 'next': {'href': '/v2/animals?limit=100&page=631'}}}
# Processing batch #631
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 631, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=630'}, 'next': {'href': '/v2/animals?limit=100&page=632'}}}
# Processing batch #632
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 632, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=631'}, 'next': {'href': '/v2/animals?limit=100&page=633'}}}
# Processing batch #633
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 633, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=632'}, 'next': {'href': '/v2/animals?limit=100&page=634'}}}
# Processing batch #634
# {'count_per_page': 100, 'total_count': 8009958, 'current_page': 634, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=633'}, 'next': {'href': '/v2/animals?limit=100&page=635'}}}
# Processing batch #635
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 635, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=634'}, 'next': {'href': '/v2/animals?limit=100&page=636'}}}
# Processing batch #636
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 636, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=635'}, 'next': {'href': '/v2/animals?limit=100&page=637'}}}
# Processing batch #637
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 637, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=636'}, 'next': {'href': '/v2/animals?limit=100&page=638'}}}
# Processing batch #638
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 638, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=637'}, 'next': {'href': '/v2/animals?limit=100&page=639'}}}
# Processing batch #639
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 639, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=638'}, 'next': {'href': '/v2/animals?limit=100&page=640'}}}
# Processing batch #640
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 640, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=639'}, 'next': {'href': '/v2/animals?limit=100&page=641'}}}
# Processing batch #641
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 641, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=640'}, 'next': {'href': '/v2/animals?limit=100&page=642'}}}
# Processing batch #642
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 642, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=641'}, 'next': {'href': '/v2/animals?limit=100&page=643'}}}
# Processing batch #643
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 643, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=642'}, 'next': {'href': '/v2/animals?limit=100&page=644'}}}
# Processing batch #644
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 644, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=643'}, 'next': {'href': '/v2/animals?limit=100&page=645'}}}
# Processing batch #645
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 645, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=644'}, 'next': {'href': '/v2/animals?limit=100&page=646'}}}
# Processing batch #646
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 646, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=645'}, 'next': {'href': '/v2/animals?limit=100&page=647'}}}
# Processing batch #647
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 647, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=646'}, 'next': {'href': '/v2/animals?limit=100&page=648'}}}
# Processing batch #648
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 648, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=647'}, 'next': {'href': '/v2/animals?limit=100&page=649'}}}
# Processing batch #649
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 649, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=648'}, 'next': {'href': '/v2/animals?limit=100&page=650'}}}
# Processing batch #650
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 650, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=649'}, 'next': {'href': '/v2/animals?limit=100&page=651'}}}
# Processing batch #651
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 651, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=650'}, 'next': {'href': '/v2/animals?limit=100&page=652'}}}
# Processing batch #652
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 652, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=651'}, 'next': {'href': '/v2/animals?limit=100&page=653'}}}
# Processing batch #653
# {'count_per_page': 100, 'total_count': 8009959, 'current_page': 653, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=652'}, 'next': {'href': '/v2/animals?limit=100&page=654'}}}
# Processing batch #654
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 654, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=653'}, 'next': {'href': '/v2/animals?limit=100&page=655'}}}
# Processing batch #655
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 655, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=654'}, 'next': {'href': '/v2/animals?limit=100&page=656'}}}
# Processing batch #656
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 656, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=655'}, 'next': {'href': '/v2/animals?limit=100&page=657'}}}
# Processing batch #657
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 657, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=656'}, 'next': {'href': '/v2/animals?limit=100&page=658'}}}
# Processing batch #658
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 658, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=657'}, 'next': {'href': '/v2/animals?limit=100&page=659'}}}
# Processing batch #659
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 659, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=658'}, 'next': {'href': '/v2/animals?limit=100&page=660'}}}
# Processing batch #660
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 660, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=659'}, 'next': {'href': '/v2/animals?limit=100&page=661'}}}
# Processing batch #661
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 661, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=660'}, 'next': {'href': '/v2/animals?limit=100&page=662'}}}
# Processing batch #662
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 662, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=661'}, 'next': {'href': '/v2/animals?limit=100&page=663'}}}
# Processing batch #663
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 663, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=662'}, 'next': {'href': '/v2/animals?limit=100&page=664'}}}
# Processing batch #664
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 664, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=663'}, 'next': {'href': '/v2/animals?limit=100&page=665'}}}
# Processing batch #665
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 665, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=664'}, 'next': {'href': '/v2/animals?limit=100&page=666'}}}
# Processing batch #666
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 666, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=665'}, 'next': {'href': '/v2/animals?limit=100&page=667'}}}
# Processing batch #667
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 667, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=666'}, 'next': {'href': '/v2/animals?limit=100&page=668'}}}
# Processing batch #668
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 668, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=667'}, 'next': {'href': '/v2/animals?limit=100&page=669'}}}
# Processing batch #669
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 669, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=668'}, 'next': {'href': '/v2/animals?limit=100&page=670'}}}
# Processing batch #670
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 670, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=669'}, 'next': {'href': '/v2/animals?limit=100&page=671'}}}
# Processing batch #671
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 671, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=670'}, 'next': {'href': '/v2/animals?limit=100&page=672'}}}
# Processing batch #672
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 672, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=671'}, 'next': {'href': '/v2/animals?limit=100&page=673'}}}
# Processing batch #673
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 673, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=672'}, 'next': {'href': '/v2/animals?limit=100&page=674'}}}
# Processing batch #674
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 674, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=673'}, 'next': {'href': '/v2/animals?limit=100&page=675'}}}
# Processing batch #675
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 675, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=674'}, 'next': {'href': '/v2/animals?limit=100&page=676'}}}
# Processing batch #676
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 676, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=675'}, 'next': {'href': '/v2/animals?limit=100&page=677'}}}
# Processing batch #677
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 677, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=676'}, 'next': {'href': '/v2/animals?limit=100&page=678'}}}
# Processing batch #678
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 678, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=677'}, 'next': {'href': '/v2/animals?limit=100&page=679'}}}
# Processing batch #679
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 679, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=678'}, 'next': {'href': '/v2/animals?limit=100&page=680'}}}
# Processing batch #680
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 680, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=679'}, 'next': {'href': '/v2/animals?limit=100&page=681'}}}
# Processing batch #681
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 681, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=680'}, 'next': {'href': '/v2/animals?limit=100&page=682'}}}
# Processing batch #682
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 682, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=681'}, 'next': {'href': '/v2/animals?limit=100&page=683'}}}
# Processing batch #683
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 683, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=682'}, 'next': {'href': '/v2/animals?limit=100&page=684'}}}
# Processing batch #684
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 684, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=683'}, 'next': {'href': '/v2/animals?limit=100&page=685'}}}
# Processing batch #685
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 685, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=684'}, 'next': {'href': '/v2/animals?limit=100&page=686'}}}
# Processing batch #686
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 686, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=685'}, 'next': {'href': '/v2/animals?limit=100&page=687'}}}
# Processing batch #687
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 687, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=686'}, 'next': {'href': '/v2/animals?limit=100&page=688'}}}
# Processing batch #688
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 688, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=687'}, 'next': {'href': '/v2/animals?limit=100&page=689'}}}
# Processing batch #689
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 689, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=688'}, 'next': {'href': '/v2/animals?limit=100&page=690'}}}
# Processing batch #690
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 690, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=689'}, 'next': {'href': '/v2/animals?limit=100&page=691'}}}
# Processing batch #691
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 691, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=690'}, 'next': {'href': '/v2/animals?limit=100&page=692'}}}
# Processing batch #692
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 692, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=691'}, 'next': {'href': '/v2/animals?limit=100&page=693'}}}
# Processing batch #693
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 693, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=692'}, 'next': {'href': '/v2/animals?limit=100&page=694'}}}
# Processing batch #694
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 694, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=693'}, 'next': {'href': '/v2/animals?limit=100&page=695'}}}
# Processing batch #695
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 695, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=694'}, 'next': {'href': '/v2/animals?limit=100&page=696'}}}
# Processing batch #696
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 696, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=695'}, 'next': {'href': '/v2/animals?limit=100&page=697'}}}
# Processing batch #697
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 697, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=696'}, 'next': {'href': '/v2/animals?limit=100&page=698'}}}
# Processing batch #698
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 698, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=697'}, 'next': {'href': '/v2/animals?limit=100&page=699'}}}
# Processing batch #699
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 699, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=698'}, 'next': {'href': '/v2/animals?limit=100&page=700'}}}
# Processing batch #700
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 700, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=699'}, 'next': {'href': '/v2/animals?limit=100&page=701'}}}
# Processing batch #701
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 701, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=700'}, 'next': {'href': '/v2/animals?limit=100&page=702'}}}
# Processing batch #702
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 702, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=701'}, 'next': {'href': '/v2/animals?limit=100&page=703'}}}
# Processing batch #703
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 703, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=702'}, 'next': {'href': '/v2/animals?limit=100&page=704'}}}
# Processing batch #704
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 704, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=703'}, 'next': {'href': '/v2/animals?limit=100&page=705'}}}
# Processing batch #705
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 705, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=704'}, 'next': {'href': '/v2/animals?limit=100&page=706'}}}
# Processing batch #706
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 706, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=705'}, 'next': {'href': '/v2/animals?limit=100&page=707'}}}
# Processing batch #707
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 707, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=706'}, 'next': {'href': '/v2/animals?limit=100&page=708'}}}
# Processing batch #708
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 708, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=707'}, 'next': {'href': '/v2/animals?limit=100&page=709'}}}
# Processing batch #709
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 709, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=708'}, 'next': {'href': '/v2/animals?limit=100&page=710'}}}
# Processing batch #710
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 710, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=709'}, 'next': {'href': '/v2/animals?limit=100&page=711'}}}
# Processing batch #711
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 711, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=710'}, 'next': {'href': '/v2/animals?limit=100&page=712'}}}
# Processing batch #712
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 712, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=711'}, 'next': {'href': '/v2/animals?limit=100&page=713'}}}
# Processing batch #713
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 713, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=712'}, 'next': {'href': '/v2/animals?limit=100&page=714'}}}
# Processing batch #714
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 714, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=713'}, 'next': {'href': '/v2/animals?limit=100&page=715'}}}
# Processing batch #715
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 715, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=714'}, 'next': {'href': '/v2/animals?limit=100&page=716'}}}
# Processing batch #716
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 716, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=715'}, 'next': {'href': '/v2/animals?limit=100&page=717'}}}
# Processing batch #717
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 717, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=716'}, 'next': {'href': '/v2/animals?limit=100&page=718'}}}
# Processing batch #718
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 718, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=717'}, 'next': {'href': '/v2/animals?limit=100&page=719'}}}
# Processing batch #719
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 719, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=718'}, 'next': {'href': '/v2/animals?limit=100&page=720'}}}
# Processing batch #720
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 720, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=719'}, 'next': {'href': '/v2/animals?limit=100&page=721'}}}
# Processing batch #721
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 721, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=720'}, 'next': {'href': '/v2/animals?limit=100&page=722'}}}
# Processing batch #722
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 722, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=721'}, 'next': {'href': '/v2/animals?limit=100&page=723'}}}
# Processing batch #723
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 723, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=722'}, 'next': {'href': '/v2/animals?limit=100&page=724'}}}
# Processing batch #724
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 724, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=723'}, 'next': {'href': '/v2/animals?limit=100&page=725'}}}
# Processing batch #725
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 725, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=724'}, 'next': {'href': '/v2/animals?limit=100&page=726'}}}
# Processing batch #726
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 726, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=725'}, 'next': {'href': '/v2/animals?limit=100&page=727'}}}
# Processing batch #727
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 727, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=726'}, 'next': {'href': '/v2/animals?limit=100&page=728'}}}
# Processing batch #728
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 728, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=727'}, 'next': {'href': '/v2/animals?limit=100&page=729'}}}
# Processing batch #729
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 729, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=728'}, 'next': {'href': '/v2/animals?limit=100&page=730'}}}
# Processing batch #730
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 730, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=729'}, 'next': {'href': '/v2/animals?limit=100&page=731'}}}
# Processing batch #731
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 731, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=730'}, 'next': {'href': '/v2/animals?limit=100&page=732'}}}
# Processing batch #732
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 732, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=731'}, 'next': {'href': '/v2/animals?limit=100&page=733'}}}
# Processing batch #733
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 733, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=732'}, 'next': {'href': '/v2/animals?limit=100&page=734'}}}
# Processing batch #734
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 734, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=733'}, 'next': {'href': '/v2/animals?limit=100&page=735'}}}
# Processing batch #735
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 735, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=734'}, 'next': {'href': '/v2/animals?limit=100&page=736'}}}
# Processing batch #736
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 736, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=735'}, 'next': {'href': '/v2/animals?limit=100&page=737'}}}
# Processing batch #737
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 737, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=736'}, 'next': {'href': '/v2/animals?limit=100&page=738'}}}
# Processing batch #738
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 738, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=737'}, 'next': {'href': '/v2/animals?limit=100&page=739'}}}
# Processing batch #739
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 739, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=738'}, 'next': {'href': '/v2/animals?limit=100&page=740'}}}
# Processing batch #740
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 740, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=739'}, 'next': {'href': '/v2/animals?limit=100&page=741'}}}
# Processing batch #741
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 741, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=740'}, 'next': {'href': '/v2/animals?limit=100&page=742'}}}
# Processing batch #742
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 742, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=741'}, 'next': {'href': '/v2/animals?limit=100&page=743'}}}
# Processing batch #743
# {'count_per_page': 100, 'total_count': 8009962, 'current_page': 743, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=742'}, 'next': {'href': '/v2/animals?limit=100&page=744'}}}
# Processing batch #744
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 744, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=743'}, 'next': {'href': '/v2/animals?limit=100&page=745'}}}
# Processing batch #745
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 745, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=744'}, 'next': {'href': '/v2/animals?limit=100&page=746'}}}
# Processing batch #746
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 746, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=745'}, 'next': {'href': '/v2/animals?limit=100&page=747'}}}
# Processing batch #747
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 747, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=746'}, 'next': {'href': '/v2/animals?limit=100&page=748'}}}
# Processing batch #748
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 748, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=747'}, 'next': {'href': '/v2/animals?limit=100&page=749'}}}
# Processing batch #749
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 749, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=748'}, 'next': {'href': '/v2/animals?limit=100&page=750'}}}
# Processing batch #750
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 750, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=749'}, 'next': {'href': '/v2/animals?limit=100&page=751'}}}
# Processing batch #751
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 751, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=750'}, 'next': {'href': '/v2/animals?limit=100&page=752'}}}
# Processing batch #752
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 752, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=751'}, 'next': {'href': '/v2/animals?limit=100&page=753'}}}
# Processing batch #753
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 753, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=752'}, 'next': {'href': '/v2/animals?limit=100&page=754'}}}
# Processing batch #754
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 754, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=753'}, 'next': {'href': '/v2/animals?limit=100&page=755'}}}
# Processing batch #755
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 755, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=754'}, 'next': {'href': '/v2/animals?limit=100&page=756'}}}
# Processing batch #756
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 756, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=755'}, 'next': {'href': '/v2/animals?limit=100&page=757'}}}
# Processing batch #757
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 757, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=756'}, 'next': {'href': '/v2/animals?limit=100&page=758'}}}
# Processing batch #758
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 758, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=757'}, 'next': {'href': '/v2/animals?limit=100&page=759'}}}
# Processing batch #759
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 759, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=758'}, 'next': {'href': '/v2/animals?limit=100&page=760'}}}
# Processing batch #760
# {'count_per_page': 100, 'total_count': 8009964, 'current_page': 760, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=759'}, 'next': {'href': '/v2/animals?limit=100&page=761'}}}
# Processing batch #761
# {'count_per_page': 100, 'total_count': 8009964, 'current_page': 761, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=760'}, 'next': {'href': '/v2/animals?limit=100&page=762'}}}
# Processing batch #762
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 762, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=761'}, 'next': {'href': '/v2/animals?limit=100&page=763'}}}
# Processing batch #763
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 763, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=762'}, 'next': {'href': '/v2/animals?limit=100&page=764'}}}
# Processing batch #764
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 764, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=763'}, 'next': {'href': '/v2/animals?limit=100&page=765'}}}
# Processing batch #765
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 765, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=764'}, 'next': {'href': '/v2/animals?limit=100&page=766'}}}
# Processing batch #766
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 766, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=765'}, 'next': {'href': '/v2/animals?limit=100&page=767'}}}
# Processing batch #767
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 767, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=766'}, 'next': {'href': '/v2/animals?limit=100&page=768'}}}
# Processing batch #768
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 768, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=767'}, 'next': {'href': '/v2/animals?limit=100&page=769'}}}
# Processing batch #769
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 769, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=768'}, 'next': {'href': '/v2/animals?limit=100&page=770'}}}
# Processing batch #770
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 770, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=769'}, 'next': {'href': '/v2/animals?limit=100&page=771'}}}
# Processing batch #771
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 771, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=770'}, 'next': {'href': '/v2/animals?limit=100&page=772'}}}
# Processing batch #772
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 772, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=771'}, 'next': {'href': '/v2/animals?limit=100&page=773'}}}
# Processing batch #773
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 773, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=772'}, 'next': {'href': '/v2/animals?limit=100&page=774'}}}
# Processing batch #774
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 774, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=773'}, 'next': {'href': '/v2/animals?limit=100&page=775'}}}
# Processing batch #775
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 775, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=774'}, 'next': {'href': '/v2/animals?limit=100&page=776'}}}
# Processing batch #776
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 776, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=775'}, 'next': {'href': '/v2/animals?limit=100&page=777'}}}
# Processing batch #777
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 777, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=776'}, 'next': {'href': '/v2/animals?limit=100&page=778'}}}
# Processing batch #778
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 778, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=777'}, 'next': {'href': '/v2/animals?limit=100&page=779'}}}
# Processing batch #779
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 779, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=778'}, 'next': {'href': '/v2/animals?limit=100&page=780'}}}
# Processing batch #780
# {'count_per_page': 100, 'total_count': 8009965, 'current_page': 780, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=779'}, 'next': {'href': '/v2/animals?limit=100&page=781'}}}
# Processing batch #781
# {'count_per_page': 100, 'total_count': 8009966, 'current_page': 781, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=780'}, 'next': {'href': '/v2/animals?limit=100&page=782'}}}
# Processing batch #782
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 782, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=781'}, 'next': {'href': '/v2/animals?limit=100&page=783'}}}
# Processing batch #783
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 783, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=782'}, 'next': {'href': '/v2/animals?limit=100&page=784'}}}
# Processing batch #784
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 784, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=783'}, 'next': {'href': '/v2/animals?limit=100&page=785'}}}
# Processing batch #785
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 785, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=784'}, 'next': {'href': '/v2/animals?limit=100&page=786'}}}
# Processing batch #786
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 786, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=785'}, 'next': {'href': '/v2/animals?limit=100&page=787'}}}
# Processing batch #787
# {'count_per_page': 100, 'total_count': 8009967, 'current_page': 787, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=786'}, 'next': {'href': '/v2/animals?limit=100&page=788'}}}
# Processing batch #788
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 788, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=787'}, 'next': {'href': '/v2/animals?limit=100&page=789'}}}
# Processing batch #789
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 789, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=788'}, 'next': {'href': '/v2/animals?limit=100&page=790'}}}
# Processing batch #790
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 790, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=789'}, 'next': {'href': '/v2/animals?limit=100&page=791'}}}
# Processing batch #791
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 791, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=790'}, 'next': {'href': '/v2/animals?limit=100&page=792'}}}
# Processing batch #792
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 792, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=791'}, 'next': {'href': '/v2/animals?limit=100&page=793'}}}
# Processing batch #793
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 793, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=792'}, 'next': {'href': '/v2/animals?limit=100&page=794'}}}
# Processing batch #794
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 794, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=793'}, 'next': {'href': '/v2/animals?limit=100&page=795'}}}
# Processing batch #795
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 795, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=794'}, 'next': {'href': '/v2/animals?limit=100&page=796'}}}
# Processing batch #796
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 796, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=795'}, 'next': {'href': '/v2/animals?limit=100&page=797'}}}
# Processing batch #797
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 797, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=796'}, 'next': {'href': '/v2/animals?limit=100&page=798'}}}
# Processing batch #798
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 798, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=797'}, 'next': {'href': '/v2/animals?limit=100&page=799'}}}
# Processing batch #799
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 799, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=798'}, 'next': {'href': '/v2/animals?limit=100&page=800'}}}
# Processing batch #800
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 800, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=799'}, 'next': {'href': '/v2/animals?limit=100&page=801'}}}
# Processing batch #801
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 801, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=800'}, 'next': {'href': '/v2/animals?limit=100&page=802'}}}
# Processing batch #802
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 802, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=801'}, 'next': {'href': '/v2/animals?limit=100&page=803'}}}
# Processing batch #803
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 803, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=802'}, 'next': {'href': '/v2/animals?limit=100&page=804'}}}
# Processing batch #804
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 804, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=803'}, 'next': {'href': '/v2/animals?limit=100&page=805'}}}
# Processing batch #805
# {'count_per_page': 100, 'total_count': 8009968, 'current_page': 805, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=804'}, 'next': {'href': '/v2/animals?limit=100&page=806'}}}
# Processing batch #806
# ...
# Processing batch #1035
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1035, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1034'}, 'next': {'href': '/v2/animals?limit=100&page=1036'}}}
# Processing batch #1036
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1036, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1035'}, 'next': {'href': '/v2/animals?limit=100&page=1037'}}}
# Processing batch #1037
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1037, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1036'}, 'next': {'href': '/v2/animals?limit=100&page=1038'}}}
# Processing batch #1038
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1038, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1037'}, 'next': {'href': '/v2/animals?limit=100&page=1039'}}}
# Processing batch #1039
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1039, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1038'}, 'next': {'href': '/v2/animals?limit=100&page=1040'}}}
# Processing batch #1040
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1040, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1039'}, 'next': {'href': '/v2/animals?limit=100&page=1041'}}}
# Processing batch #1041
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1041, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1040'}, 'next': {'href': '/v2/animals?limit=100&page=1042'}}}
# Processing batch #1042
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1042, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1041'}, 'next': {'href': '/v2/animals?limit=100&page=1043'}}}
# Processing batch #1043
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1043, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1042'}, 'next': {'href': '/v2/animals?limit=100&page=1044'}}}
# Processing batch #1044
# {'count_per_page': 100, 'total_count': 8009960, 'current_page': 1044, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1043'}, 'next': {'href': '/v2/animals?limit=100&page=1045'}}}
# Processing batch #1045
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1045, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1044'}, 'next': {'href': '/v2/animals?limit=100&page=1046'}}}
# Processing batch #1046
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1046, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1045'}, 'next': {'href': '/v2/animals?limit=100&page=1047'}}}
# Processing batch #1047
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1047, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1046'}, 'next': {'href': '/v2/animals?limit=100&page=1048'}}}
# Processing batch #1048
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 1048, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1047'}, 'next': {'href': '/v2/animals?limit=100&page=1049'}}}
# Processing batch #1049
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 1049, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1048'}, 'next': {'href': '/v2/animals?limit=100&page=1050'}}}
# Processing batch #1050
# {'count_per_page': 100, 'total_count': 8009963, 'current_page': 1050, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1049'}, 'next': {'href': '/v2/animals?limit=100&page=1051'}}}
# Processing batch #1051
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1051, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1050'}, 'next': {'href': '/v2/animals?limit=100&page=1052'}}}
# Processing batch #1052
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1052, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1051'}, 'next': {'href': '/v2/animals?limit=100&page=1053'}}}
# Processing batch #1053
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1053, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1052'}, 'next': {'href': '/v2/animals?limit=100&page=1054'}}}
# Processing batch #1054
# {'count_per_page': 100, 'total_count': 8009961, 'current_page': 1054, 'total_pages': 80100, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1053'}, 'next': {'href': '/v2/animals?limit=100&page=1055'}}}
# Processing batch #1055
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1055, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1054'}, 'next': {'href': '/v2/animals?limit=100&page=1056'}}}
# Processing batch #1056
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1056, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1055'}, 'next': {'href': '/v2/animals?limit=100&page=1057'}}}
# Processing batch #1057
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1057, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1056'}, 'next': {'href': '/v2/animals?limit=100&page=1058'}}}
# Processing batch #1058
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1058, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1057'}, 'next': {'href': '/v2/animals?limit=100&page=1059'}}}
# Processing batch #1059
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1059, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1058'}, 'next': {'href': '/v2/animals?limit=100&page=1060'}}}
# Processing batch #1060
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1060, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1059'}, 'next': {'href': '/v2/animals?limit=100&page=1061'}}}
# Processing batch #1061
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1061, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1060'}, 'next': {'href': '/v2/animals?limit=100&page=1062'}}}
# Processing batch #1062
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1062, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1061'}, 'next': {'href': '/v2/animals?limit=100&page=1063'}}}
# Processing batch #1063
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1063, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1062'}, 'next': {'href': '/v2/animals?limit=100&page=1064'}}}
# Processing batch #1064
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1064, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1063'}, 'next': {'href': '/v2/animals?limit=100&page=1065'}}}
# Processing batch #1065
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1065, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1064'}, 'next': {'href': '/v2/animals?limit=100&page=1066'}}}
# Processing batch #1066
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1066, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1065'}, 'next': {'href': '/v2/animals?limit=100&page=1067'}}}
# Processing batch #1067
# {'count_per_page': 100, 'total_count': 8010075, 'current_page': 1067, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1066'}, 'next': {'href': '/v2/animals?limit=100&page=1068'}}}
# Processing batch #1068
# {'count_per_page': 100, 'total_count': 8010074, 'current_page': 1068, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1067'}, 'next': {'href': '/v2/animals?limit=100&page=1069'}}}
# Processing batch #1069
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1069, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1068'}, 'next': {'href': '/v2/animals?limit=100&page=1070'}}}
# Processing batch #1070
# {'count_per_page': 100, 'total_count': 8010073, 'current_page': 1070, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1069'}, 'next': {'href': '/v2/animals?limit=100&page=1071'}}}
# Processing batch #1071
# {'count_per_page': 100, 'total_count': 8010063, 'current_page': 1071, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1070'}, 'next': {'href': '/v2/animals?limit=100&page=1072'}}}
# Processing batch #1072
# {'count_per_page': 100, 'total_count': 8010062, 'current_page': 1072, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1071'}, 'next': {'href': '/v2/animals?limit=100&page=1073'}}}
# Processing batch #1073
# {'count_per_page': 100, 'total_count': 8010059, 'current_page': 1073, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1072'}, 'next': {'href': '/v2/animals?limit=100&page=1074'}}}
# Processing batch #1074
# {'count_per_page': 100, 'total_count': 8010056, 'current_page': 1074, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1073'}, 'next': {'href': '/v2/animals?limit=100&page=1075'}}}
# Processing batch #1075
# {'count_per_page': 100, 'total_count': 8010056, 'current_page': 1075, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1074'}, 'next': {'href': '/v2/animals?limit=100&page=1076'}}}
# Processing batch #1076
# {'count_per_page': 100, 'total_count': 8010052, 'current_page': 1076, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1075'}, 'next': {'href': '/v2/animals?limit=100&page=1077'}}}
# Processing batch #1077
# {'count_per_page': 100, 'total_count': 8010051, 'current_page': 1077, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1076'}, 'next': {'href': '/v2/animals?limit=100&page=1078'}}}
# Processing batch #1078
# {'count_per_page': 100, 'total_count': 8010051, 'current_page': 1078, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1077'}, 'next': {'href': '/v2/animals?limit=100&page=1079'}}}
# Processing batch #1079
# {'count_per_page': 100, 'total_count': 8010051, 'current_page': 1079, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1078'}, 'next': {'href': '/v2/animals?limit=100&page=1080'}}}
# Processing batch #1080
# {'count_per_page': 100, 'total_count': 8010051, 'current_page': 1080, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1079'}, 'next': {'href': '/v2/animals?limit=100&page=1081'}}}
# Processing batch #1081
# {'count_per_page': 100, 'total_count': 8010053, 'current_page': 1081, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1080'}, 'next': {'href': '/v2/animals?limit=100&page=1082'}}}
# Processing batch #1082
# {'count_per_page': 100, 'total_count': 8010053, 'current_page': 1082, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1081'}, 'next': {'href': '/v2/animals?limit=100&page=1083'}}}
# Processing batch #1083
# {'count_per_page': 100, 'total_count': 8010053, 'current_page': 1083, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1082'}, 'next': {'href': '/v2/animals?limit=100&page=1084'}}}
# Processing batch #1084
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1084, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1083'}, 'next': {'href': '/v2/animals?limit=100&page=1085'}}}
# Processing batch #1085
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1085, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1084'}, 'next': {'href': '/v2/animals?limit=100&page=1086'}}}
# Processing batch #1086
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1086, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1085'}, 'next': {'href': '/v2/animals?limit=100&page=1087'}}}
# Processing batch #1087
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1087, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1086'}, 'next': {'href': '/v2/animals?limit=100&page=1088'}}}
# Processing batch #1088
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1088, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1087'}, 'next': {'href': '/v2/animals?limit=100&page=1089'}}}
# Processing batch #1089
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1089, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1088'}, 'next': {'href': '/v2/animals?limit=100&page=1090'}}}
# Processing batch #1090
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1090, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1089'}, 'next': {'href': '/v2/animals?limit=100&page=1091'}}}
# Processing batch #1091
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1091, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1090'}, 'next': {'href': '/v2/animals?limit=100&page=1092'}}}
# Processing batch #1092
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1092, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1091'}, 'next': {'href': '/v2/animals?limit=100&page=1093'}}}
# Processing batch #1093
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1093, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1092'}, 'next': {'href': '/v2/animals?limit=100&page=1094'}}}
# Processing batch #1094
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1094, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1093'}, 'next': {'href': '/v2/animals?limit=100&page=1095'}}}
# Processing batch #1095
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1095, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1094'}, 'next': {'href': '/v2/animals?limit=100&page=1096'}}}
# Processing batch #1096
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1096, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1095'}, 'next': {'href': '/v2/animals?limit=100&page=1097'}}}
# Processing batch #1097
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1097, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1096'}, 'next': {'href': '/v2/animals?limit=100&page=1098'}}}
# Processing batch #1098
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1098, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1097'}, 'next': {'href': '/v2/animals?limit=100&page=1099'}}}
# Processing batch #1099
# {'count_per_page': 100, 'total_count': 8010054, 'current_page': 1099, 'total_pages': 80101, '_links': {'previous': {'href': '/v2/animals?limit=100&page=1098'}, 'next': {'href': '/v2/animals?limit=100&page=1100'}}}
# Processing batch #1100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-30535aaa079a> in <module>
#      27
#      28     # Print out each API call's 'pagination' dictionary that describes if there is a next page, other info
# ---> 29     print(response_json['pagination'])
#      30
#      31     # Pull out records and add them to our list (app_pet_records)
#
# KeyError: 'pagination'

# %%
len(all_pet_records)
# Out:
# 49900

# %%
large_animals_df = pd.DataFrame(all_pet_records)

# Show number of rows/columns
large_animals_df.shape
# Out:
# (49900, 23)

# %%
# Look at first 5 records
large_animals_df.head(5)
# Out:
#          id organization_id  \
# 0  47429065            NY48
# 1  47429067            NY48
# 2  47429066            NY48
# 3  47429068          CA1044
# 4  47429070          CA1044
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/stevie-47429065/...  Dog     Dog
# 1  https://www.petfinder.com/dog/luna-47429067/ny...  Dog     Dog
# 2  https://www.petfinder.com/dog/ella-47429066/ny...  Dog     Dog
# 3  https://www.petfinder.com/dog/mayo-47429068/ca...  Dog     Dog
# 4  https://www.petfinder.com/dog/mustard-47429070...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Boxer', 'secondary': 'Mastiff', '...
# 1  {'primary': 'Pit Bull Terrier', 'secondary': N...
# 2  {'primary': 'Australian Cattle Dog / Blue Heel...
# 3  {'primary': 'Great Dane', 'secondary': 'Mixed ...
# 4  {'primary': 'Great Dane', 'secondary': 'Mixed ...
#
#                                               colors   age  gender   size  \
# 0  {'primary': None, 'secondary': None, 'tertiary...  Baby  Female  Small
# 1  {'primary': None, 'secondary': None, 'tertiary...  Baby  Female  Small
# 2  {'primary': None, 'secondary': None, 'tertiary...  Baby  Female  Small
# 3  {'primary': None, 'secondary': None, 'tertiary...  Baby  Female  Small
# 4  {'primary': None, 'secondary': None, 'tertiary...  Baby    Male  Small
#
#    ... tags     name                                        description  \
# 0  ...   []   STEVIE  Meet Stevie! This adorable purebred Boxer pupp...
# 1  ...   []     LUNA  Luna is an adorable Pit Bull / Jack Russell Te...
# 2  ...   []     ELLA  Meet Ella! This sweet puppy came to SASF from ...
# 3  ...   []     MAYO  Mayo and Mustard are large breed rescue mutts ...
# 4  ...   []  MUSTARD  Mayo and Mustard are large breed rescue mutts ...
#
#                                               photos     status  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 1  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 2  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 3  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
# 4  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  adoptable
#
#           status_changed_at              published_at distance  \
# 0  2020-02-20T19:15:03+0000  2020-02-20T19:15:03+0000     None
# 1  2020-02-20T19:15:03+0000  2020-02-20T19:15:03+0000     None
# 2  2020-02-20T19:15:03+0000  2020-02-20T19:15:03+0000     None
# 3  2020-02-20T19:15:03+0000  2020-02-20T19:15:03+0000     None
# 4  2020-02-20T19:15:03+0000  2020-02-20T19:15:03+0000     None
#
#                                              contact  \
# 0  {'email': 'adoptions@sasfinc.org', 'phone': '(...
# 1  {'email': 'adoptions@sasfinc.org', 'phone': '(...
# 2  {'email': 'adoptions@sasfinc.org', 'phone': '(...
# 3  {'email': 'infopa@petsinneed.org', 'phone': '(...
# 4  {'email': 'infopa@petsinneed.org', 'phone': '(...
#
#                                               _links
# 0  {'self': {'href': '/v2/animals/47429065'}, 'ty...
# 1  {'self': {'href': '/v2/animals/47429067'}, 'ty...
# 2  {'self': {'href': '/v2/animals/47429066'}, 'ty...
# 3  {'self': {'href': '/v2/animals/47429068'}, 'ty...
# 4  {'self': {'href': '/v2/animals/47429070'}, 'ty...
#
# [5 rows x 23 columns]

# %%
list(large_animals_df.columns)

# %%
# Export data frame to csv file
large_animals_df.to_csv('petfinder_data_21Feb2020_2.csv', encoding='utf-8', index=False)

# %%
# Perform data cleaning by filtering and keeping necessary column only
petfinder_adoption_df = large_animals_df.loc[:, ["id",
                                             "organization_id",
                                             "url",
                                             "type",
                                             "breeds",
                                             "colors",
                                             "age",
                                             "gender",
                                             "name",
                                             "status",
                                             "contact",
                                             "_links"]]

petfinder_adoption_df.head()
# Out:
#          id organization_id  \
# 0  47423986           PA753
# 1  47432926           MO669
# 2  47432970           IL244
# 3  47432973          NY1334
# 4  47432974          NY1334
#
#                                                  url type  \
# 0  https://www.petfinder.com/dog/james-47423986/p...  Dog
# 1  https://www.petfinder.com/dog/mouser-47432926/...  Dog
# 2  https://www.petfinder.com/dog/louise-47432970/...  Dog
# 3  https://www.petfinder.com/dog/archie-47432973/...  Dog
# 4  https://www.petfinder.com/dog/veronica-4743297...  Dog
#
#                                               breeds  \
# 0  {'primary': 'Labrador Retriever', 'secondary':...
# 1  {'primary': 'Jack Russell Terrier', 'secondary...
# 2  {'primary': 'Pit Bull Terrier', 'secondary': N...
# 3  {'primary': 'Terrier', 'secondary': None, 'mix...
# 4  {'primary': 'Terrier', 'secondary': None, 'mix...
#
#                                               colors    age  gender      name  \
# 0  {'primary': 'Yellow / Tan / Blond / Fawn', 'se...   Baby    Male    James.
# 1  {'primary': None, 'secondary': None, 'tertiary...  Young    Male    Mouser
# 2  {'primary': 'Black', 'secondary': None, 'terti...   Baby  Female    Louise
# 3  {'primary': 'Brindle', 'secondary': None, 'ter...   Baby    Male    Archie
# 4  {'primary': 'Bicolor', 'secondary': None, 'ter...   Baby  Female  Veronica
#
#       status                                            contact  \
# 0  adoptable  {'email': 'hopeforhannahrescue@gmail.com', 'ph...
# 1  adoptable  {'email': 'kristen@allcrittercare.com', 'phone...
# 2  adoptable  {'email': 'info@RoverRescue.org', 'phone': '(6...
# 3  adoptable  {'email': 'happylifeanimalrescue@gmail.com', '...
# 4  adoptable  {'email': 'happylifeanimalrescue@gmail.com', '...
#
#                                               _links
# 0  {'self': {'href': '/v2/animals/47423986'}, 'ty...
# 1  {'self': {'href': '/v2/animals/47432926'}, 'ty...
# 2  {'self': {'href': '/v2/animals/47432970'}, 'ty...
# 3  {'self': {'href': '/v2/animals/47432973'}, 'ty...
# 4  {'self': {'href': '/v2/animals/47432974'}, 'ty...

# %%
petfinder_breeds = []

for i in range(len(all_pet_records)):
    petfinder_breeds.append(petfinder_adoption_df['breeds'][i]['primary'])
    
petfinder_breeds
# Out:
# ['Labrador Retriever',
#  'Jack Russell Terrier',
#  'Pit Bull Terrier',
#  'Terrier',
#  'Terrier',
#  'Terrier',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Terrier',
#  'Dachshund',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Miniature Pinscher',
#  'Chihuahua',
#  'Guinea Pig',
#  'Labrador Retriever',
#  'Boxer',
#  'Guinea Pig',
#  'Guinea Pig',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Hound',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'American Bobtail',
#  'Tabby',
#  'Tabby',
#  'Domestic Long Hair',
#  'Tabby',
#  'Tabby',
#  'Tabby',
#  'Calico',
#  'Spaniel',
#  'Australian Shepherd',
#  'Boxer',
#  'Great Pyrenees',
#  'Mastiff',
#  'Schnauzer',
#  'Domestic Short Hair',
#  'Husky',
#  'German Shepherd Dog',
#  'Lhasa Apso',
#  'Domestic Long Hair',
#  'Terrier',
#  'Labrador Retriever',
#  'Whippet',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Corgi',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Pointer',
#  'Domestic Short Hair',
#  'Norwich Terrier',
#  'Chihuahua',
#  'Treeing Walker Coonhound',
#  'Domestic Short Hair',
#  'Maltese',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Tuxedo',
#  'Domestic Medium Hair',
#  'Chihuahua',
#  'Saint Bernard',
#  'Poodle',
#  'Bull Terrier',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Golden Retriever',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'West Highland White Terrier / Westie',
#  'Beagle',
#  'Husky',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Tabby',
#  'Domestic Short Hair',
#  'American Shorthair',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Siamese',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Terrier',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Australian Shepherd',
#  'Wirehaired Terrier',
#  'German Shepherd Dog',
#  'Ragdoll',
#  'Labrador Retriever',
#  'Shepherd',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Calico',
#  'Australian Cattle Dog / Blue Heeler',
#  'Pit Bull Terrier',
#  'German Shepherd Dog',
#  'Hound',
#  'Hound',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Cattle Dog',
#  'Hound',
#  'Domestic Short Hair',
#  'Terrier',
#  'Pit Bull Terrier',
#  'Nova Scotia Duck Tolling Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Hound',
#  'Hound',
#  'Mixed Breed',
#  'Husky',
#  'Beagle',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Siberian Husky',
#  'Bernese Mountain Dog',
#  'Chihuahua',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Shepherd',
#  'German Shepherd Dog',
#  'Labrador Retriever',
#  'Domestic Long Hair',
#  'Labrador Retriever',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Domestic Long Hair',
#  'Siamese',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'German Shepherd Dog',
#  'Calico',
#  'Beagle',
#  'Pit Bull Terrier',
#  'Terrier',
#  'Chihuahua',
#  'Domestic Medium Hair',
#  'Boxer',
#  'Labrador Retriever',
#  'Russian Blue',
#  'Shepherd',
#  'Pit Bull Terrier',
#  'Boxer',
#  'Miniature Poodle',
#  'Labrador Retriever',
#  'Pug',
#  'Shepherd',
#  'Foxhound',
#  'Siberian Husky',
#  'Maltese',
#  'Domestic Short Hair',
#  'Beagle',
#  'Domestic Short Hair',
#  'Boxer',
#  'German Shepherd Dog',
#  'Tabby',
#  'Hound',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Great Pyrenees',
#  'Domestic Short Hair',
#  'Terrier',
#  'Schnauzer',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Blue Lacy',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Saint Bernard',
#  'Jack Russell Terrier',
#  'Saint Bernard',
#  'Chihuahua',
#  'Russian Blue',
#  'Rat',
#  'Chihuahua',
#  'Poodle',
#  'Tiger',
#  'Chihuahua',
#  'Irish Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'English Bulldog',
#  'Labrador Retriever',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Tiger',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Yorkshire Terrier',
#  'Tabby',
#  'Tabby',
#  'Domestic Short Hair',
#  'Jack Russell Terrier',
#  'Lhasa Apso',
#  'Pug',
#  'American Curl',
#  'Pit Bull Terrier',
#  'Scottish Fold',
#  'Bluetick Coonhound',
#  'Mixed Breed',
#  'Labrador Retriever',
#  'Dilute Calico',
#  'Domestic Short Hair',
#  'Corgi',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'American Staffordshire Terrier',
#  'Beagle',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Torbie',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Poodle',
#  'Chow Chow',
#  'Staffordshire Bull Terrier',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Border Collie',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Staffordshire Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Mastiff',
#  'Boxer',
#  'Siberian Husky',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Siberian Husky',
#  'Mixed Breed',
#  'Bunny Rabbit',
#  'Staffordshire Bull Terrier',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Poodle',
#  'German Shepherd Dog',
#  'Siberian Husky',
#  'Pig',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Maltese',
#  'German Shepherd Dog',
#  'Hound',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Catahoula Leopard Dog',
#  'Domestic Short Hair',
#  'Husky',
#  'Tortoiseshell',
#  'Shih Tzu',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Dachshund',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Labrador Retriever',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Cattle Dog',
#  'Dachshund',
#  'Pit Bull Terrier',
#  'Terrier',
#  'Border Collie',
#  'Chihuahua',
#  'Chihuahua',
#  'Chihuahua',
#  'Rottweiler',
#  'Beagle',
#  'Husky',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Golden Retriever',
#  'Affenpinscher',
#  'Shih Tzu',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Lancashire Heeler',
#  'Retriever',
#  'Border Collie',
#  'Shih Tzu',
#  'Labrador Retriever',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Great Pyrenees',
#  'Chihuahua',
#  'Mixed Breed',
#  'Alaskan Malamute',
#  'Chihuahua',
#  'Dachshund',
#  'American Staffordshire Terrier',
#  'Chihuahua',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Miniature Poodle',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Great Dane',
#  'Staffordshire Bull Terrier',
#  'Chihuahua',
#  'Rat Terrier',
#  'Chihuahua',
#  'Terrier',
#  'Border Collie',
#  'Border Collie',
#  'Border Collie',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Great Dane',
#  'Russian Blue',
#  'Domestic Medium Hair',
#  'Siamese',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Long Hair',
#  'Hound',
#  'Parson Russell Terrier',
#  'Domestic Short Hair',
#  'Terrier',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Russian Blue',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Domestic Medium Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Dachshund',
#  'Miniature Pinscher',
#  'Chihuahua',
#  'German Shepherd Dog',
#  'Chihuahua',
#  'Chihuahua',
#  'Boxer',
#  'Boxer',
#  'Labrador Retriever',
#  'Poodle',
#  'Shih Tzu',
#  'Eskimo Dog',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Tabby',
#  'Domestic Medium Hair',
#  'Chihuahua',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Australian Cattle Dog / Blue Heeler',
#  'Pit Bull Terrier',
#  'Hound',
#  'Dachshund',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Mixed Breed',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Maine Coon',
#  'Pug',
#  'German Shepherd Dog',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Australian Shepherd',
#  'Tabby',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Whippet',
#  'Mixed Breed',
#  'Doberman Pinscher',
#  'Calico',
#  'Russian Blue',
#  'American Bulldog',
#  'Terrier',
#  'Great Pyrenees',
#  'Dachshund',
#  'Chihuahua',
#  'Rottweiler',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Rottweiler',
#  'Rottweiler',
#  'Labrador Retriever',
#  'Cocker Spaniel',
#  'Beagle',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Mountain Cur',
#  'Labrador Retriever',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Brittany Spaniel',
#  'Labrador Retriever',
#  'Yorkshire Terrier',
#  'Dachshund',
#  'Mixed Breed',
#  'Husky',
#  'Tortoiseshell',
#  'Tabby',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Shepherd',
#  'Terrier',
#  'Russian Blue',
#  'Dachshund',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Dachshund',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Boxer',
#  'American Bully',
#  'Domestic Short Hair',
#  'Tuxedo',
#  'Pit Bull Terrier',
#  'Beagle',
#  'Shepherd',
#  'Domestic Short Hair',
#  'Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Tabby',
#  'Labrador Retriever',
#  'American Bobtail',
#  'Terrier',
#  'Miniature Pinscher',
#  'Australian Shepherd',
#  'Domestic Short Hair',
#  'Great Pyrenees',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Domestic Short Hair',
#  'Great Pyrenees',
#  'Boxer',
#  'Beagle',
#  'Doberman Pinscher',
#  'Labrador Retriever',
#  'Shepherd',
#  'Tabby',
#  'Hound',
#  'Labrador Retriever',
#  'Mixed Breed',
#  'Collie',
#  'Australian Shepherd',
#  'Alaskan Malamute',
#  'Terrier',
#  'Dachshund',
#  'Jack Russell Terrier',
#  'Tabby',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Tabby',
#  'Golden Retriever',
#  'Shih Tzu',
#  'Terrier',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Golden Retriever',
#  'Chihuahua',
#  'Chihuahua',
#  'Tabby',
#  'Pointer',
#  'Domestic Long Hair',
#  'Spaniel',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Terrier',
#  'Doberman Pinscher',
#  'Australian Shepherd',
#  'German Shorthaired Pointer',
#  'German Shepherd Dog',
#  'Terrier',
#  'Border Collie',
#  'Tuxedo',
#  'Dachshund',
#  'Chihuahua',
#  'Treeing Walker Coonhound',
#  'Boxer',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  'Wheaten Terrier',
#  'Labrador Retriever',
#  'Dachshund',
#  'Terrier',
#  'Chihuahua',
#  'American Bully',
#  'Labrador Retriever',
#  'Rottweiler',
#  'Tabby',
#  'Great Pyrenees',
#  'Chihuahua',
#  'Cattle Dog',
#  'German Shepherd Dog',
#  'Chihuahua',
#  'Shepherd',
#  'Black Labrador Retriever',
#  'Hound',
#  'Hound',
#  'Hound',
#  'Chihuahua',
#  'Terrier',
#  'Chihuahua',
#  'Treeing Walker Coonhound',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Goldendoodle',
#  'Terrier',
#  'German Shepherd Dog',
#  'Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Jack Russell Terrier',
#  'Chihuahua',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'French Lop',
#  'Terrier',
#  'German Shepherd Dog',
#  'Dachshund',
#  'Chihuahua',
#  'Torbie',
#  'Chihuahua',
#  'Domestic Long Hair',
#  'Domestic Short Hair',
#  'Siberian Husky',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Mixed Breed',
#  'Holland Lop',
#  'Beagle',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Tabby',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Boxer',
#  'Terrier',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Husky',
#  'German Shepherd Dog',
#  'Chihuahua',
#  'American Staffordshire Terrier',
#  'American Staffordshire Terrier',
#  'Domestic Medium Hair',
#  'Terrier',
#  'Chihuahua',
#  'Black Mouth Cur',
#  'Labrador Retriever',
#  'Pointer',
#  'Labrador Retriever',
#  'American Bulldog',
#  'Mastiff',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Great Pyrenees',
#  'Beagle',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Pit Bull Terrier',
#  'Rottweiler',
#  'German Shepherd Dog',
#  'Chihuahua',
#  'Great Pyrenees',
#  'Rottweiler',
#  'Chihuahua',
#  'Staffordshire Bull Terrier',
#  'Chihuahua',
#  'Chow Chow',
#  'Chihuahua',
#  'German Shepherd Dog',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Beagle',
#  'Pit Bull Terrier',
#  'Carolina Dog',
#  'Great Dane',
#  'Domestic Short Hair',
#  'Bunny Rabbit',
#  'Dutch',
#  'Great Pyrenees',
#  'Terrier',
#  'Domestic Short Hair',
#  'Boxer',
#  'Staffordshire Bull Terrier',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Siberian Husky',
#  'Domestic Short Hair',
#  'Siberian Husky',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Chicken',
#  'Husky',
#  'German Shepherd Dog',
#  'American Staffordshire Terrier',
#  'Labrador Retriever',
#  'German Shepherd Dog',
#  'Anatolian Shepherd',
#  'German Shepherd Dog',
#  'Cairn Terrier',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Jindo',
#  'American Bulldog',
#  'American Bulldog',
#  'American Bulldog',
#  'Australian Shepherd',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'Bunny Rabbit',
#  'German Shepherd Dog',
#  'German Shepherd Dog',
#  'Border Terrier',
#  'Staffordshire Bull Terrier',
#  'Siamese',
#  'Dutch Shepherd',
#  'Shiba Inu',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Labrador Retriever',
#  'Chihuahua',
#  'Australian Cattle Dog / Blue Heeler',
#  'German Shepherd Dog',
#  'Pit Bull Terrier',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Australian Cattle Dog / Blue Heeler',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Boxer',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Long Hair',
#  'Brittany Spaniel',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'German Shepherd Dog',
#  'Pit Bull Terrier',
#  'Cairn Terrier',
#  'Beagle',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Plott Hound',
#  'Labrador Retriever',
#  'Pug',
#  'Shih Tzu',
#  'Poodle',
#  'Domestic Short Hair',
#  'Chihuahua',
#  'Pit Bull Terrier',
#  'German Shepherd Dog',
#  'Cattle Dog',
#  'American Shorthair',
#  'Retriever',
#  'Domestic Short Hair',
#  'Tabby',
#  'Coonhound',
#  'Terrier',
#  'Domestic Short Hair',
#  'Australian Cattle Dog / Blue Heeler',
#  'Newfoundland Dog',
#  'Calico',
#  'Spaniel',
#  'German Shepherd Dog',
#  'Retriever',
#  'Labrador Retriever',
#  'Calico',
#  'Domestic Short Hair',
#  'Retriever',
#  'Black Labrador Retriever',
#  'Australian Cattle Dog / Blue Heeler',
#  'Schnauzer',
#  'Domestic Short Hair',
#  'Bunny Rabbit',
#  'Domestic Medium Hair',
#  'Cattle Dog',
#  'Domestic Medium Hair',
#  'Retriever',
#  'Dachshund',
#  'Pug',
#  'Pug',
#  'Mixed Breed',
#  'Hound',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Domestic Short Hair',
#  'Border Collie',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Border Collie',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Domestic Short Hair',
#  'Border Collie',
#  'Border Collie',
#  'German Shepherd Dog',
#  'Siberian Husky',
#  'Cardigan Welsh Corgi',
#  'Bunny Rabbit',
#  'Bunny Rabbit',
#  'Bunny Rabbit',
#  'Bunny Rabbit',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Medium Hair',
#  'Hound',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'German Shepherd Dog',
#  'Mixed Breed',
#  'German Shepherd Dog',
#  'Border Collie',
#  'Chihuahua',
#  'Hound',
#  'Domestic Short Hair',
#  'Shepherd',
#  'Shepherd',
#  'Border Terrier',
#  'Shepherd',
#  'Australian Cattle Dog / Blue Heeler',
#  'Pointer',
#  'Shepherd',
#  'Schnauzer',
#  'Australian Shepherd',
#  'Jack Russell Terrier',
#  'Tabby',
#  'Domestic Short Hair',
#  'Hound',
#  'Basset Hound',
#  'German Shepherd Dog',
#  'Domestic Short Hair',
#  'Yorkshire Terrier',
#  'Mixed Breed',
#  'Pomeranian',
#  'Poodle',
#  'Jack Russell Terrier',
#  'Domestic Short Hair',
#  'Tabby',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Retriever',
#  'French Bulldog',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Shepherd',
#  'Domestic Short Hair',
#  'Schnauzer',
#  'Tuxedo',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Cocker Spaniel',
#  'Mixed Breed',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Mixed Breed',
#  'Labrador Retriever',
#  'Mixed Breed',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Pit Bull Terrier',
#  'Domestic Medium Hair',
#  'Shepherd',
#  'Guinea Pig',
#  'Guinea Pig',
#  'Terrier',
#  'Black Labrador Retriever',
#  'Terrier',
#  'Pointer',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Tabby',
#  'Domestic Short Hair',
#  'Labrador Retriever',
#  'Labrador Retriever',
#  'Terrier',
#  'Domestic Short Hair',
#  'Domestic Short Hair',
#  'Terrier',
#  'Terrier',
#  'Shepherd',
#  'Pit Bull Terrier',
#  'Chihuahua',
#  ...]

# %%
len(petfinder_breeds)
# Out:
# 2000

# %%
# Export and save json data to json file
with open('petfinder_data_v2.json', 'w') as outfile:
    json.dump(response_json, outfile)

# %%
# Put the json file to dataframe
# json_file = "./petfinder_data_v2.json"
petfinder_data_df = pd.read_json("./petfinder_data_v2.json")
petfinder_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-7f9cf13a10a7> in <module>
#       1 # Put the json file to dataframe
#       2 # json_file = "./petfinder_data_v2.json"
# ----> 3 petfinder_data_df = pd.read_json("./petfinder_data_v2.json")
#       4 petfinder_data_df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     737         obj = None
#     738         if typ == "frame":
# --> 739             obj = FrameParser(json, **kwargs).parse()
#     740
#     741         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     847
#     848         else:
# --> 849             self._parse_no_numpy()
#     850
#     851         if self.obj is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1091         if orient == "columns":
#    1092             self.obj = DataFrame(
# -> 1093                 loads(json, precise_float=self.precise_float), dtype=None
#    1094             )
#    1095         elif orient == "split":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      75     # figure out the index, if necessary
#      76     if index is None:
# ---> 77         index = extract_index(arrays)
#      78     else:
#      79         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     370             if have_dicts:
#     371                 raise ValueError(
# --> 372                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     373                 )
#     374
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %% [markdown]
# ## Web Scraping

# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import time

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL of page to be scraped
# url = "http://dog.rescueme.org/California"
# browser.visit(url)

# %%
# response = requests.get(url)
# print(response.text)

# %%
# soup = BeautifulSoup(response.text, 'html.parser')

# %%
# print(soup.prettify())
# Out:
# {"type":"https://httpstatus.es/429", "status":429, "title":"Rate Limit Exceeded", "detail":"Limit Exceeded"}

# %%
name = []
link = []
breed = []
location = []

for page in range(1, 6):
    url = f"http://dog.rescueme.org/California#all{page}"
#     print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('div', class_="row")
    
    for result in results:
    # Error handling
        try:
            name.append(result.find('span', class_= '_cpn').text)
            link.append(result.a['href'])
            breed.append(result.find('span', class_= '_sbbr').text)
            location.append(result.find('span', class_= '_clo _clom').text)
            
            
            
#             name = result.find('span', class_= '_cpn').text
#             link = result.a['href']
#             breed = result.find('span', class_= '_sbbr').text
#             location = result.find('span', class_= '_clo _clom').text
            
            if (name and link and breed and location):
                print('page:', page, '------------------')
                print(name)
#                 print(link)
#                 print(breed)
#                 print(location)
    
        except Exception as e:
            print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# page: 1 ------------------
# ['Nana']
# page: 1 ------------------
# ['Nana', 'Dan']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell']
# page: 1 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '']
# page: 1 ------------------
# ...
# page: 2 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally', 'BRUNO', 'URGENT - BLACKIE', 'DOGGIE', 'Blue', 'HACHI', 'KODA', 'Kupi', 'Savannah', 'Rocky', 'Champ', 'Bella PUPPY', 'Scrappy SEE Video', 'MAX', 'Groot,Milo Adopt Toget', 'Zander', 'Bravo', 'Autumn', 'Milo', 'Captain', 'Toby', 'Angel', 'Chocomax', 'Macie', 'Max', 'Brianna', 'Oliver', 'Leta', 'Charley', 'URGENT AFTER 2/25', 'LUCKY-URGENT 3/3', 'Grover', 'Naomi', 'Puppy', 'Alice', 'Oreo', 'Cali', 'Copper', '', 'Walker', 'Sheba', 'Max', 'Buddy', 'mack', 'Ned Pepper', 'Sweet tea', 'Tank', 'Midnight', 'Frankie', 'Rhiannon', 'Honey biscuit', 'Roger', 'Velvet / Violet', 'Whiskey a go go', 'Storm', 'Fox', 'Doe', 'Badger', 'Taz', 'Hawk', 'Coon', 'Bear', 'URGENT AFTER 2/25', 'Sonny 4 lbs', 'Henri', 'Bella', 'Buck', 'Cowboy', 'Shadow', 'Max', 'Copper', 'George', 'Kuhio', 'Tank', 'Princess', 'Klaus', 'Bruno', 'Princ Harry', 'Pippa', 'Spencer', 'Frankie', 'Milo', 'Pancho', 'Roxy', 'Ally', 'MADDIE', 'COOPER', 'Arturo', 'Poldi', 'Smalls', 'Mia', 'Zeus', 'URGENT AFTER 2/22', 'Captain & Clifford', 'Henry is a shy Doxie', 'Rocky', 'Benji', 'Phoebe', 'Vladimir', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Sasha', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Chance', 'URGENT AFTER 2/22', 'URGENT AFTER 2/26', 'Georgie', 'Nala', 'URGENT AFTER 2/20', 'Olivia', 'Lilikoi', 'Rocky', 'Minnie', 'Codey and Luna', 'Zully', 'Skye', 'Jack', 'URGENT - HEATH', 'URGENT - LUNA', 'URGENT - RAT TERRIER', 'Mickey', 'URGENT - SANDY', 'Twinkie', 'URGENT - SPIKE', 'Oakley', 'URGENT - ROCKY', 'Pepper', 'Smokey', 'Dillon', 'Chloe', 'Hooey', 'Wrangler', 'Ryder', 'Hazel', 'Dooby', 'Shyloh', '', 'Ollie', 'Grayson', 'Tonka', '', 'Feagan', 'Sariya', 'Sunny', 'Rambo', 'Hera', 'Love Bug', 'Lilith', 'Rocky', 'Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally' ...
# page: 2 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally', 'BRUNO', 'URGENT - BLACKIE', 'DOGGIE', 'Blue', 'HACHI', 'KODA', 'Kupi', 'Savannah', 'Rocky', 'Champ', 'Bella PUPPY', 'Scrappy SEE Video', 'MAX', 'Groot,Milo Adopt Toget', 'Zander', 'Bravo', 'Autumn', 'Milo', 'Captain', 'Toby', 'Angel', 'Chocomax', 'Macie', 'Max', 'Brianna', 'Oliver', 'Leta', 'Charley', 'URGENT AFTER 2/25', 'LUCKY-URGENT 3/3', 'Grover', 'Naomi', 'Puppy', 'Alice', 'Oreo', 'Cali', 'Copper', '', 'Walker', 'Sheba', 'Max', 'Buddy', 'mack', 'Ned Pepper', 'Sweet tea', 'Tank', 'Midnight', 'Frankie', 'Rhiannon', 'Honey biscuit', 'Roger', 'Velvet / Violet', 'Whiskey a go go', 'Storm', 'Fox', 'Doe', 'Badger', 'Taz', 'Hawk', 'Coon', 'Bear', 'URGENT AFTER 2/25', 'Sonny 4 lbs', 'Henri', 'Bella', 'Buck', 'Cowboy', 'Shadow', 'Max', 'Copper', 'George', 'Kuhio', 'Tank', 'Princess', 'Klaus', 'Bruno', 'Princ Harry', 'Pippa', 'Spencer', 'Frankie', 'Milo', 'Pancho', 'Roxy', 'Ally', 'MADDIE', 'COOPER', 'Arturo', 'Poldi', 'Smalls', 'Mia', 'Zeus', 'URGENT AFTER 2/22', 'Captain & Clifford', 'Henry is a shy Doxie', 'Rocky', 'Benji', 'Phoebe', 'Vladimir', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Sasha', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Chance', 'URGENT AFTER 2/22', 'URGENT AFTER 2/26', 'Georgie', 'Nala', 'URGENT AFTER 2/20', 'Olivia', 'Lilikoi', 'Rocky', 'Minnie', 'Codey and Luna', 'Zully', 'Skye', 'Jack', 'URGENT - HEATH', 'URGENT - LUNA', 'URGENT - RAT TERRIER', 'Mickey', 'URGENT - SANDY', 'Twinkie', 'URGENT - SPIKE', 'Oakley', 'URGENT - ROCKY', 'Pepper', 'Smokey', 'Dillon', 'Chloe', 'Hooey', 'Wrangler', 'Ryder', 'Hazel', 'Dooby', 'Shyloh', '', 'Ollie', 'Grayson', 'Tonka', '', 'Feagan', 'Sariya', 'Sunny', 'Rambo', 'Hera', 'Love Bug', 'Lilith', 'Rocky', 'Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally' ...
# page: 2 ------------------
# ['Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally', 'BRUNO', 'URGENT - BLACKIE', 'DOGGIE', 'Blue', 'HACHI', 'KODA', 'Kupi', 'Savannah', 'Rocky', 'Champ', 'Bella PUPPY', 'Scrappy SEE Video', 'MAX', 'Groot,Milo Adopt Toget', 'Zander', 'Bravo', 'Autumn', 'Milo', 'Captain', 'Toby', 'Angel', 'Chocomax', 'Macie', 'Max', 'Brianna', 'Oliver', 'Leta', 'Charley', 'URGENT AFTER 2/25', 'LUCKY-URGENT 3/3', 'Grover', 'Naomi', 'Puppy', 'Alice', 'Oreo', 'Cali', 'Copper', '', 'Walker', 'Sheba', 'Max', 'Buddy', 'mack', 'Ned Pepper', 'Sweet tea', 'Tank', 'Midnight', 'Frankie', 'Rhiannon', 'Honey biscuit', 'Roger', 'Velvet / Violet', 'Whiskey a go go', 'Storm', 'Fox', 'Doe', 'Badger', 'Taz', 'Hawk', 'Coon', 'Bear', 'URGENT AFTER 2/25', 'Sonny 4 lbs', 'Henri', 'Bella', 'Buck', 'Cowboy', 'Shadow', 'Max', 'Copper', 'George', 'Kuhio', 'Tank', 'Princess', 'Klaus', 'Bruno', 'Princ Harry', 'Pippa', 'Spencer', 'Frankie', 'Milo', 'Pancho', 'Roxy', 'Ally', 'MADDIE', 'COOPER', 'Arturo', 'Poldi', 'Smalls', 'Mia', 'Zeus', 'URGENT AFTER 2/22', 'Captain & Clifford', 'Henry is a shy Doxie', 'Rocky', 'Benji', 'Phoebe', 'Vladimir', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Sasha', 'URGENT AFTER 2/21', 'URGENT AFTER 2/21', 'Chance', 'URGENT AFTER 2/22', 'URGENT AFTER 2/26', 'Georgie', 'Nala', 'URGENT AFTER 2/20', 'Olivia', 'Lilikoi', 'Rocky', 'Minnie', 'Codey and Luna', 'Zully', 'Skye', 'Jack', 'URGENT - HEATH', 'URGENT - LUNA', 'URGENT - RAT TERRIER', 'Mickey', 'URGENT - SANDY', 'Twinkie', 'URGENT - SPIKE', 'Oakley', 'URGENT - ROCKY', 'Pepper', 'Smokey', 'Dillon', 'Chloe', 'Hooey', 'Wrangler', 'Ryder', 'Hazel', 'Dooby', 'Shyloh', '', 'Ollie', 'Grayson', 'Tonka', '', 'Feagan', 'Sariya', 'Sunny', 'Rambo', 'Hera', 'Love Bug', 'Lilith', 'Rocky', 'Nana', 'Dan', 'Jellybean', 'Rocky', 'Kobe', 'Puchi', 'Rosie', 'Elizabeth', 'Beverly', 'Gus', 'Duncan', 'Dot', 'Layla', '', 'Skye', 'Enzo', 'Jake', 'Jake', 'Bryce/Raymond', 'Titus', 'POGO', 'Matilda', 'DIESEL OLIVAS', 'Bella', 'Daisy', 'Duncan', 'Stella', 'MIKEY', 'MIA', 'Charlie', 'Smokey', 'Sable', 'URGENT!!! BLACKY', 'URGENT!!! GINGER', 'Noki', 'Barney', 'Dino', 'BamBam', 'Precious', 'Nino', 'URGENT AFTER 2/26', 'URGENT ON 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'URGENT AFTER 2/26', 'Bella', '', 'Theo', 'Fredo', 'Mia', 'Zuzu', '', '', 'Mojo', 'URGENT - SAMMY', 'Jerry', 'Milo', 'River', 'Garth', 'Jackson', 'Logan', 'Reggie', 'Buddy', 'Norbit', 'Cruise', 'Charlie', 'Minnie Mouse', 'Razzle Dazzle', 'Dose Doe', 'Eleven', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT AFTER 2/25', 'URGENT - BETTY', 'URGENT - BELLA', 'URGENT - MAY', 'Yugi', 'URGENT - THIMES', 'Imposter bear', 'URGENT - CHANCE', 'Scruffy', 'URGENT - MAX', 'URGENT - SADIE', 'COOKIE', 'Tex', 'Nico', 'Dottie', 'Mitchell', '', 'Mimi', 'URGENT DANBAR', 'Smokey', 'Hurley', 'Coco', 'Wally' ...
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
name
# Out:
# ['Nana',
#  'Dan',
#  'Jellybean',
#  'Rocky',
#  'Kobe',
#  'Puchi',
#  'Rosie',
#  'Elizabeth',
#  'Beverly',
#  'Gus',
#  'Duncan',
#  'Dot',
#  'Layla',
#  '',
#  'Skye',
#  'Enzo',
#  'Jake',
#  'Jake',
#  'Bryce/Raymond',
#  'Titus',
#  'POGO',
#  'Matilda',
#  'DIESEL OLIVAS',
#  'Bella',
#  'Daisy',
#  'Duncan',
#  'Stella',
#  'MIKEY',
#  'MIA',
#  'Charlie',
#  'Smokey',
#  'Sable',
#  'URGENT!!! BLACKY',
#  'URGENT!!! GINGER',
#  'Noki',
#  'Barney',
#  'Dino',
#  'BamBam',
#  'Precious',
#  'Nino',
#  'URGENT AFTER 2/26',
#  'URGENT ON 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'Bella',
#  '',
#  'Theo',
#  'Fredo',
#  'Mia',
#  'Zuzu',
#  '',
#  '',
#  'Mojo',
#  'URGENT - SAMMY',
#  'Jerry',
#  'Milo',
#  'River',
#  'Garth',
#  'Jackson',
#  'Logan',
#  'Reggie',
#  'Buddy',
#  'Norbit',
#  'Cruise',
#  'Charlie',
#  'Minnie Mouse',
#  'Razzle Dazzle',
#  'Dose Doe',
#  'Eleven',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT - BETTY',
#  'URGENT - BELLA',
#  'URGENT - MAY',
#  'Yugi',
#  'URGENT - THIMES',
#  'Imposter bear',
#  'URGENT - CHANCE',
#  'Scruffy',
#  'URGENT - MAX',
#  'URGENT - SADIE',
#  'COOKIE',
#  'Tex',
#  'Nico',
#  'Dottie',
#  'Mitchell',
#  '',
#  'Mimi',
#  'URGENT DANBAR',
#  'Smokey',
#  'Hurley',
#  'Coco',
#  'Wally',
#  'BRUNO',
#  'URGENT - BLACKIE',
#  'DOGGIE',
#  'Blue',
#  'HACHI',
#  'KODA',
#  'Kupi',
#  'Savannah',
#  'Rocky',
#  'Champ',
#  'Bella PUPPY',
#  'Scrappy SEE Video',
#  'MAX',
#  'Groot,Milo Adopt Toget',
#  'Zander',
#  'Bravo',
#  'Autumn',
#  'Milo',
#  'Captain',
#  'Toby',
#  'Angel',
#  'Chocomax',
#  'Macie',
#  'Max',
#  'Brianna',
#  'Oliver',
#  'Leta',
#  'Charley',
#  'URGENT AFTER 2/25',
#  'LUCKY-URGENT 3/3',
#  'Grover',
#  'Naomi',
#  'Puppy',
#  'Alice',
#  'Oreo',
#  'Cali',
#  'Copper',
#  '',
#  'Walker',
#  'Sheba',
#  'Max',
#  'Buddy',
#  'mack',
#  'Ned Pepper',
#  'Sweet tea',
#  'Tank',
#  'Midnight',
#  'Frankie',
#  'Rhiannon',
#  'Honey biscuit',
#  'Roger',
#  'Velvet / Violet',
#  'Whiskey a go go',
#  'Storm',
#  'Fox',
#  'Doe',
#  'Badger',
#  'Taz',
#  'Hawk',
#  'Coon',
#  'Bear',
#  'URGENT AFTER 2/25',
#  'Sonny 4 lbs',
#  'Henri',
#  'Bella',
#  'Buck',
#  'Cowboy',
#  'Shadow',
#  'Max',
#  'Copper',
#  'George',
#  'Kuhio',
#  'Tank',
#  'Princess',
#  'Klaus',
#  'Bruno',
#  'Princ Harry',
#  'Pippa',
#  'Spencer',
#  'Frankie',
#  'Milo',
#  'Pancho',
#  'Roxy',
#  'Ally',
#  'MADDIE',
#  'COOPER',
#  'Arturo',
#  'Poldi',
#  'Smalls',
#  'Mia',
#  'Zeus',
#  'URGENT AFTER 2/22',
#  'Captain & Clifford',
#  'Henry is a shy Doxie',
#  'Rocky',
#  'Benji',
#  'Phoebe',
#  'Vladimir',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Sasha',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Chance',
#  'URGENT AFTER 2/22',
#  'URGENT AFTER 2/26',
#  'Georgie',
#  'Nala',
#  'URGENT AFTER 2/20',
#  'Olivia',
#  'Lilikoi',
#  'Rocky',
#  'Minnie',
#  'Codey and Luna',
#  'Zully',
#  'Skye',
#  'Jack',
#  'URGENT - HEATH',
#  'URGENT - LUNA',
#  'URGENT - RAT TERRIER',
#  'Mickey',
#  'URGENT - SANDY',
#  'Twinkie',
#  'URGENT - SPIKE',
#  'Oakley',
#  'URGENT - ROCKY',
#  'Pepper',
#  'Smokey',
#  'Dillon',
#  'Chloe',
#  'Hooey',
#  'Wrangler',
#  'Ryder',
#  'Hazel',
#  'Dooby',
#  'Shyloh',
#  '',
#  'Ollie',
#  'Grayson',
#  'Tonka',
#  '',
#  'Feagan',
#  'Sariya',
#  'Sunny',
#  'Rambo',
#  'Hera',
#  'Love Bug',
#  'Lilith',
#  'Rocky',
#  'Nana',
#  'Dan',
#  'Jellybean',
#  'Rocky',
#  'Kobe',
#  'Puchi',
#  'Rosie',
#  'Elizabeth',
#  'Beverly',
#  'Gus',
#  'Duncan',
#  'Dot',
#  'Layla',
#  '',
#  'Skye',
#  'Enzo',
#  'Jake',
#  'Jake',
#  'Bryce/Raymond',
#  'Titus',
#  'POGO',
#  'Matilda',
#  'DIESEL OLIVAS',
#  'Bella',
#  'Daisy',
#  'Duncan',
#  'Stella',
#  'MIKEY',
#  'MIA',
#  'Charlie',
#  'Smokey',
#  'Sable',
#  'URGENT!!! BLACKY',
#  'URGENT!!! GINGER',
#  'Noki',
#  'Barney',
#  'Dino',
#  'BamBam',
#  'Precious',
#  'Nino',
#  'URGENT AFTER 2/26',
#  'URGENT ON 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'Bella',
#  '',
#  'Theo',
#  'Fredo',
#  'Mia',
#  'Zuzu',
#  '',
#  '',
#  'Mojo',
#  'URGENT - SAMMY',
#  'Jerry',
#  'Milo',
#  'River',
#  'Garth',
#  'Jackson',
#  'Logan',
#  'Reggie',
#  'Buddy',
#  'Norbit',
#  'Cruise',
#  'Charlie',
#  'Minnie Mouse',
#  'Razzle Dazzle',
#  'Dose Doe',
#  'Eleven',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT - BETTY',
#  'URGENT - BELLA',
#  'URGENT - MAY',
#  'Yugi',
#  'URGENT - THIMES',
#  'Imposter bear',
#  'URGENT - CHANCE',
#  'Scruffy',
#  'URGENT - MAX',
#  'URGENT - SADIE',
#  'COOKIE',
#  'Tex',
#  'Nico',
#  'Dottie',
#  'Mitchell',
#  '',
#  'Mimi',
#  'URGENT DANBAR',
#  'Smokey',
#  'Hurley',
#  'Coco',
#  'Wally',
#  'BRUNO',
#  'URGENT - BLACKIE',
#  'DOGGIE',
#  'Blue',
#  'HACHI',
#  'KODA',
#  'Kupi',
#  'Savannah',
#  'Rocky',
#  'Champ',
#  'Bella PUPPY',
#  'Scrappy SEE Video',
#  'MAX',
#  'Groot,Milo Adopt Toget',
#  'Zander',
#  'Bravo',
#  'Autumn',
#  'Milo',
#  'Captain',
#  'Toby',
#  'Angel',
#  'Chocomax',
#  'Macie',
#  'Max',
#  'Brianna',
#  'Oliver',
#  'Leta',
#  'Charley',
#  'URGENT AFTER 2/25',
#  'LUCKY-URGENT 3/3',
#  'Grover',
#  'Naomi',
#  'Puppy',
#  'Alice',
#  'Oreo',
#  'Cali',
#  'Copper',
#  '',
#  'Walker',
#  'Sheba',
#  'Max',
#  'Buddy',
#  'mack',
#  'Ned Pepper',
#  'Sweet tea',
#  'Tank',
#  'Midnight',
#  'Frankie',
#  'Rhiannon',
#  'Honey biscuit',
#  'Roger',
#  'Velvet / Violet',
#  'Whiskey a go go',
#  'Storm',
#  'Fox',
#  'Doe',
#  'Badger',
#  'Taz',
#  'Hawk',
#  'Coon',
#  'Bear',
#  'URGENT AFTER 2/25',
#  'Sonny 4 lbs',
#  'Henri',
#  'Bella',
#  'Buck',
#  'Cowboy',
#  'Shadow',
#  'Max',
#  'Copper',
#  'George',
#  'Kuhio',
#  'Tank',
#  'Princess',
#  'Klaus',
#  'Bruno',
#  'Princ Harry',
#  'Pippa',
#  'Spencer',
#  'Frankie',
#  'Milo',
#  'Pancho',
#  'Roxy',
#  'Ally',
#  'MADDIE',
#  'COOPER',
#  'Arturo',
#  'Poldi',
#  'Smalls',
#  'Mia',
#  'Zeus',
#  'URGENT AFTER 2/22',
#  'Captain & Clifford',
#  'Henry is a shy Doxie',
#  'Rocky',
#  'Benji',
#  'Phoebe',
#  'Vladimir',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Sasha',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Chance',
#  'URGENT AFTER 2/22',
#  'URGENT AFTER 2/26',
#  'Georgie',
#  'Nala',
#  'URGENT AFTER 2/20',
#  'Olivia',
#  'Lilikoi',
#  'Rocky',
#  'Minnie',
#  'Codey and Luna',
#  'Zully',
#  'Skye',
#  'Jack',
#  'URGENT - HEATH',
#  'URGENT - LUNA',
#  'URGENT - RAT TERRIER',
#  'Mickey',
#  'URGENT - SANDY',
#  'Twinkie',
#  'URGENT - SPIKE',
#  'Oakley',
#  'URGENT - ROCKY',
#  'Pepper',
#  'Smokey',
#  'Dillon',
#  'Chloe',
#  'Hooey',
#  'Wrangler',
#  'Ryder',
#  'Hazel',
#  'Dooby',
#  'Shyloh',
#  '',
#  'Ollie',
#  'Grayson',
#  'Tonka',
#  '',
#  'Feagan',
#  'Sariya',
#  'Sunny',
#  'Rambo',
#  'Hera',
#  'Love Bug',
#  'Lilith',
#  'Rocky',
#  'Nana',
#  'Dan',
#  'Jellybean',
#  'Rocky',
#  'Kobe',
#  'Puchi',
#  'Rosie',
#  'Elizabeth',
#  'Beverly',
#  'Gus',
#  'Duncan',
#  'Dot',
#  'Layla',
#  '',
#  'Skye',
#  'Enzo',
#  'Jake',
#  'Jake',
#  'Bryce/Raymond',
#  'Titus',
#  'POGO',
#  'Matilda',
#  'DIESEL OLIVAS',
#  'Bella',
#  'Daisy',
#  'Duncan',
#  'Stella',
#  'MIKEY',
#  'MIA',
#  'Charlie',
#  'Smokey',
#  'Sable',
#  'URGENT!!! BLACKY',
#  'URGENT!!! GINGER',
#  'Noki',
#  'Barney',
#  'Dino',
#  'BamBam',
#  'Precious',
#  'Nino',
#  'URGENT AFTER 2/26',
#  'URGENT ON 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'Bella',
#  '',
#  'Theo',
#  'Fredo',
#  'Mia',
#  'Zuzu',
#  '',
#  '',
#  'Mojo',
#  'URGENT - SAMMY',
#  'Jerry',
#  'Milo',
#  'River',
#  'Garth',
#  'Jackson',
#  'Logan',
#  'Reggie',
#  'Buddy',
#  'Norbit',
#  'Cruise',
#  'Charlie',
#  'Minnie Mouse',
#  'Razzle Dazzle',
#  'Dose Doe',
#  'Eleven',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT - BETTY',
#  'URGENT - BELLA',
#  'URGENT - MAY',
#  'Yugi',
#  'URGENT - THIMES',
#  'Imposter bear',
#  'URGENT - CHANCE',
#  'Scruffy',
#  'URGENT - MAX',
#  'URGENT - SADIE',
#  'COOKIE',
#  'Tex',
#  'Nico',
#  'Dottie',
#  'Mitchell',
#  '',
#  'Mimi',
#  'URGENT DANBAR',
#  'Smokey',
#  'Hurley',
#  'Coco',
#  'Wally',
#  'BRUNO',
#  'URGENT - BLACKIE',
#  'DOGGIE',
#  'Blue',
#  'HACHI',
#  'KODA',
#  'Kupi',
#  'Savannah',
#  'Rocky',
#  'Champ',
#  'Bella PUPPY',
#  'Scrappy SEE Video',
#  'MAX',
#  'Groot,Milo Adopt Toget',
#  'Zander',
#  'Bravo',
#  'Autumn',
#  'Milo',
#  'Captain',
#  'Toby',
#  'Angel',
#  'Chocomax',
#  'Macie',
#  'Max',
#  'Brianna',
#  'Oliver',
#  'Leta',
#  'Charley',
#  'URGENT AFTER 2/25',
#  'LUCKY-URGENT 3/3',
#  'Grover',
#  'Naomi',
#  'Puppy',
#  'Alice',
#  'Oreo',
#  'Cali',
#  'Copper',
#  '',
#  'Walker',
#  'Sheba',
#  'Max',
#  'Buddy',
#  'mack',
#  'Ned Pepper',
#  'Sweet tea',
#  'Tank',
#  'Midnight',
#  'Frankie',
#  'Rhiannon',
#  'Honey biscuit',
#  'Roger',
#  'Velvet / Violet',
#  'Whiskey a go go',
#  'Storm',
#  'Fox',
#  'Doe',
#  'Badger',
#  'Taz',
#  'Hawk',
#  'Coon',
#  'Bear',
#  'URGENT AFTER 2/25',
#  'Sonny 4 lbs',
#  'Henri',
#  'Bella',
#  'Buck',
#  'Cowboy',
#  'Shadow',
#  'Max',
#  'Copper',
#  'George',
#  'Kuhio',
#  'Tank',
#  'Princess',
#  'Klaus',
#  'Bruno',
#  'Princ Harry',
#  'Pippa',
#  'Spencer',
#  'Frankie',
#  'Milo',
#  'Pancho',
#  'Roxy',
#  'Ally',
#  'MADDIE',
#  'COOPER',
#  'Arturo',
#  'Poldi',
#  'Smalls',
#  'Mia',
#  'Zeus',
#  'URGENT AFTER 2/22',
#  'Captain & Clifford',
#  'Henry is a shy Doxie',
#  'Rocky',
#  'Benji',
#  'Phoebe',
#  'Vladimir',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Sasha',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Chance',
#  'URGENT AFTER 2/22',
#  'URGENT AFTER 2/26',
#  'Georgie',
#  'Nala',
#  'URGENT AFTER 2/20',
#  'Olivia',
#  'Lilikoi',
#  'Rocky',
#  'Minnie',
#  'Codey and Luna',
#  'Zully',
#  'Skye',
#  'Jack',
#  'URGENT - HEATH',
#  'URGENT - LUNA',
#  'URGENT - RAT TERRIER',
#  'Mickey',
#  'URGENT - SANDY',
#  'Twinkie',
#  'URGENT - SPIKE',
#  'Oakley',
#  'URGENT - ROCKY',
#  'Pepper',
#  'Smokey',
#  'Dillon',
#  'Chloe',
#  'Hooey',
#  'Wrangler',
#  'Ryder',
#  'Hazel',
#  'Dooby',
#  'Shyloh',
#  '',
#  'Ollie',
#  'Grayson',
#  'Tonka',
#  '',
#  'Feagan',
#  'Sariya',
#  'Sunny',
#  'Rambo',
#  'Hera',
#  'Love Bug',
#  'Lilith',
#  'Rocky',
#  'Nana',
#  'Dan',
#  'Jellybean',
#  'Rocky',
#  'Kobe',
#  'Puchi',
#  'Rosie',
#  'Elizabeth',
#  'Beverly',
#  'Gus',
#  'Duncan',
#  'Dot',
#  'Layla',
#  '',
#  'Skye',
#  'Enzo',
#  'Jake',
#  'Jake',
#  'Bryce/Raymond',
#  'Titus',
#  'POGO',
#  'Matilda',
#  'DIESEL OLIVAS',
#  'Bella',
#  'Daisy',
#  'Duncan',
#  'Stella',
#  'MIKEY',
#  'MIA',
#  'Charlie',
#  'Smokey',
#  'Sable',
#  'URGENT!!! BLACKY',
#  'URGENT!!! GINGER',
#  'Noki',
#  'Barney',
#  'Dino',
#  'BamBam',
#  'Precious',
#  'Nino',
#  'URGENT AFTER 2/26',
#  'URGENT ON 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'URGENT AFTER 2/26',
#  'Bella',
#  '',
#  'Theo',
#  'Fredo',
#  'Mia',
#  'Zuzu',
#  '',
#  '',
#  'Mojo',
#  'URGENT - SAMMY',
#  'Jerry',
#  'Milo',
#  'River',
#  'Garth',
#  'Jackson',
#  'Logan',
#  'Reggie',
#  'Buddy',
#  'Norbit',
#  'Cruise',
#  'Charlie',
#  'Minnie Mouse',
#  'Razzle Dazzle',
#  'Dose Doe',
#  'Eleven',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT AFTER 2/25',
#  'URGENT - BETTY',
#  'URGENT - BELLA',
#  'URGENT - MAY',
#  'Yugi',
#  'URGENT - THIMES',
#  'Imposter bear',
#  'URGENT - CHANCE',
#  'Scruffy',
#  'URGENT - MAX',
#  'URGENT - SADIE',
#  'COOKIE',
#  'Tex',
#  'Nico',
#  'Dottie',
#  'Mitchell',
#  '',
#  'Mimi',
#  'URGENT DANBAR',
#  'Smokey',
#  'Hurley',
#  'Coco',
#  'Wally',
#  'BRUNO',
#  'URGENT - BLACKIE',
#  'DOGGIE',
#  'Blue',
#  'HACHI',
#  'KODA',
#  'Kupi',
#  'Savannah',
#  'Rocky',
#  'Champ',
#  'Bella PUPPY',
#  'Scrappy SEE Video',
#  'MAX',
#  'Groot,Milo Adopt Toget',
#  'Zander',
#  'Bravo',
#  'Autumn',
#  'Milo',
#  'Captain',
#  'Toby',
#  'Angel',
#  'Chocomax',
#  'Macie',
#  'Max',
#  'Brianna',
#  'Oliver',
#  'Leta',
#  'Charley',
#  'URGENT AFTER 2/25',
#  'LUCKY-URGENT 3/3',
#  'Grover',
#  'Naomi',
#  'Puppy',
#  'Alice',
#  'Oreo',
#  'Cali',
#  'Copper',
#  '',
#  'Walker',
#  'Sheba',
#  'Max',
#  'Buddy',
#  'mack',
#  'Ned Pepper',
#  'Sweet tea',
#  'Tank',
#  'Midnight',
#  'Frankie',
#  'Rhiannon',
#  'Honey biscuit',
#  'Roger',
#  'Velvet / Violet',
#  'Whiskey a go go',
#  'Storm',
#  'Fox',
#  'Doe',
#  'Badger',
#  'Taz',
#  'Hawk',
#  'Coon',
#  'Bear',
#  'URGENT AFTER 2/25',
#  'Sonny 4 lbs',
#  'Henri',
#  'Bella',
#  'Buck',
#  'Cowboy',
#  'Shadow',
#  'Max',
#  'Copper',
#  'George',
#  'Kuhio',
#  'Tank',
#  'Princess',
#  'Klaus',
#  'Bruno',
#  'Princ Harry',
#  'Pippa',
#  'Spencer',
#  'Frankie',
#  'Milo',
#  'Pancho',
#  'Roxy',
#  'Ally',
#  'MADDIE',
#  'COOPER',
#  'Arturo',
#  'Poldi',
#  'Smalls',
#  'Mia',
#  'Zeus',
#  'URGENT AFTER 2/22',
#  'Captain & Clifford',
#  'Henry is a shy Doxie',
#  'Rocky',
#  'Benji',
#  'Phoebe',
#  'Vladimir',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Sasha',
#  'URGENT AFTER 2/21',
#  'URGENT AFTER 2/21',
#  'Chance',
#  'URGENT AFTER 2/22',
#  'URGENT AFTER 2/26',
#  'Georgie',
#  'Nala',
#  'URGENT AFTER 2/20',
#  'Olivia',
#  'Lilikoi',
#  'Rocky',
#  'Minnie',
#  'Codey and Luna',
#  'Zully',
#  'Skye',
#  'Jack',
#  'URGENT - HEATH',
#  'URGENT - LUNA',
#  'URGENT - RAT TERRIER',
#  'Mickey',
#  'URGENT - SANDY',
#  'Twinkie',
#  'URGENT - SPIKE',
#  'Oakley',
#  'URGENT - ROCKY',
#  'Pepper',
#  'Smokey',
#  'Dillon',
#  'Chloe',
#  'Hooey',
#  'Wrangler',
#  'Ryder',
#  'Hazel',
#  'Dooby',
#  'Shyloh',
#  '',
#  'Ollie',
#  'Grayson',
#  'Tonka',
#  '',
#  'Feagan',
#  'Sariya',
#  'Sunny',
#  'Rambo',
#  'Hera',
#  'Love Bug',
#  'Lilith',
#  'Rocky',
#  ...]

# %%
for x in range(1, 25):
#     html = browser.html
#     soup = BeautifulSoup(html, 'html.parser')
    
    results = soup.find_all('div', class_="row")
    
    for result in results:
    # Error handling
        try:
            name = result.find('span', class_= '_cpn').text
            link = result.a['href']
            breed = result.find('span', class_= '_sbbr').text
            location = result.find('span', class_= '_clo _clom').text
        
            if (name and link and breed and location):
                print('page:', x, '------------------')
                print(name)
                print(link)
                print(breed)
                print(location)
    
        except Exception as e:
            print(e)
        
    browser.click_link_by_partial_text('NEXT')
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# page: 1 ------------------
# Nana
# http://post.rescueme.org/20-02-21-00420
# Chihuahua
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Dan
# http://post.rescueme.org/20-02-21-00413
# Lhasa Apso
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Jellybean
# http://post.rescueme.org/20-02-21-00380
# Dachshund
# Los Angeles County, Woodland Hills, CA
# page: 1 ------------------
# Rocky
# http://post.rescueme.org/20-02-21-00370
# Pit Bull
# Stanislaus County, Oakdale, CA
# page: 1 ------------------
# Kobe
# http://post.rescueme.org/20-02-21-00369
# American Bulldog
# Los Angeles County, Woodland Hills, CA
# page: 1 ------------------
# Puchi
# http://post.rescueme.org/20-02-21-00364
# Chihuahua
# Orange County, Menifee, CA
# page: 1 ------------------
# Rosie
# http://post.rescueme.org/20-02-21-00321
# German Shepherd
# Sonoma County, Santa Rosa, CA
# page: 1 ------------------
# Elizabeth
# http://post.rescueme.org/20-02-21-00316
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Beverly
# http://post.rescueme.org/20-02-21-00313
# Pit Bull
# Riverside County, Downey , CA
# page: 1 ------------------
# Gus
# http://post.rescueme.org/20-02-21-00308
# Pit Bull
# Humboldt County, Arcata, CA
# page: 1 ------------------
# Duncan
# http://post.rescueme.org/20-02-21-00302
# Chihuahua
# Sutter County, Yuba City, CA
# page: 1 ------------------
# Dot
# http://post.rescueme.org/20-02-21-00296
# Catahoula
# San Luis Obispo County, Atascadero, CA
# page: 1 ------------------
# Layla
# http://post.rescueme.org/20-02-21-00295
# Lab
# CA
# page: 1 ------------------
# Skye
# http://post.rescueme.org/20-02-21-00285
# German Shepherd
# San Bernardino County, High Desert/Rancho Cucamonga, CA
# page: 1 ------------------
# Enzo
# http://post.rescueme.org/20-02-21-00282
# German Shepherd
# San Bernardino County, High Desert/Rancho Cucamonga, CA
# page: 1 ------------------
# Jake
# http://post.rescueme.org/20-02-21-00274
# American Bulldog
# Stanislaus County, Oakdale, CA
# page: 1 ------------------
# Jake
# http://post.rescueme.org/20-02-21-00271
# American Bulldog
# Stanislaus County, Oakdale, CA
# page: 1 ------------------
# Bryce/Raymond
# http://post.rescueme.org/20-02-21-00257
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Titus
# http://post.rescueme.org/20-02-21-00251
# Boxer
# Riverside County, Downey , CA
# page: 1 ------------------
# POGO
# http://post.rescueme.org/20-02-21-00238
# Chow Chow
# San Bernardino County, San Bernardino, CA
# page: 1 ------------------
# Matilda
# http://post.rescueme.org/20-02-21-00225
# Pit Bull
# CA
# page: 1 ------------------
# DIESEL OLIVAS
# http://post.rescueme.org/20-02-21-00222
# Pit Bull
# Los Angeles County, whittier, CA
# page: 1 ------------------
# Bella
# http://post.rescueme.org/20-02-21-00195
# Pit Bull
# Los Angeles County, Woodland Hills, CA
# page: 1 ------------------
# Daisy
# http://post.rescueme.org/20-02-20-00546
# Black Mouth Cur
# Los Angeles County, Pasadena, CA
# page: 1 ------------------
# Duncan
# http://post.rescueme.org/20-02-20-00506
# Poodle
# Los Angeles County, Chatsworth, CA
# page: 1 ------------------
# Stella
# http://post.rescueme.org/20-02-20-00504
# Foxhound
# Sacramento County, Sacramento, CA
# page: 1 ------------------
# MIKEY
# http://post.rescueme.org/20-02-20-00490
# Shih Tzu
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# MIA
# http://post.rescueme.org/20-02-20-00487
# Poodle
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Charlie
# http://post.rescueme.org/20-02-20-00457
# Treeing Walker Coonhound
# Kern County, CA
# page: 1 ------------------
# Smokey
# http://post.rescueme.org/20-02-20-00446
# Pit Bull
# Shasta County, REdding, CA
# page: 1 ------------------
# Sable
# http://post.rescueme.org/20-02-20-00434
# Tibetan Mastiff
# Santa Clara County, San Jose, CA
# page: 1 ------------------
# URGENT!!! BLACKY
# http://post.rescueme.org/20-02-20-00431
# German Shepherd
# Riverside County, Norco, CA
# page: 1 ------------------
# URGENT!!! GINGER
# http://post.rescueme.org/20-02-20-00426
# Lab
# Riverside County, Norco, CA
# page: 1 ------------------
# Noki
# http://post.rescueme.org/20-02-20-00396
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Barney
# http://post.rescueme.org/20-02-20-00386
# Great Pyrenees
# Orange County, Orange, CA
# page: 1 ------------------
# Dino
# http://post.rescueme.org/20-02-20-00383
# Great Pyrenees
# Orange County, Orange, CA
# page: 1 ------------------
# BamBam
# http://post.rescueme.org/20-02-20-00377
# Lab
# Orange County, Orange, CA
# page: 1 ------------------
# Precious
# http://post.rescueme.org/20-02-20-00365
# Pit Bull
# Riverside County, Downey , CA
# page: 1 ------------------
# Nino
# http://post.rescueme.org/20-02-20-00360
# Pit Bull
# Riverside County, Downey , CA
# page: 1 ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00333
# Lab
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT ON 2/26
# http://post.rescueme.org/20-02-20-00331
# Petit Basset Griffon Vendeen
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00329
# Chihuahua
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00328
# Silky Terrier
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00327
# Chihuahua
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00326
# American Bulldog
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# Bella
# http://post.rescueme.org/20-02-20-00284
# Pit Bull
# Riverside County, Downey , CA
# page: 1 ------------------
# Theo
# http://post.rescueme.org/20-02-20-00261
# Chihuahua
# Riverside County, Downey , CA
# page: 1 ------------------
# Fredo
# http://post.rescueme.org/20-02-20-00240
# German Shepherd
# Ventura County, Moorpark, CA
# page: 1 ------------------
# Mia
# http://post.rescueme.org/20-02-20-00238
# Belgian Malinois
# Riverside County, Downey , CA
# page: 1 ------------------
# Zuzu
# http://post.rescueme.org/20-02-20-00235
# German Shepherd
# Ventura County, Moorpark, CA
# page: 1 ------------------
# Mojo
# http://post.rescueme.org/20-02-20-00213
# Miniature Pinscher
# Riverside County, Downey , CA
# page: 1 ------------------
# URGENT - SAMMY
# http://post.rescueme.org/20-02-20-00201
# Chihuahua
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Jerry
# http://post.rescueme.org/20-02-20-00190
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Milo
# http://post.rescueme.org/20-02-20-00149
# Pomeranian
# San Bernardino County, Victorville, CA
# page: 1 ------------------
# River
# http://post.rescueme.org/20-02-20-00138
# Lab
# Riverside County, Temecula, CA
# page: 1 ------------------
# Garth
# http://post.rescueme.org/20-02-20-00130
# Lab
# Riverside County, Temecula, CA
# page: 1 ------------------
# Jackson
# http://post.rescueme.org/20-02-20-00122
# Lab
# Riverside County, Temecula, CA
# page: 1 ------------------
# Logan
# http://post.rescueme.org/20-02-20-00098
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Reggie
# http://post.rescueme.org/20-02-20-00086
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Buddy
# http://post.rescueme.org/20-02-20-00021
# Chihuahua
# Contra Costa County, Brentwood, CA
# page: 1 ------------------
# Norbit
# http://post.rescueme.org/20-02-19-00612
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Cruise
# http://post.rescueme.org/20-02-19-00605
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Charlie
# http://post.rescueme.org/20-02-19-00597
# Bichon Frise
# El Dorado County, Cameron Park, CA
# page: 1 ------------------
# Minnie Mouse
# http://post.rescueme.org/20-02-19-00594
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Razzle Dazzle
# http://post.rescueme.org/20-02-19-00591
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Dose Doe
# http://post.rescueme.org/20-02-19-00586
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Eleven
# http://post.rescueme.org/20-02-19-00576
# Lab
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00554
# Pit Bull
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00553
# Jack Russell
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00552
# Chihuahua
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00551
# Pit Bull
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# URGENT - BETTY
# http://post.rescueme.org/20-02-19-00544
# Bullmastiff
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# URGENT - BELLA
# http://post.rescueme.org/20-02-19-00543
# Pit Bull
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# URGENT - MAY
# http://post.rescueme.org/20-02-19-00506
# Australian Cattle Dog
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Yugi
# http://post.rescueme.org/20-02-19-00504
# Chihuahua
# Sacramento County, RNCHO CORDOVA, CA
# page: 1 ------------------
# URGENT - THIMES
# http://post.rescueme.org/20-02-19-00501
# Lab
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Imposter bear
# http://post.rescueme.org/20-02-19-00493
# Chihuahua
# Sacramento County, RNCHO CORDOVA, CA
# page: 1 ------------------
# URGENT - CHANCE
# http://post.rescueme.org/20-02-19-00479
# Lab
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Scruffy
# http://post.rescueme.org/20-02-19-00478
# Chihuahua
# Los Angeles County, Chatsworth, CA
# page: 1 ------------------
# URGENT - MAX
# http://post.rescueme.org/20-02-19-00470
# Australian Cattle Dog
# Pasadena, CA
# page: 1 ------------------
# URGENT - SADIE
# http://post.rescueme.org/20-02-19-00449
# Corgi
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# COOKIE
# http://post.rescueme.org/20-02-19-00438
# Shar-Pei
# Chino Hills, CA
# page: 1 ------------------
# Tex
# http://post.rescueme.org/20-02-19-00420
# Corgi
# Riverside County, Hemet, CA
# page: 1 ------------------
# Nico
# http://post.rescueme.org/20-02-19-00400
# Siberian Husky
# Sonoma County, Santa Rosa, CA
# page: 1 ------------------
# Dottie
# http://post.rescueme.org/20-02-19-00391
# Yorkie
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Mitchell
# http://post.rescueme.org/20-02-19-00384
# Beagle
# Orange County, Orange, CA
# page: 1 ------------------
# Mimi
# http://post.rescueme.org/20-02-19-00333
# Chihuahua
# San Diego County, la mesa, CA
# page: 1 ------------------
# URGENT DANBAR
# http://post.rescueme.org/20-02-19-00313
# Lab
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Smokey
# http://post.rescueme.org/20-02-19-00295
# Pit Bull
# Shasta County, Redding, CA
# page: 1 ------------------
# Hurley
# http://post.rescueme.org/20-02-19-00287
# Australian Cattle Dog
# Placer County, Roseville, CA
# page: 1 ------------------
# Coco
# http://post.rescueme.org/20-02-19-00282
# Poodle
# Los Angeles County, Sherman Oaks, CA
# page: 1 ------------------
# Wally
# http://post.rescueme.org/20-02-19-00258
# Lab
# Orange County, Orange, CA
# page: 1 ------------------
# BRUNO
# http://post.rescueme.org/20-02-19-00196
# Bulldog
# San Diego County, la mesa, CA
# page: 1 ------------------
# URGENT - BLACKIE
# http://post.rescueme.org/20-02-19-00150
# Dachshund
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# DOGGIE
# http://post.rescueme.org/20-02-19-00138
# Chihuahua
# CA
# page: 1 ------------------
# Blue
# http://post.rescueme.org/20-02-19-00129
# Catahoula
# Madera County, Coarsegold, CA
# page: 1 ------------------
# HACHI
# http://post.rescueme.org/20-02-19-00125
# Chihuahua
# CA
# page: 1 ------------------
# KODA
# http://post.rescueme.org/20-02-19-00118
# Norfolk Terrier
# CA
# page: 1 ------------------
# Kupi
# http://post.rescueme.org/20-02-19-00016
# Chihuahua
# Los Angeles County, Chatsworth, CA
# page: 1 ------------------
# Savannah
# http://post.rescueme.org/20-02-19-00004
# Belgian Malinois
# Santa Barbara County, Santa Barabara, CA
# page: 1 ------------------
# Rocky
# http://post.rescueme.org/20-02-18-00522
# Rottweiler
# Van Nuys, CA
# page: 1 ------------------
# Champ
# http://post.rescueme.org/20-02-18-00520
# Pit Bull
# Monterey County, Seaside, CA
# page: 1 ------------------
# Bella PUPPY
# http://post.rescueme.org/20-02-18-00506
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Scrappy SEE Video
# http://post.rescueme.org/20-02-18-00503
# Australian Cattle Dog
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# MAX
# http://post.rescueme.org/20-02-18-00501
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Groot,Milo Adopt Toget
# http://post.rescueme.org/20-02-18-00482
# Dutch Shepherd
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Zander
# http://post.rescueme.org/20-02-18-00467
# American Staffordshire Terrier
# Orange County, San Juan Capistrano, CA
# page: 1 ------------------
# Bravo
# http://post.rescueme.org/20-02-18-00465
# Chihuahua
# Los Angeles County, Chatsworth, CA
# page: 1 ------------------
# Autumn
# http://post.rescueme.org/20-02-18-00454
# German Shepherd
# Los Angeles County, Sierra Madre, CA
# page: 1 ------------------
# Milo
# http://post.rescueme.org/20-02-18-00442
# Jack Russell
# Los Angeles County, Sierra Madre, CA
# page: 1 ------------------
# Captain
# http://post.rescueme.org/20-02-18-00435
# Siberian Husky
# Los Angeles County, Sierra Madre, CA
# page: 1 ------------------
# Toby
# http://post.rescueme.org/20-02-18-00420
# Corgi
# Orange County, Orange, CA
# page: 1 ------------------
# Angel
# http://post.rescueme.org/20-02-18-00408
# German Shepherd
# Los Angeles County, los Angeles, CA
# page: 1 ------------------
# Chocomax
# http://post.rescueme.org/20-02-18-00380
# Lab
# Los Angeles County, los Angeles, CA
# page: 1 ------------------
# Macie
# http://post.rescueme.org/20-02-18-00371
# Yorkie
# San Diego County, San Diego, CA
# page: 1 ------------------
# Max
# http://post.rescueme.org/20-02-18-00360
# German Shepherd
# Los Angeles County, los Angeles, CA
# page: 1 ------------------
# Brianna
# http://post.rescueme.org/20-02-18-00326
# Chihuahua
# Orange County, Orange, CA
# page: 1 ------------------
# Oliver
# http://post.rescueme.org/20-02-18-00309
# Pit Bull
# Los Angeles County, Covina, CA
# page: 1 ------------------
# Leta
# http://post.rescueme.org/20-02-18-00306
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# Charley
# http://post.rescueme.org/20-02-18-00302
# Yorkie
# Orange County, Irvine, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-18-00254
# American Bulldog
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# LUCKY-URGENT 3/3
# http://post.rescueme.org/20-02-18-00253
# Rottweiler
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# Grover
# http://post.rescueme.org/20-02-18-00238
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Naomi
# http://post.rescueme.org/20-02-18-00231
# White Shepherd
# Sacramento County, Sacramento, CA
# page: 1 ------------------
# Puppy
# http://post.rescueme.org/20-02-18-00198
# Pit Bull
# Los Angeles County, Altadena, CA
# page: 1 ------------------
# Alice
# http://post.rescueme.org/20-02-18-00138
# Yorkie
# Riverside County, Lakeview, CA
# page: 1 ------------------
# Oreo
# http://post.rescueme.org/20-02-18-00020
# Cocker Spaniel
# Los Angeles County, Woodlands Hills/Riverside, CA
# page: 1 ------------------
# Cali
# http://post.rescueme.org/20-02-18-00018
# Beagle
# Los Angeles County, Woodlands Hills/Riverside, CA
# page: 1 ------------------
# Copper
# http://post.rescueme.org/20-02-18-00017
# Pit Bull
# Riverside County, Perris, CA
# page: 1 ------------------
# Walker
# http://post.rescueme.org/20-02-18-00014
# Siberian Husky
# Kings County, HANFORD, CA
# page: 1 ------------------
# Sheba
# http://post.rescueme.org/20-02-18-00005
# Mastiff
# Los Angeles County, Whittier, CA
# page: 1 ------------------
# Max
# http://post.rescueme.org/20-02-17-00540
# German Shepherd
# Riverside County, Cherry Valley, CA
# page: 1 ------------------
# Buddy
# http://post.rescueme.org/20-02-17-00534
# Pit Bull
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# mack
# http://post.rescueme.org/20-02-17-00533
# Pit Bull
# Alameda County, newark, CA
# page: 1 ------------------
# Ned Pepper
# http://post.rescueme.org/20-02-17-00532
# Boxer
# San Bernardino County, San Bernardino, CA
# page: 1 ------------------
# Sweet tea
# http://post.rescueme.org/20-02-17-00531
# Yorkie
# San Bernardino County, San Bernardino, CA
# page: 1 ------------------
# Tank
# http://post.rescueme.org/20-02-17-00527
# Pit Bull
# Alameda County, newark, CA
# page: 1 ------------------
# Midnight
# http://post.rescueme.org/20-02-17-00523
# Lab
# Los Angeles County, Downey, CA
# page: 1 ------------------
# Frankie
# http://post.rescueme.org/20-02-17-00520
# Boxer
# Los Angeles County, Downey, CA
# page: 1 ------------------
# Rhiannon
# http://post.rescueme.org/20-02-17-00519
# Siberian Husky
# Los Angeles County, Downey, CA
# page: 1 ------------------
# Honey biscuit
# http://post.rescueme.org/20-02-17-00505
# Yorkie
# San Bernardino County, San Bernardino, CA
# page: 1 ------------------
# Roger
# http://post.rescueme.org/20-02-17-00504
# Pit Bull
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Velvet / Violet
# http://post.rescueme.org/20-02-17-00503
# Maltese
# Los Angeles County, Pico rivera, CA
# page: 1 ------------------
# Whiskey a go go
# http://post.rescueme.org/20-02-17-00502
# Dachshund
# San Bernardino County, San Bernardino, CA
# page: 1 ------------------
# Storm
# http://post.rescueme.org/20-02-17-00492
# German Shepherd
# Riverside County, Corona, CA
# page: 1 ------------------
# Fox
# http://post.rescueme.org/20-02-17-00481
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Doe
# http://post.rescueme.org/20-02-17-00480
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Badger
# http://post.rescueme.org/20-02-17-00479
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Taz
# http://post.rescueme.org/20-02-17-00476
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Hawk
# http://post.rescueme.org/20-02-17-00473
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Coon
# http://post.rescueme.org/20-02-17-00472
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# Bear
# http://post.rescueme.org/20-02-17-00469
# Lab
# Riverside County, Perris, CA
# page: 1 ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-17-00448
# Pit Bull
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# Sonny 4 lbs
# http://post.rescueme.org/20-02-17-00399
# Chihuahua
# Los Angeles County, los angeles, CA
# page: 1 ------------------
# Henri
# http://post.rescueme.org/20-02-17-00385
# American Bulldog
# Orange County, CA
# page: 1 ------------------
# Bella
# http://post.rescueme.org/20-02-17-00382
# Pit Bull
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Buck
# http://post.rescueme.org/20-02-17-00381
# Mastiff
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Cowboy
# http://post.rescueme.org/20-02-17-00379
# Shar-Pei
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Shadow
# http://post.rescueme.org/20-02-17-00374
# Siberian Husky
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Max
# http://post.rescueme.org/20-02-17-00373
# German Shepherd
# Riverside County, Hemet, CA
# page: 1 ------------------
# Copper
# http://post.rescueme.org/20-02-17-00368
# Pit Bull
# Riverside County, Perris, CA
# page: 1 ------------------
# George
# http://post.rescueme.org/20-02-17-00356
# German Shepherd
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
# Kuhio
# http://post.rescueme.org/20-02-17-00344
# Shih Tzu
# El Dorado County, El Dorado Hills, CA
# page: 1 ------------------
# Tank
# http://post.rescueme.org/20-02-17-00316
# Rhodesian Ridgeback
# San Bernardino County, Hesperia, CA
# page: 1 ------------------
# Princess
# http://post.rescueme.org/20-02-17-00305
# Pit Bull
# Los Angeles County, Long beach, CA
# page: 1 ------------------
# Klaus
# http://post.rescueme.org/20-02-17-00293
# Siberian Husky
# Tulare County, Tulare, CA
# page: 1 ------------------
# Bruno
# http://post.rescueme.org/20-02-17-00276
# Pit Bull
# Riverside County, Downey , CA
# page: 1 ------------------
# Princ Harry
# http://post.rescueme.org/20-02-17-00275
# Australian Cattle Dog
# Contra Costa County, Walnut Creek, CA
# page: 1 ------------------
# Pippa
# http://post.rescueme.org/20-02-17-00259
# Chihuahua
# San Joaquin County, Tracy, CA
# page: 1 ------------------
# Spencer
# http://post.rescueme.org/20-02-17-00171
# Belgian Malinois
# Santa Clara County, San Jose, CA
# page: 1 ------------------
# Frankie
# http://post.rescueme.org/20-02-17-00162
# American Bulldog
# Riverside County, Lake Elsinore, CA
# page: 1 ------------------
# Milo
# http://post.rescueme.org/20-02-17-00156
# Chihuahua
# San Bernardino County, Victorville, CA
# page: 1 ------------------
# Pancho
# http://post.rescueme.org/20-02-17-00110
# Boxer
# Riverside County, Downey , CA
# page: 1 ------------------
# Roxy
# http://post.rescueme.org/20-02-17-00076
# Mastiff
# Palmdale, CA
# page: 1 ------------------
# Ally
# http://post.rescueme.org/20-02-17-00039
# Silky Terrier
# San Diego County, Carlsbad, CA
# page: 1 ------------------
# MADDIE
# http://post.rescueme.org/20-02-17-00037
# Australian Cattle Dog
# Sonoma County, Santa Rosa, CA
# page: 1 ------------------
# COOPER
# http://post.rescueme.org/20-02-17-00036
# Australian Cattle Dog
# Sonoma County, Santa Rosa, CA
# page: 1 ------------------
# Arturo
# http://post.rescueme.org/20-02-17-00027
# Chihuahua
# Los Angeles County, Chatsworth, CA
# page: 1 ------------------
# Poldi
# http://post.rescueme.org/20-02-16-00433
# Chihuahua
# San Joaquin County, Tracy, CA
# page: 1 ------------------
# Smalls
# http://post.rescueme.org/20-02-16-00428
# Rottweiler
# Mendocino County, Willits, CA
# page: 1 ------------------
# Mia
# http://post.rescueme.org/20-02-16-00412
# Chihuahua
# Los Angeles County, Santa Clarita, CA
# page: 1 ------------------
# Zeus
# http://post.rescueme.org/20-02-16-00342
# German Shepherd
# Riverside County, Downey , CA
# page: 1 ------------------
# URGENT AFTER 2/22
# http://post.rescueme.org/20-02-16-00338
# Lab
# Riverside County, Moreno Valley, CA
# page: 1 ------------------
# Captain & Clifford
# http://post.rescueme.org/20-02-16-00337
# Chihuahua
# Riverside County, Downey , CA
# page: 1 ------------------
# Henry is a shy Doxie
# http://post.rescueme.org/20-02-16-00329
# Dachshund
# Los Angeles County, Los Angeles, CA
# page: 1 ------------------
#
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Oakley
# http://post.rescueme.org/20-02-16-00010
# Chihuahua
# Orange County, Yorba Linda, CA
# page: 1 ------------------
# URGENT - ROCKY
# http://post.rescueme.org/20-02-16-00009
# Lab
# Los Angeles County, Baldwin Park, CA
# page: 1 ------------------
# Pepper
# http://post.rescueme.org/20-02-16-00005
# German Shepherd
# Orange County, Yorba Linda, CA
# page: 1 ------------------
# Smokey
# http://post.rescueme.org/20-02-15-00296
# Pit Bull
# San Joaquin County, Stockton, CA
# page: 1 ------------------
# Dillon
# http://post.rescueme.org/20-02-15-00228
# Yorkie
# Los Angeles County, Diamond Bar, CA
# page: 1 ------------------
# Chloe
# http://post.rescueme.org/20-02-15-00223
# Pit Bull
# San Joaquin County, Manteca, CA
# page: 1 ------------------
# Hooey
# http://post.rescueme.org/20-02-15-00212
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# page: 1 ------------------
# Wrangler
# http://post.rescueme.org/20-02-15-00211
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# page: 1 ------------------
# Ryder
# http://post.rescueme.org/20-02-15-00207
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# page: 1 ------------------
# Hazel
# http://post.rescueme.org/20-02-15-00185
# Boxer
# Riverside County, Downey , CA
# page: 1 ------------------
# Dooby
# http://post.rescueme.org/20-02-15-00182
# Pomeranian
# Ventura County, Thousand Oaks, CA
# page: 1 ------------------
# Shyloh
# http://post.rescueme.org/20-02-15-00122
# Shih Tzu
# Los Angeles County, Van Nuys, CA
# page: 1 ------------------
# Ollie
# http://post.rescueme.org/20-02-15-00018
# Chihuahua
# San Bernardino County, Loma linda, CA
# page: 1 ------------------
# Grayson
# http://post.rescueme.org/20-02-15-00016
# Yorkie
# San Bernardino County, Loma linda, CA
# page: 1 ------------------
# Tonka
# http://post.rescueme.org/20-02-15-00008
# Pit Bull
# Shasta County, CA
# page: 1 ------------------
# Feagan
# http://post.rescueme.org/20-02-14-00464
# American Staffordshire Terrier
# Los Angeles County, Santa Clarita, CA
# page: 1 ------------------
# Sariya
# http://post.rescueme.org/20-02-14-00423
# Chihuahua
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Sunny
# http://post.rescueme.org/20-02-14-00416
# German Shepherd
# Riverside County, Anza, CA
# page: 1 ------------------
# Rambo
# http://post.rescueme.org/20-02-14-00414
# Chihuahua
# San Bernardino County, Montclair, CA
# page: 1 ------------------
# Hera
# http://post.rescueme.org/20-02-14-00413
# American Bulldog
# San Joaquin County, Tracy, CA
# page: 1 ------------------
# Love Bug
# http://post.rescueme.org/20-02-14-00396
# Shih Tzu
# San Diego County, Spring Valley, CA
# page: 1 ------------------
# Lilith
# http://post.rescueme.org/20-02-14-00356
# Pit Bull
# San Mateo County, Redwood City, CA
# page: 1 ------------------
# Rocky
# http://post.rescueme.org/20-02-14-00337
# American Staffordshire Terrier
# Orange County, Westminster, CA
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      41         try:
# ---> 42             return self._container[index]
#      43         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-23-c30c2a846124> in <module>
#      23             print(e)
#      24
# ---> 25     browser.click_link_by_partial_text('NEXT')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/driver/__init__.py in click_link_by_partial_text(self, partial_text)
#     394         Clicks in a link by partial content of its text.
#     395         """
# --> 396         return self.find_link_by_partial_text(partial_text).first.click()
#     397
#     398     def click_link_by_id(self, id):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in first(self)
#      55             >>> assert element_list[0] == element_list.first
#      56         """
# ---> 57         return self[0]
#      58
#      59     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      44             raise ElementDoesNotExist(
#      45                 u'no elements could be found with {0} "{1}"'.format(
# ---> 46                     self.find_by, self.query
#      47                 )
#      48             )
#
# ElementDoesNotExist: no elements could be found with link by partial text "NEXT"

# %%
results = soup.find_all('div', class_="row")
# print(results)
# names = soup.find_all('span', class_= '_cpn')

for result in results:
    # Error handling
    try:
        name = result.find('span', class_= '_cpn').text
        link = result.a['href']
        breed = result.find('span', class_= '_sbbr').text
        location = result.find('span', class_= '_clo _clom').text
        
        if (name and link and breed and location):
            print('------------------')
            print(name)
            print(link)
            print(breed)
            print(location)
    
    except Exception as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# ------------------
# Duncan
# http://post.rescueme.org/20-02-20-00506
# Poodle
# Los Angeles County, Chatsworth, CA
# ------------------
# Stella
# http://post.rescueme.org/20-02-20-00504
# Foxhound
# Sacramento County, Sacramento, CA
# ------------------
# MIKEY
# http://post.rescueme.org/20-02-20-00490
# Shih Tzu
# Los Angeles County, Los Angeles, CA
# ------------------
# MIA
# http://post.rescueme.org/20-02-20-00487
# Poodle
# Los Angeles County, Los Angeles, CA
# ------------------
# Smokey
# http://post.rescueme.org/20-02-20-00446
# Pit Bull
# Shasta County, REdding, CA
# ------------------
# Sable
# http://post.rescueme.org/20-02-20-00434
# Tibetan Mastiff
# Santa Clara County, San Jose, CA
# ------------------
# URGENT!!! BLACKY
# http://post.rescueme.org/20-02-20-00431
# German Shepherd
# Riverside County, Norco, CA
# ------------------
# URGENT!!! GINGER
# http://post.rescueme.org/20-02-20-00426
# Lab
# Riverside County, Norco, CA
# ------------------
# Noki
# http://post.rescueme.org/20-02-20-00396
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Barney
# http://post.rescueme.org/20-02-20-00386
# Great Pyrenees
# Orange County, Orange, CA
# ------------------
# Dino
# http://post.rescueme.org/20-02-20-00383
# Great Pyrenees
# Orange County, Orange, CA
# ------------------
# BamBam
# http://post.rescueme.org/20-02-20-00377
# Lab
# Orange County, Orange, CA
# ------------------
# Precious
# http://post.rescueme.org/20-02-20-00365
# Pit Bull
# Riverside County, Downey , CA
# ------------------
# Nino
# http://post.rescueme.org/20-02-20-00360
# Pit Bull
# Riverside County, Downey , CA
# ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00333
# Lab
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT ON 2/26
# http://post.rescueme.org/20-02-20-00331
# Petit Basset Griffon Vendeen
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00329
# Chihuahua
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00328
# Silky Terrier
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00327
# Chihuahua
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/26
# http://post.rescueme.org/20-02-20-00326
# American Bulldog
# Riverside County, Moreno Valley, CA
# ------------------
# Bella
# http://post.rescueme.org/20-02-20-00284
# Pit Bull
# Riverside County, Downey , CA
# ------------------
# Theo
# http://post.rescueme.org/20-02-20-00261
# Chihuahua
# Riverside County, Downey , CA
# ------------------
# Fredo
# http://post.rescueme.org/20-02-20-00240
# German Shepherd
# Ventura County, Moorpark, CA
# ------------------
# Mia
# http://post.rescueme.org/20-02-20-00238
# Belgian Malinois
# Riverside County, Downey , CA
# ------------------
# Zuzu
# http://post.rescueme.org/20-02-20-00235
# German Shepherd
# Ventura County, Moorpark, CA
# ------------------
# Mojo
# http://post.rescueme.org/20-02-20-00213
# Miniature Pinscher
# Riverside County, Downey , CA
# ------------------
# URGENT - SAMMY
# http://post.rescueme.org/20-02-20-00201
# Chihuahua
# Los Angeles County, Baldwin Park, CA
# ------------------
# Elizabeth
# http://post.rescueme.org/20-02-20-00196
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Jerry
# http://post.rescueme.org/20-02-20-00190
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Milo
# http://post.rescueme.org/20-02-20-00149
# Pomeranian
# San Bernardino County, Victorville, CA
# ------------------
# River
# http://post.rescueme.org/20-02-20-00138
# Lab
# Riverside County, Temecula, CA
# ------------------
# Garth
# http://post.rescueme.org/20-02-20-00130
# Lab
# Riverside County, Temecula, CA
# ------------------
# Jackson
# http://post.rescueme.org/20-02-20-00122
# Lab
# Riverside County, Temecula, CA
# ------------------
# Logan
# http://post.rescueme.org/20-02-20-00098
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Reggie
# http://post.rescueme.org/20-02-20-00086
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Buddy
# http://post.rescueme.org/20-02-20-00021
# Chihuahua
# Contra Costa County, Brentwood, CA
# ------------------
# Norbit
# http://post.rescueme.org/20-02-19-00612
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# Cruise
# http://post.rescueme.org/20-02-19-00605
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# Charlie
# http://post.rescueme.org/20-02-19-00597
# Bichon Frise
# El Dorado County, Cameron Park, CA
# ------------------
# Minnie Mouse
# http://post.rescueme.org/20-02-19-00594
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# Razzle Dazzle
# http://post.rescueme.org/20-02-19-00591
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# Dose Doe
# http://post.rescueme.org/20-02-19-00586
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# Eleven
# http://post.rescueme.org/20-02-19-00576
# Lab
# San Bernardino County, Montclair, CA
# ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00554
# Pit Bull
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00553
# Jack Russell
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00552
# Chihuahua
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-19-00551
# Pit Bull
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT - BETTY
# http://post.rescueme.org/20-02-19-00544
# Bullmastiff
# Los Angeles County, Baldwin Park, CA
# ------------------
# URGENT - BELLA
# http://post.rescueme.org/20-02-19-00543
# Pit Bull
# Los Angeles County, Baldwin Park, CA
# ------------------
# URGENT - MAY
# http://post.rescueme.org/20-02-19-00506
# Australian Cattle Dog
# Los Angeles County, Baldwin Park, CA
# ------------------
# Yugi
# http://post.rescueme.org/20-02-19-00504
# Chihuahua
# Sacramento County, RNCHO CORDOVA, CA
# ------------------
# URGENT - THIMES
# http://post.rescueme.org/20-02-19-00501
# Lab
# Los Angeles County, Baldwin Park, CA
# ------------------
# Imposter bear
# http://post.rescueme.org/20-02-19-00493
# Chihuahua
# Sacramento County, RNCHO CORDOVA, CA
# ------------------
# URGENT - CHANCE
# http://post.rescueme.org/20-02-19-00479
# Lab
# Los Angeles County, Baldwin Park, CA
# ------------------
# Scruffy
# http://post.rescueme.org/20-02-19-00478
# Chihuahua
# Los Angeles County, Chatsworth, CA
# ------------------
# URGENT - MAX
# http://post.rescueme.org/20-02-19-00470
# Australian Cattle Dog
# Pasadena, CA
# ------------------
# URGENT - SADIE
# http://post.rescueme.org/20-02-19-00449
# Corgi
# Los Angeles County, Baldwin Park, CA
# ------------------
# COOKIE
# http://post.rescueme.org/20-02-19-00438
# Shar-Pei
# Chino Hills, CA
# ------------------
# Tex
# http://post.rescueme.org/20-02-19-00420
# Corgi
# Riverside County, Hemet, CA
# ------------------
# Nico
# http://post.rescueme.org/20-02-19-00400
# Siberian Husky
# Sonoma County, Santa Rosa, CA
# ------------------
# Dottie
# http://post.rescueme.org/20-02-19-00391
# Yorkie
# Los Angeles County, Van Nuys, CA
# ------------------
# Mitchell
# http://post.rescueme.org/20-02-19-00384
# Beagle
# Orange County, Orange, CA
# ------------------
# Mimi
# http://post.rescueme.org/20-02-19-00333
# Chihuahua
# San Diego County, la mesa, CA
# ------------------
# URGENT DANBAR
# http://post.rescueme.org/20-02-19-00313
# Lab
# Los Angeles County, Baldwin Park, CA
# ------------------
# Smokey
# http://post.rescueme.org/20-02-19-00295
# Pit Bull
# Shasta County, Redding, CA
# ------------------
# Hurley
# http://post.rescueme.org/20-02-19-00287
# Australian Cattle Dog
# Placer County, Roseville, CA
# ------------------
# Coco
# http://post.rescueme.org/20-02-19-00282
# Poodle
# Los Angeles County, Sherman Oaks, CA
# ------------------
# Wally
# http://post.rescueme.org/20-02-19-00258
# Lab
# Orange County, Orange, CA
# ------------------
# BRUNO
# http://post.rescueme.org/20-02-19-00196
# Bulldog
# San Diego County, la mesa, CA
# ------------------
# URGENT - BLACKIE
# http://post.rescueme.org/20-02-19-00150
# Dachshund
# Los Angeles County, Baldwin Park, CA
# ------------------
# DOGGIE
# http://post.rescueme.org/20-02-19-00138
# Chihuahua
# CA
# ------------------
# Blue
# http://post.rescueme.org/20-02-19-00129
# Catahoula
# Madera County, Coarsegold, CA
# ------------------
# HACHI
# http://post.rescueme.org/20-02-19-00125
# Chihuahua
# CA
# ------------------
# KODA
# http://post.rescueme.org/20-02-19-00118
# Norfolk Terrier
# CA
# ------------------
# Kupi
# http://post.rescueme.org/20-02-19-00016
# Chihuahua
# Los Angeles County, Chatsworth, CA
# ------------------
# Savannah
# http://post.rescueme.org/20-02-19-00004
# Belgian Malinois
# Santa Barbara County, Santa Barabara, CA
# ------------------
# Rocky
# http://post.rescueme.org/20-02-18-00522
# Rottweiler
# Van Nuys, CA
# ------------------
# Champ
# http://post.rescueme.org/20-02-18-00520
# Pit Bull
# Monterey County, Seaside, CA
# ------------------
# Bella PUPPY
# http://post.rescueme.org/20-02-18-00506
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# ------------------
# Scrappy SEE Video
# http://post.rescueme.org/20-02-18-00503
# Australian Cattle Dog
# Los Angeles County, Van Nuys, CA
# ------------------
# MAX
# http://post.rescueme.org/20-02-18-00501
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# ------------------
# Groot,Milo Adopt Toget
# http://post.rescueme.org/20-02-18-00482
# Dutch Shepherd
# Los Angeles County, Van Nuys, CA
# ------------------
# Zander
# http://post.rescueme.org/20-02-18-00467
# American Staffordshire Terrier
# Orange County, San Juan Capistrano, CA
# ------------------
# Bravo
# http://post.rescueme.org/20-02-18-00465
# Chihuahua
# Los Angeles County, Chatsworth, CA
# ------------------
# Autumn
# http://post.rescueme.org/20-02-18-00454
# German Shepherd
# Los Angeles County, Sierra Madre, CA
# ------------------
# Milo
# http://post.rescueme.org/20-02-18-00442
# Jack Russell
# Los Angeles County, Sierra Madre, CA
# ------------------
# Captain
# http://post.rescueme.org/20-02-18-00435
# Siberian Husky
# Los Angeles County, Sierra Madre, CA
# ------------------
# Toby
# http://post.rescueme.org/20-02-18-00420
# Corgi
# Orange County, Orange, CA
# ------------------
# Angel
# http://post.rescueme.org/20-02-18-00408
# German Shepherd
# Los Angeles County, los Angeles, CA
# ------------------
# Chocomax
# http://post.rescueme.org/20-02-18-00380
# Lab
# Los Angeles County, los Angeles, CA
# ------------------
# Macie
# http://post.rescueme.org/20-02-18-00371
# Yorkie
# San Diego County, San Diego, CA
# ------------------
# Max
# http://post.rescueme.org/20-02-18-00360
# German Shepherd
# Los Angeles County, los Angeles, CA
# ------------------
# Brianna
# http://post.rescueme.org/20-02-18-00326
# Chihuahua
# Orange County, Orange, CA
# ------------------
# Oliver
# http://post.rescueme.org/20-02-18-00309
# Pit Bull
# Los Angeles County, Covina, CA
# ------------------
# Leta
# http://post.rescueme.org/20-02-18-00306
# German Shepherd
# Riverside County, Downey , CA
# ------------------
# Charley
# http://post.rescueme.org/20-02-18-00302
# Yorkie
# Orange County, Irvine, CA
# ------------------
# URGENT AFTER 2/25
# http://post.rescueme.org/20-02-18-00254
# American Bulldog
# Riverside County, Moreno Valley, CA
# ------------------
# LUCKY-URGENT 3/3
# http://post.rescueme.org/20-02-18-00253
# Rottweiler
# Riverside County, Moreno Valley, CA
# ------------------
# Grover
# http://post.rescueme.org/20-02-18-00238
# American Staffordshire Terrier
# Los Angeles County, Van Nuys, CA
# ------------------
# Naomi
# http://post.rescueme.org/20-02-18-00231
# White Shepherd
# Sacramento County, Sacramento, CA
# ------------------
# Puppy
# http://post.rescueme.org/20-02-18-00198
# Pit Bull
# Los Angeles County, Altadena, CA
# ------------------
# Cuddles
# http://post.rescueme.org/20-02-18-00152
# Pomeranian
# Riverside County, Lakeview, CA
# ------------------
# Alice
# http://post.rescueme.org/20-02-18-00138
# Yorkie
# Riverside County, Lakeview, CA
# ------------------
# Oreo
# http://post.rescueme.org/20-02-18-00020
# Cocker Spaniel
# Los Angeles County, Woodlands Hills/Riverside, CA
# ------------------
# Cali
# http://post.rescueme.org/20-02-18-00018
# Beagle
# Los Angeles County, Woodlands Hills/Riverside, CA
# ------------------
# Copper
# http://post.rescueme.org/20-02-18-00017
# Pit Bull
# Riverside County, Perris, CA
# ------------------
# Walker
# http://post.rescueme.org/20-02-18-00014
# Siberian Husky
# Kings County, HANFORD, CA
# ------------------
# Sheba
# http://post.rescueme.org/20-02-18-00005
# Mastiff
# Los Angeles County, Whittier, CA
# ------------------
# Max
# http://post.rescueme.org/20-02-17-00540
# German Shepherd
# Riverside County, Cherry Valley, CA
# ------------------
# Buddy
# http://post.rescueme.org/20-02-17-00534
# Pit Bull
# Los Angeles County, Los Angeles, CA
# ------------------
# mack
# http://post.rescueme.org/20-02-17-00533
# Pit Bull
# ------------------
# Twinkie
# http://post.rescueme.org/20-02-16-00013
# Pomeranian
# Orange County, Yorba Linda, CA
# ------------------
# URGENT - SPIKE
# http://post.rescueme.org/20-02-16-00011
# Chihuahua
# Los Angeles County, Baldwin Park, CA
# ------------------
# Oakley
# http://post.rescueme.org/20-02-16-00010
# Chihuahua
# Orange County, Yorba Linda, CA
# ------------------
# URGENT - ROCKY
# http://post.rescueme.org/20-02-16-00009
# Lab
# Los Angeles County, Baldwin Park, CA
# ------------------
# URGENT - MELVIN
# http://post.rescueme.org/20-02-16-00007
# Siberian Husky
# Los Angeles County, Baldwin Park, CA
# ------------------
# Pepper
# http://post.rescueme.org/20-02-16-00005
# German Shepherd
# Orange County, Yorba Linda, CA
# ------------------
# Smokey
# http://post.rescueme.org/20-02-15-00296
# Pit Bull
# San Joaquin County, Stockton, CA
# ------------------
# Dillon
# http://post.rescueme.org/20-02-15-00228
# Yorkie
# Los Angeles County, Diamond Bar, CA
# ------------------
# Chloe
# http://post.rescueme.org/20-02-15-00223
# Pit Bull
# San Joaquin County, Manteca, CA
# ------------------
# Hooey
# http://post.rescueme.org/20-02-15-00212
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# ------------------
# Wrangler
# http://post.rescueme.org/20-02-15-00211
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# ------------------
# Ryder
# http://post.rescueme.org/20-02-15-00207
# Australian Cattle Dog
# Orange County, Yorba Linda, CA
# ------------------
# Hazel
# http://post.rescueme.org/20-02-15-00185
# Boxer
# Riverside County, Downey , CA
# ------------------
# Dooby
# http://post.rescueme.org/20-02-15-00182
# Pomeranian
# Ventura County, Thousand Oaks, CA
# ------------------
# Titus
# http://post.rescueme.org/20-02-15-00128
# Boxer
# Riverside County, Downey , CA
# ------------------
# Shyloh
# http://post.rescueme.org/20-02-15-00122
# Shih Tzu
# Los Angeles County, Van Nuys, CA
# ------------------
# Ollie
# http://post.rescueme.org/20-02-15-00018
# Chihuahua
# San Bernardino County, Loma linda, CA
# ------------------
# Grayson
# http://post.rescueme.org/20-02-15-00016
# Yorkie
# San Bernardino County, Loma linda, CA
# ------------------
# Tonka
# http://post.rescueme.org/20-02-15-00008
# Pit Bull
# Shasta County, CA
# ------------------
# Feagan
# http://post.rescueme.org/20-02-14-00464
# American Staffordshire Terrier
# Los Angeles County, Santa Clarita, CA
# ------------------
# Sariya
# http://post.rescueme.org/20-02-14-00423
# Chihuahua
# San Bernardino County, Montclair, CA
# ------------------
# Sunny
# http://post.rescueme.org/20-02-14-00416
# German Shepherd
# Riverside County, Anza, CA
# ------------------
# Rambo
# http://post.rescueme.org/20-02-14-00414
# Chihuahua
# San Bernardino County, Montclair, CA
# ------------------
# Hera
# http://post.rescueme.org/20-02-14-00413
# American Bulldog
# San Joaquin County, Tracy, CA
# ------------------
# Love Bug
# http://post.rescueme.org/20-02-14-00396
# Shih Tzu
# San Diego County, Spring Valley, CA
# ------------------
# Lilith
# http://post.rescueme.org/20-02-14-00356
# Pit Bull
# San Mateo County, Redwood City, CA
# ------------------
# Rocky
# http://post.rescueme.org/20-02-14-00337
# American Staffordshire Terrier
# Orange County, Westminster, CA
# ------------------
# Moo Moo
# http://post.rescueme.org/20-02-14-00336
# Bulldog
# Orange County, Westminster, CA
# ------------------
# Misty
# http://post.rescueme.org/20-02-14-00335
# Corgi
# Orange County, Westminster, CA
# ------------------
# Lucky
# http://post.rescueme.org/20-02-14-00334
# Shetland Sheepdog
# Orange County, Westminster, CA
# ------------------
# Kodak
# http://post.rescueme.org/20-02-14-00333
# Siberian Husky
# Orange County, Westminster, CA
# ------------------
# Elvis
# http://post.rescueme.org/20-02-14-00332
# Staffordshire Bull Terrier
# Orange County, Westminster, CA
# ------------------
# Cupid
# http://post.rescueme.org/20-02-14-00331
# Chihuahua
# Orange County, Westminster, CA
# ------------------
# Cherub
# http://post.rescueme.org/20-02-14-00330
# Cairn
# Orange County, Westminster, CA
# ------------------
# Bruno
# http://post.rescueme.org/20-02-14-00329
# Siberian Husky
# Orange County, Westminster, CA
# ------------------
# Roxy
# http://post.rescueme.org/20-02-14-00317
# Siberian Husky
# Riverside County, Lake Elsinore, CA
# ------------------
# Ringo
# http://post.rescueme.org/20-02-14-00316
# Shih Tzu
# Los Angeles County, Culver City, CA
# ------------------
# Sammie
# http://post.rescueme.org/20-02-14-00301
# German Shepherd
# San Bernardino County, Phelan, CA
# ------------------
# LUCARIO-URGENT NOW
# http://post.rescueme.org/20-02-14-00282
# Siberian Husky
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/20
# http://post.rescueme.org/20-02-14-00281
# Siberian Husky
# Riverside County, Moreno Valley, CA
# ------------------
# URGENT AFTER 2/20
# http://post.rescueme.org/20-02-14-00280
# German Shepherd
# Riverside County, Moreno Valley, CA
# ------------------
# SPARKY-URGENT 2/27
# http://post.rescueme.org/20-02-14-00278
# Yorkie
# Riverside County, Moreno Valley, CA
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
# URL of page to be scraped
url = "https://www.dogsblog.com/"
response = requests.get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# 	<meta charset="UTF-8">
# 	<!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
# 	<!--[if IE ]>
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<![endif]-->
# 	<link rel="profile" href="http://gmpg.org/xfn/11" />
#
#
#
#
# 					<meta name="viewport" content="width=device-width, initial-scale=1">
# 			<meta name="apple-mobile-web-app-capable" content="yes">
# 			<meta name="apple-mobile-web-app-status-bar-style" content="black">
#
# 			<link rel="pingback" href="https://www.dogsblog.com/xmlrpc.php" />
# 	<script type="text/javascript">document.documentElement.className = document.documentElement.className.replace( /\bno-js\b/,'js' );</script>
# <!-- Search Engine Optimization by Rank Math - https://s.rankmath.com/home -->
# <title>Dogs for Adoption - dogsblog.com</title>
# <meta name="description" content="dogsblog.com lists rescue dogs available for adoption all over the UK. All breeds, all types of dogs, all seeking new homes. Bring joy, adopt a dog!"/>
# <meta name="robots" content="index,follow"/>
# <link rel="canonical" href="https://www.dogsblog.com/" />
# <link rel="next" href="https://www.dogsblog.com/page/2/" />
# <meta property="og:locale" content="en_US">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Dogs for Adoption - dogsblog.com">
# <meta property="og:description" content="Bring joy, adopt a dog.">
# <meta property="og:url" content="https://www.dogsblog.com/">
# <meta property="og:site_name" content="Dogs for Adoption - dogsblog.com">
# <meta property="og:image" content="https://s6004.pcdn.co/wp-content/uploads/2019/05/dogsblog-logo-icon.jpg">
# <meta property="og:image:secure_url" content="https://s6004.pcdn.co/wp-content/uploads/2019/05/dogsblog-logo-icon.jpg">
# <meta property="og:image:width" content="1000">
# <meta property="og:image:height" content="1000">
# <meta property="og:image:type" content="image/jpeg">
# <meta name="twitter:card" content="summary_large_image">
# <meta name="twitter:title" content="Dogs for Adoption - dogsblog.com">
# <meta name="twitter:description" content="Bring joy, adopt a dog.">
# <meta name="twitter:site" content="@dogsblog">
# <meta name="twitter:image" content="https://s6004.pcdn.co/wp-content/uploads/2019/05/dogsblog-logo-icon.jpg">
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebSite","@id":"https:\/\/www.dogsblog.com\/#website","url":"https:\/\/www.dogsblog.com","name":"Dogs for Adoption - dogsblog.com","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.dogsblog.com\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org\/","@type":"Blog","url":"https:\/\/www.dogsblog.com","headline":"Dogs for Adoption - dogsblog.com","description":"bring joy, adopt a dog","blogPost":[{"@type":"BlogPosting","headline":"Lady &#8211; 11 month old female American Bulldog","name":"Lady &#8211; 11 month old female American Bulldog","url":"https:\/\/www.dogsblog.com\/lady-176\/","mainEntityOfPage":"https:\/\/www.dogsblog.com\/lady-176\/","dateModified":"2020-02-21T08:07:37-08:00","datePublished":"2020-02-21T08:07:37-08:00","author":{"@type":"Person","name":"All Dogs Matter London","url":"https:\/\/www.dogsblog.com\/author\/all-dogs-matter-london\/","description":"For further details regarding adopting a dog from All Dogs Matter, please email info@alldogsmatter.co.uk or telephone 0208 341 3196 \/ 07904 472 678. Address: 30 Aylmer Parade, London, N2 0PE. We are located in London.\r\n\r\nAll Dogs Matter is a registered dog rescue and rehoming charity based in North London. Our aim us to rescue and rehome dogs in and around London and surrounding areas. We work hard to help rescue and rehome as many abandoned and homeless dogs as we can.\r\n \r\nThe dogs who come into our care are strays, from pounds or simply dogs whose owners no longer can or want to keep. The dogs are a variety of breeds and come in all shapes and sizes!\r\n \r\nWe neuter, vaccinate and microchip each dog and then pair it with the right new owner, ensuring that it will be safe, cared for and loved for the rest of its life.","image":{"@type":"ImageObject","url":"https:\/\/secure.gravatar.com\/avatar\/007015e81eb29aeb8dd1da4fd0bb79e5?s=96&d=mm&r=g","height":96,"width":96}},"publisher":{"@type":"Organization","name":"Dogs for Adoption - dogsblog.com","logo":{"@type":"ImageObject","url":"https:\/\/www.dogsblog.com\/wp-content\/uploads\/2019\/03\/dogsblog-logo-head-1.png"}},"image":{"@type":"ImageObject","url":"https:\/\/www.dogsblog.com\/wp-content\/uploads\/2020\/02\/lady-scaled.jpg","height":1920,"width":2560},"keywords":[],"commentCount":0,"comment":"","wordCount":138},{"@type":"BlogPosting","headline":"India &#8211; 7 month old male German Shepherd Cross Labrador","name":"India &#8211; 7 month old male German Shepherd Cross Labrador","url":"https:\/\/www.dogsblog.com\/india-12\/","mainEntityOfPage":"https:\/\/www.dogsblog.com\/india-12\/","dateModified":"2020-02-21T08:04:37-08:00","datePublished":"2020-02-21T08:01:37-08:00","author":{"@type":"Person","name":"All Dogs Matter London","url":"https:\/\/www.dogsblog.com\/author\/all-dogs-matter-london\/","description":"For further details regarding adopting a dog from All Dogs Matter, please email info@alldogsmatter.co.uk or telephone 0208 341 3196 \/ 07904 472 678. Address: 30 Aylmer Parade, London, N2 0PE. We are located in London.\r\n\r\nAll Dogs Matter is a registered dog rescue and rehoming charity based in North London. Our aim us to rescue and rehome dogs in and around London and surrounding areas. We work hard to help rescue and rehome as many abandoned and homeless dogs as we can.\r\n \r\nThe dogs who come into our care are strays, from pounds or simply dogs whose owners no longer can or want to keep. The dogs are a variety of breeds and come in all shapes and sizes!\r\n \r\nWe neuter, vaccinate and microchip each dog and then pair it with the right new owner, ensuring that it will be safe, cared for and loved for the rest of its life.","image":{"@type":"ImageObject","url":"https:\/\/secure.gravatar.com\/avatar\/007015e81eb29aeb8dd1da4fd0bb79e5?s=96&d=mm&r=g","height":96,"width":96}},"publisher":{"@type":"Organization","name":"Dogs for Adoption - dogsblog.com","logo":{"@type":"ImageObject","url":"https:\/\/www.dogsblog.com\/wp-content\/uploads\/2019\/03\/dogsblog-logo-head-1.png"}},"image":{"@type":"ImageObject","url":"https:\/\/www.dogsblog.com\/wp-content\/uploads\/2020\/02\/india-2-rotated.jpg","height":2016,"width":1512},"keywords":[],"commentCount":0,"comment":"","wordCount ...
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Organization","@id":"https:\/\/www.dogsblog.com#organization","name":"Dogs for Adoption - dogsblog.com","url":"https:\/\/www.dogsblog.com","sameAs":["https:\/\/www.facebook.com\/dogsblogdotcom\/","https:\/\/twitter.com\/dogsblog"],"logo":"https:\/\/www.dogsblog.com\/wp-content\/uploads\/2019\/03\/dogsblog-logo-head-1.png"}</script>
# <meta name="google-site-verification" content="RmlK_XxMrxvSVMQkf7sfbCYO43kTptxk4ucFT71Rj0Y">
# <!-- /Rank Math WordPress SEO plugin -->
#
# <link rel='dns-prefetch' href='//js.stripe.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Dogs for Adoption - dogsblog.com &raquo; Feed" href="https://www.dogsblog.com/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Dogs for Adoption - dogsblog.com &raquo; Comments Feed" href="https://www.dogsblog.com/comments/feed/" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s6004.pcdn.co\/wp-includes\/js\/wp-emoji-release.min.js"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel='stylesheet' id='wp-block-library-css'  href='https://s6004.pcdn.co/wp-includes/css/dist/block-library/style.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='contact-form-7-css'  href='https://s6004.pcdn.co/wp-content/plugins/contact-form-7/includes/css/styles.css' type='text/css' media='all' />
# <link rel='stylesheet' id='ts_fab_css-css'  href='https://s6004.pcdn.co/wp-content/plugins/fanciest-author-box/css/ts-fab.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='give-styles-css'  href='https://s6004.pcdn.co/wp-content/plugins/give/assets/dist/css/give.css' type='text/css' media='all' />
# <link rel='stylesheet' id='give_ffm_frontend_styles-css'  href='https://s6004.pcdn.co/wp-content/plugins/give-form-field-manager/assets/css/give-ffm-frontend.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='give_ffm_datepicker_styles-css'  href='https://s6004.pcdn.co/wp-content/plugins/give-form-field-manager/assets/css/give-ffm-datepicker.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='give-stripe-css'  href='https://s6004.pcdn.co/wp-content/plugins/give-stripe/assets/dist/css/give-stripe.css' type='text/css' media='all' />
# <link rel='stylesheet' id='search-filter-plugin-styles-css'  href='https://s6004.pcdn.co/wp-content/plugins/search-filter-pro/public/assets/css/search-filter.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='ad-sense-stylesheet-css'  href='https://s6004.pcdn.co/wp-content/themes/mts_sense/style.css' type='text/css' media='all' />
# <style id='ad-sense-stylesheet-inline-css' type='text/css'>
#
# 		body {background-color:#f7f7f7;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/pattern0.png);}
# 		.text-info {background-color:#efefef;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		#header, .navigation.mobile-menu-wrapper {background-color:#f2f2f2;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		.navigation-wrap, .navigation ul ul, .navigation.mobile-menu-wrapper {background-color:#648ee0;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		.navigation ul ul:before { border-bottom-color: #648ee0}
# 		.footer-header, .toplink {background-color:#eaeaea;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		.footer-widgets {background-color:#353535;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		.copyrights {background-color:#252526;background-image:url(https://s6004.pcdn.co/wp-content/themes/mts_sense/images/nobg.png);}
# 		.navigation-banner {background-color:#252525}
#
# 		.latestPost .post-image:hover .post-format-icons, .currenttext, .pagination a:hover, #commentform input#submit, #load-posts a, .contact-form input[type='submit'], .advanced-recent-posts li .post-img:hover .post-format-icons, .popular-posts li .post-img:hover .post-format-icons, .category-posts li .post-img:hover .post-format-icons, .related-posts-widget li .post-img:hover .post-format-icons, .author-posts-widget li .post-img:hover .post-format-icons, .latestPost .readMore a, .featured-thumbnail, .currenttext, .page-numbers.current, .pagination .nav-previous a, .pagination .nav-next a, .pagination a.next, .pagination a.prev, .ball-pulse > div, .pace .pace-progress, .woocommerce-account .woocommerce-MyAccount-navigation li.is-active, .woocommerce-product-search button[type='submit'], .woocommerce .woocommerce-widget-layered-nav-dropdown__submit {
# 			background-color:#2196f3; }
#
# 		.text-info .text { color: #333399; }
# 		.text-info .readMore a { background-color: #ff2a7a; }
#
# 		a, #site-header .navigation ul.menu > li.current-menu-item > a, #site-header .navigation ul.menu > li:hover > a,
# 		#site-header .navigation ul.sub-menu > li:hover > a, #site-header #primary-navigation a:hover, .single_post .post-info .theauthor a, #comments h4.total-comments span { color: #2196f3; }
#
# 		.contact-form input[type='submit'], .latestPost .readMore a, .currenttext, .page-numbers.current, .pagination .nav-previous a, .pagination .nav-next a, .pagination a.next, .pagination a.prev {
# 			border-color: #2196f3;
# 		}
#
# 		.latestPost .post-image:hover .post-format-icons, .advanced-recent-posts li .post-img:hover .post-format-icons,
# 		.popular-posts li .post-img:hover .post-format-icons, .category-posts li .post-img:hover .post-format-icons,
# 		.related-posts-widget li .post-img:hover .post-format-icons, .author-posts-widget li .post-img:hover .post-format-icons {
# 			box-shadow: 0 0 0 4px #2196f3;
# 		}
#
# 		.latestPost .post-format-icons, .advanced-recent-posts li .post-format-icons, .popular-posts li .post-format-icons, .category-posts li .post-format-icons, .related-posts-widget li .post-format-icons, .author-posts-widget li .post-format-icons, .widget .wpt_widget_content #tags-tab-content ul li a:hover, body .owl-prev, body .owl-next, .contact-form input[type='submit']:hover, .text-info .readMore a:hover, .text-info .readMore a:focus, .text-info .readMore a:active, .tagcloud a:hover, .tagcloud a:focus, .tagcloud a:active, .tags a:hover, .tags a:focus, .tags a:active, #site-footer .tagcloud a:hover, .thecomment a:hover, .thecomment a:focus, .thecomment a:active, .latestPost .readMore a:hover, .latestPost .readMore a:focus, .latestPost .readMore a:active, .toplink:hover, .pagination .nav-previous a:hover, .pagination .nav-next a:hover, .pagination a.next:hover, .pagination a.prev:hover, #commentform input#submit:hover, .single-button > div a:hover, #load-posts a:hover, #load-posts a:focus, #load-posts a:active, .contact-form input[type='submit']:hover, .commentlist .navigation a:hover, .blocker-notice .refresh-button, .review-type-star.latestPost-review-wrapper, .review-type-star.latestPost-review-wrapper i, .latestPost .review-type-circle.latestPost-review-wrapper, .latestPost-review-wrapper {
# 		  background-color:#116ebf; border-color:#116ebf; color: #fff; }
#
# 		a:not(.wp-block-button .wp-block-button__link):hover, .latestPost .title a:hover, .postauthor h5 a:hover, .single_post .post-info .theauthor a:hover, .widget.widget_nav_menu li:hover > a, .widget.widget_nav_menu li:hover > .toggle-caret, .widget li.active > .toggle-caret, .comment-meta a, .reply a:hover, .default-post-info.post-info .thecomment a:hover, .single_post .post-info .thecomment a:hover, .copyrights .to-top a:hover, .woocommerce .woocommerce-breadcrumb a:hover {
# 			color: #116ebf;
# 		}
#
# 		.widget li a:hover, .widget .wpt_widget_content .wpt-pagination a:hover, .widget .wp_review_tab_widget_content .wp-review-tab-pagination a:hover, .ajax-search-results li a:hover { color: #116ebf!important; }
#
# 		.widget .wpt_widget_content .tab_title.selected a,  .widget .wp_review_tab_widget_content .tab_title.selected a {
# 			border-color: #2196f3!important; background-color:#2196f3!important; }
#
# 		.widget .wpt_widget_content .has-4-tabs .tab_title.selected:nth-child(even) a, .widget .wpt_widget_content .tab_title.selected:last-child a, .widget .wp_review_tab_widget_content .has-4-tabs .tab_title.selected:nth-child(even) a, .widget .wp_review_tab_widget_content .tab_title.selected:last-child a {
# 			border-right-color: #2196f3!important }
#
# 		.single .pagination > .current > .currenttext { border: 1px solid #2196f3!important; }
#
# 		.woocommerce nav.woocommerce-pagination ul li span.current, .woocommerce-page nav.woocommerce-pagination ul li span.current, .woocommerce #content nav.woocommerce-pagination ul li span.current, .woocommerce-page #content nav.woocommerce-pagination ul li span.current, .woocommerce nav.woocommerce-pagination ul li a:hover, .woocommerce-page nav.woocommerce-pagination ul li a:hover, .woocommerce #content nav.woocommerce-pagination ul li a:hover, .woocommerce-page #content nav.woocommerce-pagination ul li a:hover, .woocommerce nav.woocommerce-pagination ul li a:focus, .woocommerce-page nav.woocommerce-pagination ul li a:focus, .woocommerce #content nav.woocommerce-pagination ul li a:focus, .woocommerce-page #content nav.woocommerce-pagination ul li a:focus, .woocommerce input[type='submit'], .woocommerce div.product form.cart .button, .woocommerce-page div.product form.cart .button, .woocommerce #content div.product form.cart .button, .woocommerce-page #content div.product form.cart .button, .woocommerce a.button, .woocommerce-page a.button, .woocommerce button.button, .woocommerce-page button.button, .woocommerce input.button, .woocommerce-page input.button, .woocommerce #respond input#submit, .woocommerce-page #respond input#submit, .woocommerce #content input.button, .woocommerce-page #content input.button {
# 			border-color: #2196f3!important;
# 			background-color:#2196f3!important;
# 		}
#
#
#
#
#
#
#
#
# 		.footer-header .logo-wrap, .widget-header { display: none; }
#
# 		.footer-header { min-height: 0; position: absolute; background: 0; } #site-footer { overflow: visible; } .toplink { position: absolute; right: 30px; }
#
#
# 		#site-header #primary-navigation a:hover {
#     color: #fff;
# }
# .sidebar .widget h3, .widget li {
#     border: none;
# }
# .pt-cv-readmore {
#     color: YOUR_COLOR !important;
#     background-color: #116ebf !important;
#     border: none !important;
# }
# .latestPost .title a:hover {
#     color: #333399;
# }
# .widget {
#     margin-bottom: 0;
# }
# .featured-thumbnail img {
#     max-height: 250px;
# }
# .give-btn-reveal {
#     color: #fff;
#     background: #ff2a7a;
#     width: 130px;
# }
#
# </style>
# <link rel='stylesheet' id='responsive-css'  href='https://s6004.pcdn.co/wp-content/themes/mts_sense/css/responsive.css' type='text/css' media='all' />
# <link rel='stylesheet' id='fontawesome-css'  href='https://s6004.pcdn.co/wp-content/themes/mts_sense/css/font-awesome.min.css' type='text/css' media='all' />
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/jquery.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/jquery-migrate.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/ui/core.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/ui/datepicker.min.js'></script>
# <script type='text/javascript'>
# jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/ui/widget.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/ui/mouse.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/jquery/ui/slider.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/plupload/moxie.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/plupload/plupload.min.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var pluploadL10n = {"queue_limit_exceeded":"You have attempted to queue too many files.","file_exceeds_size_limit":"%s exceeds the maximum upload size for this site.","zero_byte_file":"This file is empty. Please try another.","invalid_filetype":"Sorry, this file type is not permitted for security reasons.","not_an_image":"This file is not an image. Please try another.","image_memory_exceeded":"Memory exceeded. Please try another smaller file.","image_dimensions_exceeded":"This is larger than the maximum size. Please try another.","default_error":"An error occurred in the upload. Please try again later.","missing_upload_url":"There was a configuration error. Please contact the server administrator.","upload_limit_exceeded":"You may only upload 1 file.","http_error":"Unexpected response from the server. The file may have been uploaded successfully. Check in the Media Library or reload the page.","http_error_image":"Post-processing of the image failed. If this is a photo or a large image, please scale it down to 2500 pixels and upload it again.","upload_failed":"Upload failed.","big_upload_failed":"Please try uploading this file with the %1$sbrowser uploader%2$s.","big_upload_queued":"%s exceeds the maximum upload size for the multi-file uploader when used in your browser.","io_error":"IO error.","security_error":"Security error.","file_cancelled":"File canceled.","upload_stopped":"Upload stopped.","dismiss":"Dismiss","crunching":"Crunching\u2026","deleted":"moved to the trash.","error_uploading":"\u201c%s\u201d has failed to upload."};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/plupload/handlers.min.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var give_ffm_frontend = {"ajaxurl":"https:\/\/www.dogsblog.com\/wp-admin\/admin-ajax.php","error_message":"Please complete all required fields","submit_button_text":"Donate Now","nonce":"06d4179a45","confirmMsg":"Are you sure?","i18n":{"timepicker":{"choose_time":"Choose Time","time":"Time","hour":"Hour","minute":"Minute","second":"Second","millisecond":"Millisecond","microsecond":"Microsecond","timezone":"Time Zone","done":"Done","now":"Now"},"repeater":{"max_rows":"You have added the maximum number of fields allowed."}},"plupload":{"url":"https:\/\/www.dogsblog.com\/wp-admin\/admin-ajax.php?nonce=7cd4f4f36a","flash_swf_url":"https:\/\/www.dogsblog.com\/wp-includes\/js\/plupload\/plupload.flash.swf","filters":[{"title":"Allowed Files","extensions":"*"}],"multipart":true,"urlstream_upload":true}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/give-form-field-manager/assets/js/frontend/give-ffm-frontend.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/fanciest-author-box/js/ts-fab.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/give/assets/dist/js/babel-polyfill.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var give_global_vars = {"ajaxurl":"https:\/\/www.dogsblog.com\/wp-admin\/admin-ajax.php","checkout_nonce":"b8a4b2f95d","currency":"GBP","currency_sign":"\u00a3","currency_pos":"before","thousands_separator":",","decimal_separator":".","no_gateway":"Please select a payment method.","bad_minimum":"The minimum custom donation amount for this form is","bad_maximum":"The maximum custom donation amount for this form is","general_loading":"Loading...","purchase_loading":"Please Wait...","number_decimals":"2","give_version":"2.5.10","magnific_options":{"main_class":"give-modal","close_on_bg_click":false},"form_translation":{"payment-mode":"Please select payment mode.","give_first":"Please enter your first name.","give_email":"Please enter a valid email address.","give_user_login":"Invalid email address or username.","give_user_pass":"Enter a password.","give_user_pass_confirm":"Enter the password confirmation.","give_agree_to_terms":"You must agree to the terms and conditions."},"confirm_email_sent_message":"Please check your email and click on the link to access your complete donation history.","ajax_vars":{"ajaxurl":"https:\/\/www.dogsblog.com\/wp-admin\/admin-ajax.php","ajaxNonce":"0da875755b","loading":"Loading","select_option":"Please select an option","default_gateway":"paypal","permalinks":"1","number_decimals":2},"cookie_hash":"8d1068d3b18464ffd487056f3a924578","session_nonce_cookie_name":"wp-give_session_reset_nonce_8d1068d3b18464ffd487056f3a924578","session_cookie_name":"wp-give_session_8d1068d3b18464ffd487056f3a924578","delete_session_nonce_cookie":"0"};
# var giveApiSettings = {"root":"https:\/\/www.dogsblog.com\/wp-json\/give-api\/v2\/","rest_base":"give-api\/v2"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/give/assets/dist/js/give.js'></script>
# <script type='text/javascript' src='https://js.stripe.com/v3/'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var give_stripe_vars = {"zero_based_currency":"","zero_based_currencies_list":["JPY","KRW","CLP","ISK","BIF","DJF","GNF","KHR","KPW","LAK","LKR","MGA","MZN","VUV"],"sitename":"Dogs for Adoption & Rescue - DogsBlog.com","publishable_key":"pk_live_SMtnnvlq4TpJelMdklNha8iD","checkout_image":"","checkout_address":"on","checkout_processing_text":"Donation Processing...","zipcode_option":"1","remember_option":"1","give_version":"2.5.10","cc_fields_format":"multi","card_number_placeholder_text":"Card Number","card_cvc_placeholder_text":"CVC","donate_button_text":"Donate Now","element_font_styles":{"cssSrc":false},"element_base_styles":{"color":"#32325D","fontWeight":500,"fontSize":"16px","fontSmoothing":"antialiased","::placeholder":{"color":"#222222"},":-webkit-autofill":{"color":"#e39f48"}},"element_complete_styles":{},"element_empty_styles":{},"element_invalid_styles":{},"float_labels":"","base_country":"GB","payment_request_button_style":"dark","stripe_card_update":"","stripe_account_id":"acct_2LE8XTGjqf2zPsY8DAS2","preferred_locale":"en"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/give-stripe/assets/dist/js/give-stripe.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var SF_LDATA = {"ajax_url":"https:\/\/www.dogsblog.com\/wp-admin\/admin-ajax.php","home_url":"https:\/\/www.dogsblog.com\/"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/search-filter-pro/public/assets/js/search-filter-build.min.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/search-filter-pro/public/assets/js/chosen.jquery.min.js'></script>
# <link rel='https://api.w.org/' href='https://www.dogsblog.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://www.dogsblog.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://s6004.pcdn.co/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 5.3.2" />
#
#
# 	<style>
# 	.ts-fab-wrapper .ts-fab-list li a { background-color: #e9e9e9; border: 1px solid #e9e9e9; color: #333; }
# 	.ts-fab-wrapper .ts-fab-list li.active a { background-color: #41A4E4; border: 1px solid #41A4E4; color: #fff; }
# 	.ts-fab-wrapper .ts-fab-tab { background-color: #f9f9f9; border: 2px solid #333; color: #555; }
# 	</style>
# 	<meta name="generator" content="Give v2.5.10" />
# <link href="//fonts.googleapis.com/css?family=Roboto+Slab:700|Roboto:700|Roboto:normal&amp;subset=latin" rel="stylesheet" type="text/css">
# <style type="text/css">
# #header h1, #header h2, .footer-header #logo { font-family: 'Roboto Slab'; font-weight: 700; font-size: 28px; color: #ffffff; }
# #primary-navigation a { font-family: 'Roboto'; font-weight: 700; font-size: 13px; color: #ffffff;text-transform: uppercase; }
# .latestPost .title a { font-family: 'Roboto Slab'; font-weight: 700; font-size: 16px; color: #555555; }
# .single-title { font-family: 'Roboto'; font-weight: 700; font-size: 30px; color: #252525; }
# body { font-family: 'Roboto'; font-weight: normal; font-size: 16px; color: #757575; }
# .sidebar .widget h3 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 20px; color: #252525; }
# .sidebar .widget { font-family: 'Roboto'; font-weight: normal; font-size: 14px; color: #1e73be; }
# .sidebar .widget li .post-title a, .sidebar .widget li .entry-title a { font-family: 'Roboto Slab'; font-weight: 700; font-size: 16px; color: #1e73be; }
# #site-footer .widget h3 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 20px; color: #ffffff; }
# #site-footer { font-family: 'Roboto'; font-weight: 700; font-size: 14px; color: #757575; }
# #site-footer .widget li .post-title a, #site-footer .widget li .entry-title a { font-family: 'Roboto Slab'; font-weight: 700; font-size: 14px; color: #757575; }
# h1 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 28px; color: #252525; }
# h2 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 24px; color: #252525; }
# h3 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 22px; color: #252525; }
# h4 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 20px; color: #252525; }
# h5 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 18px; color: #252525; }
# h6 { font-family: 'Roboto Slab'; font-weight: 700; font-size: 16px; color: #252525; }
# </style>
# <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
#
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/14138684/DogsBlog-MPU', [300, 250], 'div-gpt-ad-1554110540861-0').addService(googletag.pubads());
#    googletag.defineSlot('/14138684/DogsBlog-Leader', [728, 90], 'div-gpt-ad-1554110929370-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <meta name="google-site-verification" content="RmlK_XxMrxvSVMQkf7sfbCYO43kTptxk4ucFT71Rj0Y" /></head>
# <body id="blog" class="home blog main">
#
#
# 		<div class="main-container popup">
# 		<header id="site-header" role="banner" itemscope itemtype="http://schema.org/WPHeader">
# 	  		<div class="container">
# 	  			<div id="header">
# 					<div class="logo-wrap">
# 														<h1 id="logo" class="image-logo" itemprop="headline">
# 									<a href="https://www.dogsblog.com"><img src="https://s6004.pcdn.co/wp-content/uploads/2019/03/dogsblog-logo-head-1.png" alt="Dogs for Adoption - dogsblog.com" width="320" height="70"></a>
# 								</h1><!-- END #logo -->
# 																		</div>
# 											<div class="header-banner">
# 							<div style=" max-width: 100%;">
# 								<!-- /14138684/DogsBlog-Leader -->
# <div id='div-gpt-ad-1554110929370-0' style='height:90px; width:728px;'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1554110929370-0'); });
# </script>
# </div>							</div>
# 						</div>
# 									</div><!--#header-->
# 												<div class="navigation-wrap">
# 						 				   					<div id="primary-navigation" role="navigation" itemscope itemtype="http://schema.org/SiteNavigationElement">
# 			  				<a href="#" id="pull" class="toggle-mobile-menu">Menu</a>
# 			  				<nav class="navigation clearfix mobile-menu-wrapper">
# 																	<ul id="menu-main-menu" class="menu clearfix"><li id="menu-item-226655" class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current_page_item menu-item
class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-125165"><a href="https://www.dogsblog.com/about-dogsblog/">About</a>
# 	<ul class="sub-menu">
# 		<li id="menu-item-125168" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-125168"><a href="https://www.dogsblog.com/about-dogsblog/media/">DogsBlog Media Coverage</a></li>
# 	</ul>
# </li>
# 	<li id="menu-item-125170" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-125170"><a href="https://www.dogsblog.com/about-dogsblog/dogsblog-web-links/">Your Website Can Help DogsBlog</a></li>
# 	<li id="menu-item-125158" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-125158"><a href="https://www.dogsblog.com/adopting-a-dog/get-in-touch/">Contact DogsBlog</a></li>
# 	<li id="menu-item-125164" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-125164"><a href="https://www.dogsblog.com/about-dogsblog/list-your-rescue-shelter-on-dogsblogcom/" style="color: #ffffff;">List Your Shelter</a></li>
# </ul>
# </li>
# </ul>															</nav>
# 		   				</div>
# 		  					  									<div id="search-6" class="widget widget_search">
# 							<form method="get" id="searchform" class="search-form" action="https://www.dogsblog.com" _lpchecked="1">
# 	<fieldset>
# 		<input type="search" name="s" id="s" value="" />
# 		<i id="search-image" class="sbutton fa fa-search"></i>
# 	</fieldset>
# </form>
# 						</div><!-- END #search-6 -->
# 		  								</div>
# 													<div class="text-info">
# 					<h3 class="text">You can now help to support our dog adoption mission!</h3>
# 											<div class="readMore">
# 							<a href="/support/" title="DONATE TODAY">DONATE TODAY</a>
# 						</div>
#
# 				</div>
# 						</div>
# 		</header>
# <div id="page" class="page-traditional">
#
# 	<div class="article">
# 		<div id="content_box">
#     <div id="text-15" class="widget widget_text">			<div class="textwidget"><h2>Since 2007, <span style="color: #ff2a7a;">57089</span> Dogs Have <span style="color: #ff2a7a;">Found New Homes</span> Through dogsblog.com. Now Let&#8217;s Find The Ideal Adoptable Dog For You!</h2>
# <p>Use the form below to find dogs for adoption by breed, by age (e.g. <a href="https://www.dogsblog.com/category/age/0-1-years/">puppies for adoption</a> or <a href="https://www.dogsblog.com/category/age/6-years/">older dogs for adoption</a>), by location, by shelter or search by your ideal criteria such as <a href="https://www.dogsblog.com/tag/house-trained/">house-trained dogs</a>, <a href="https://www.dogsblog.com/tag/good-with-children/">dogs good with children</a>, <a href="https://www.dogsblog.com/tag/suitable-to-live-with-other-dogs/">good with other dogs,</a> <a href="https://www.dogsblog.com/tag/suitable-to-live-with-cats/">good with cats</a>, <a href="https://www.dogsblog.com/tag/suitable-for-agility/">active dogs</a> etc. Go ahead, give it a try&#8230;<br />
# <div class="su-tabs su-tabs-style-default su-tabs-mobile-stack" data-active="1" data-scroll-offset="0"><div class="su-tabs-nav"><span class="" data-url="" data-target="blank" tabindex="0" role="button">by Breed</span><span class="" data-url="" data-target="blank" tabindex="0" role="button">by Location</span><span class="" data-url="" data-target="blank" tabindex="0" role="button">by Shelter</span><span class="" data-url="" data-target="blank" tabindex="0" role="button">Matchmaker</span></div><div class="su-tabs-panes"><div class="su-tabs-pane su-u-clearfix su-u-trim" data-title="by Breed"><div id="pro_categories_widget-7" class="widget widget_categories"><select  name='cat' id='cat_7' class='postform' >
# 	<option value='-1'>Select Category</option>
# 	<option class="level-0" value="3">&#8211; All Dogs Available for Adoption</option>
# 	<option class="level-0" value="26">&#8211; Female Dogs For Adoption</option>
# 	<option class="level-0" value="25">&#8211; Male Dogs For Adoption</option>
# 	<option class="level-0" value="6">0-1 years (Puppies for Adoption)</option>
# 	<option class="level-0" value="7">1-2 years</option>
# 	<option class="level-0" value="8">3-5 years</option>
# 	<option class="level-0" value="20">6 Years + (Older Dogs for Adoption)</option>
# 	<option class="level-0" value="393">Akita</option>
# 	<option class="level-0" value="405">Akita Cross</option>
# 	<option class="level-0" value="149">Alaskan Malamute</option>
# 	<option class="level-0" value="258">Alaskan Malamute Cross</option>
# 	<option class="level-0" value="57">American Bulldog</option>
# 	<option class="level-0" value="126">American Bulldog Cross</option>
# 	<option class="level-0" value="175">Australian Kelpie Cross</option>
# 	<option class="level-0" value="503">Basenji Cross</option>
# 	<option class="level-0" value="121">Basset Hound Cross</option>
# 	<option class="level-0" value="120">Beagle</option>
# 	<option class="level-0" value="124">Beagle Cross</option>
# 	<option class="level-0" value="127">Bedlington Terrier Cross</option>
# 	<option class="level-0" value="58">Belgian Shepherd</option>
# 	<option class="level-0" value="147">Belgian Shepherd Cross</option>
# 	<option class="level-0" value="90">Bichon Frise</option>
# 	<option class="level-0" value="82">Bichon Frise Cross</option>
# 	<option class="level-0" value="37">Border Collie</option>
# 	<option class="level-0" value="80">Border Collie Cross</option>
# 	<option class="level-0" value="181">Border Terrier</option>
# 	<option class="level-0" value="111">Border Terrier Cross</option>
# 	<option class="level-0" value="119">Boxer</option>
# 	<option class="level-0" value="35">Boxer Cross</option>
# 	<option class="level-0" value="252">Brittany Spaniel</option>
# 	<option class="level-0" value="796">Bucovina Shepherd Cross</option>
# 	<option class="level-0" value="61">Bull Mastiff Cross</option>
# 	<option class="level-0" value="86">Bull Terrier Cross</option>
# 	<option class="level-0" value="615">Bulldog</option>
# 	<option class="level-0" value="441">Bulldog Cross</option>
# 	<option class="level-0" value="312">Cairn Terrier</option>
# 	<option class="level-0" value="97">Cairn Terrier Cross</option>
# 	<option class="level-0" value="306">Cane Corso Cross</option>
# 	<option class="level-0" value="56">Cavalier King Charles Spaniel</option>
# 	<option class="level-0" value="166">Chihuahua</option>
# 	<option class="level-0" value="28">Chihuahua Cross</option>
# 	<option class="level-0" value="419">Chinese Crested Hairless Cross</option>
# 	<option class="level-0" value="225">Chow Chow</option>
# 	<option class="level-0" value="579">Cockapoo</option>
# 	<option class="level-0" value="461">Collie</option>
# 	<option class="level-0" value="22">Collie Cross</option>
# 	<option class="level-0" value="138">Corgi Cross</option>
# 	<option class="level-0" value="594">Croatian Sheepdog Cross</option>
# 	<option class="level-0" value="67">Dachshund Cross</option>
# 	<option class="level-0" value="81">Dalmatian</option>
# 	<option class="level-0" value="87">Dalmatian Cross</option>
# 	<option class="level-0" value="130">Deerhound Cross</option>
# 	<option class="level-0" value="62">Dobermann Cross</option>
# 	<option class="level-0" value="145">Dogue de Bordeaux Cross</option>
# 	<option class="level-0" value="93">English Bull Terrier</option>
# 	<option class="level-0" value="44">English Bull Terrier Cross</option>
# </div>
# 		</div>	</aside><!--#sidebar-->
# 	</div><!--#page-->
# 	<footer id="site-footer" role="contentinfo" itemscope itemtype="http://schema.org/WPFooter">
# 		<div class="container">
# 			<div class="footer-header">
# 				<div class="logo-wrap">
# 																		<h3 id="logo" class="text-logo" itemprop="headline">
# 								<a href="https://www.dogsblog.com">Dogs for Adoption &#8211; dogsblog.com</a>
# 							</h3><!-- END #logo -->
# 												<div class="site-description" itemprop="description">
# 							bring joy, adopt a dog						</div>
# 									</div>
# 								<a href="#blog" class="toplink"><i class="fa fa-angle-up"></i></a>
# 		</div><!--.footer-header-->
#
# 			<div class="copyrights">
# 				<!--start copyrights-->
# <div class="row" id="copyright-note">
# 		<span>Copyright &copy; 2020  <a href=" https://www.dogsblog.com/" title=" bring joy, adopt a dog">Dogs for Adoption - dogsblog.com</a></span>
# 	<div class="to-top"></div>
# </div>
# <!--end copyrights-->
# 			</div>
# 		</div><!--.container-->
# 	</footer><!--#site-footer-->
# 	</div><!--.main-container-->
# 	<!--start footer code-->
# 		<!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-282190-10"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-282190-10');
# </script>	<!--end footer code-->
#
#
# <link rel='stylesheet' id='su-shortcodes-css'  href='https://s6004.pcdn.co/wp-content/plugins/shortcodes-ultimate/includes/css/shortcodes.css' type='text/css' media='all' />
# <link rel='stylesheet' id='animate-css'  href='https://s6004.pcdn.co/wp-content/plugins/shortcodes-ultimate/vendor/animatecss/animate.css' type='text/css' media='all' />
# <script type='text/javascript'>
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.dogsblog.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"cached":"1"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/contact-form-7/includes/js/scripts.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var mts_customscript = {"responsive":"1","nav_menu":"primary"};
# /* ]]> */
# </script>
# <script type='text/javascript' async="async" src='https://s6004.pcdn.co/wp-content/themes/mts_sense/js/customscript.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-includes/js/wp-embed.min.js'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var SUShortcodesL10n = {"noPreview":"This shortcode doesn't work in live preview. Please insert it into editor and preview on the site.","magnificPopup":{"close":"Close (Esc)","loading":"Loading...","prev":"Previous (Left arrow key)","next":"Next (Right arrow key)","counter":"%curr% of %total%","error":"Failed to load content.. <a href=\"0rl target=\"_blank\"><u>\/u><\/a>"}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/shortcodes-ultimate/includes/js/shortcodes/index.js'></script>
# <script type='text/javascript' src='https://s6004.pcdn.co/wp-content/plugins/shortcodes-ultimate/vendor/jquery-inview/jquery-inview.js'></script>
# </body>
# </html>

# %%
# URL of page to be scraped
url = "https://bestfriends.org/adopt/adopt-our-sanctuary/dogs"
browser.visit(url)

# %%
for x in range(1, 10):
    browser.is_element_visible_by_css(".load-more", wait_time=3)
    browser.click_link_by_partial_text('MORE ANIMALS')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      41         try:
# ---> 42             return self._container[index]
#      43         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-42-766f58ab8e17> in <module>
#       1 for x in range(1, 10):
#       2     browser.is_element_visible_by_css(".load-more", wait_time=3)
# ----> 3     browser.click_link_by_partial_text('MORE ANIMALS')
#       4
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/driver/__init__.py in click_link_by_partial_text(self, partial_text)
#     394         Clicks in a link by partial content of its text.
#     395         """
# --> 396         return self.find_link_by_partial_text(partial_text).first.click()
#     397
#     398     def click_link_by_id(self, id):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in first(self)
#      55             >>> assert element_list[0] == element_list.first
#      56         """
# ---> 57         return self[0]
#      58
#      59     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/element_list.py in __getitem__(self, index)
#      44             raise ElementDoesNotExist(
#      45                 u'no elements could be found with {0} "{1}"'.format(
# ---> 46                     self.find_by, self.query
#      47                 )
#      48             )
#
# ElementDoesNotExist: no elements could be found with link by partial text "MORE ANIMALS"

# %%
for x in range(1, 25):
    
    soup = BeautifulSoup(html, 'html.parser')

# %%
# URL of page to be scraped
url = "https://bestfriends.org/adopt/adopt-our-sanctuary/dogs"
response = requests.get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>
# <html class="ie6 ie" lang="en"
#       dir="ltr"> <![endif]-->
# <!--[if IE 7]>
# <html class="ie7 ie" lang="en"
#       dir="ltr"> <![endif]-->
# <!--[if IE 8]>
# <html class="ie8 ie" lang="en"
#       dir="ltr"> <![endif]-->
# <!--[if gt IE 8]> <!-->
# <html class="
# not-ie" lang="en"
#       dir="ltr"> <!--<![endif]-->
# <head>
#   <!--[if IE]><![endif]-->
# <link rel="dns-prefetch" href="//maxcdn.bootstrapcdn.com" />
# <link rel="dns-prefetch" href="//s3fs.bestfriends.org" />
# <link rel="dns-prefetch" href="//dm76icm4097f8.cloudfront.net" />
# <link rel="dns-prefetch" href="//ajax.googleapis.com" />
# <link rel="dns-prefetch" href="//google_tag" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"c72fbe0d5a",applicationID:"206872624"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var a,f,c=e("handle"),u=e("loader"),s=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){a=new PerformanceObserver(r),f=new PerformanceObserver(i);try{a.observe({entryTypes:["paint"]}),f.observe({entryTypes:["largest-contentful-paint"]})}catch(p){}}if("addEventListener"in document){var l=!1,d=["click","keydown","mousedown","pointerdown","touchstart"];d.forEach(function(e){document.addEventListener(e,o,!1)})}}},{}],3:[function(e,n,t){function r(e,n){if(!i)return!1;if(e!==i)return!1;if(!n)return!0;if(!o)return!1;for(var t=o.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}n.exports={agent:i,version:o,match:r}},{}],4:[function(e,n,t){function r(e,n){var t=[],r="",o=0;for(r in e)i.call(e,r)&&(t[o]=n(r,e[r]),o+=1);return t}var i=Object.prototype.hasOwnProperty;n.exports=r},{}],5:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,i=t-n||0,o=Array(i<0?0:i);++r<i;)o[r]=e[n+r];return o}n.exports=r},{}],6:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function i(e){function n(e){return e&&e instanceof r?e:e?c(e,f,o):o()}function t(t,r,i,o){if(!l.aborted||o){e&&e(t,r,i);for(var a=n(i),f=v(t),c=f.length,u=0;u<c;u++)f[u].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function d(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}fun ...
# <link rel="shortcut icon" href="https://bestfriends.org/sites/all/themes/bf_theme/favicon.ico" type="image/vnd.microsoft.icon" />
#
#       <script type='text/javascript'>
#       var objBlackAndWhite  = {
# 				hoverEffect: false, // default true
# 				// set the path to BnWWorker.js for a superfast implementation
# 				webworkerPath: '',
# 				// for the images with a fluid width and height
# 				responsive: true,
# 				invertHoverEffect: true,
# 				speed: {//this property could also be just speed: value for both fadeIn and fadeOut
# 					fadeIn: 400, // 400ms for fadeIn animations
# 					fadeOut: 800 // 800ms for fadeOut animations
# 				}
# 	    };
# 	  </script>
#     <script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@graph": [
#         {
#             "isAccessibleForFree": "False"
#         },
#         {
#             "@type": "WebSite",
#             "@id": "https://bestfriends.org/",
#             "name": "Best Friends Animal Society",
#             "url": "https://bestfriends.org/",
#             "publisher": {
#                 "@type": "Organization",
#                 "@id": "https://bestfriends.org/",
#                 "name": "Best Friends Animal Society",
#                 "url": "https://bestfriends.org/",
#                 "sameAs": [
#                     "https://www.facebook.com/bestfriendsanimalsociety",
#                     "https://twitter.com/bestfriends",
#                     "https://www.instagram.com/bestfriendsanimalsociety/",
#                     "https://www.pinterest.com/bfas/",
#                     "https://www.pinterest.com/bfas/",
#                     "https://plus.google.com/+BestfriendsOrg"
#                 ],
#                 "logo": {
#                     "@type": "ImageObject",
#                     "representativeOfPage": "True",
#                     "url": "https://s3fs.bestfriends.org/s3fs-public/bfas.png",
#                     "width": "458",
#                     "height": "88"
#                 }
#             }
#         }
#     ]
# }</script>
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />
# <meta name="description" content="Adopt a dog. Browse adoptable dogs and puppies from Best Friends. We have purebred, mixed breed, big, small, playful, relaxed, and all ages available." />
# <style type='text/css'>.navigation > div > ul ul li:hover > a, .navigation > div > ul ul li.current-menu-item > a, .navigation > div > ul ul li.current-menu-parent > a, .navigation > div > ul ul li.current-menu-ancestor > a, .navigation > div > ul ul li.current_page_item > a, .navigation > div > ul ul li.current_page_parent > a, .navigation > div > ul ul li.current_page_ancestor > a, .simple-pricing-table.type-1 .featured .cost, .simple-pricing-table.type-2 .title, .widget_popular_posts a:hover h6, .portfolio-filter li a:hover, #sidebar .widget li a:hover, .portfolio-filter .active,  .entry-meta span:before, .entry-title h2 a:hover, #sidebar .jta-tweet-a, .entry-meta a:hover, .author-entry h5, #footer a:hover, .quote-author, .tooltip {color: #f58320 !important;}</style> <style type='text/css'>.navigation > div > ul > li:hover > a, .navigation > div > ul > li.current-menu-item > a, .navigation > div > ul > li.current-menu-parent > a, .navigation > div > ul > li.current-menu-ancestor > a, .navigation > div > ul > li.current_page_item > a, .navigation > div > ul > li.current_page_parent > a, .navigation > div > ul > li.current_page_ancestor > a, .scribble .projects-carousel li:hover > a:after, .simple-pricing-table.type-2 .featured .price, .scribble article:hover .project-meta:after, .simple-pricing-table .featured .button, .jta-tweet-list-controls span:hover, .simple-pricing-table.type-1 .title, .gallery-slider-nav:hover a:hover, .color-1.scribble .team-entry:hover:after, .scribble .tabs-nav .active:after, .post-slider-nav:hover a:hover, .flex-direction-nav a:hover, .portfolio-controls a:hover, .acc-trigger.active:before, .detail-box .transform, .ajax-nav li:hover > a, .jcarousel-prev:hover, .jcarousel-next:hover, .wp-pagenavi .current, .button.default:hover, .flexslider .caption, .ajax-nav .current a, ul.type-1 li:before, .quotes-nav a:hover, #back-top:hover, .dropcap.color, i.small-arrows, .curtain, .highlight, .button.default:hover	{background-color: #f58320 !important; }</style> <style type='text/css'>.portfolio-items article:hover .project-meta, .projects-carousel li:hover > a, .ajax-nav li:hover:before, .ajax-nav .current:before, .tabs-nav .active, .team-entry:hover{border-color: #f58320 }</style> <style type='text/css'>::-moz-selection {background-color: #f58320 }</style> <style type='text/css'>::selection {background-color: #f58320 }</style> <meta name="generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="https://bestfriends.org/adopt/adopt-our-sanctuary/dogs" />
# <link rel="shortlink" href="https://bestfriends.org/adopt/adopt-our-sanctuary/dogs" />
# <meta property="og:site_name" content="Best Friends Animal Society" />
# <meta property="og:type" content="article" />
# <meta property="og:url" content="https://bestfriends.org/adopt/adopt-our-sanctuary/dogs" />
# <meta property="og:title" content="Adoptable Dogs" />
#   <title>Adopt a Dog | Best Friends Animal Society</title>
#   <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__BJ6Ou6QsBRtnFTmxaakamOIS8n4QswDP2XnnZ1sxtaM__NBuvkP6eInGIkb1aJvUHx5PX79XApuxBDkk_77W5tYk__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__uAP5bebd2dLDQdmK5pC9dbCEUp4h0sdbe5g8hpAc9R0__nBpV3Zd2TwkMQygaG4H_-KCkK9-invGqS8VH-XeUcS4__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__ebpEINUCRrHjk5palJFmf7f1eJCvi-uKiW_rJi3LX7Q__DZPVFj4GF8QQIXoGAoPr_oNZ9SWVnB0FlpcawPG4M9Q__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/all/themes/bf_theme/css/font-family.css?q60pir" media="all" />
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__tO7tiFv7QuqLvrUeQg3YHIbA-yfQLVihYXqqfyMjbao__fhXJY7stl-UQVpZniOpHjM206acYMkG7-OrTpsQRzrI__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <style type="text/css" media="all">
# /* <![CDATA[ */
# #search-block-form .form-item-search-block-form input.form-text{color:#FFFFFF}
#
# /* ]]> */
# </style>
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__mdcsO0-rPpwCYLFv3WJDJUucmogB2qILtqFm8WpA6Go__ZYEfG0Qxh43BhzbI2aZDA1mHu29eh1zkOkAmrx1RY4g__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <style type="text/css" media="all">
# /* <![CDATA[ */
# @media screen and (min-width:986px){.responsive-menu-block-wrapper.responsive-menu-block{display:block;}#block-responsive-menu-toggle{display:none;}}
#
# /* ]]> */
# </style>
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__CH768KJRCo7Pljxwc0RsnckBez923rbQLAE5o_On7JU__QnFhrHrTMu3OTl7zGsqxGvRVysFYmHArFkZSybiCkMA__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
# <link type="text/css" rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://s3fs.bestfriends.org/advagg_css/css__RpbgAHH8eo27fVK5PkX1VRqzXDt6FsNG1qKi2LT6K6w__PEcAoPnXUfGTrSNVHWgD9sc0ev9oNNxR-pTZ44_CZgs__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.css" media="all" />
#   <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__SlxZR0T0y0knhPGspoKKlEQqbk_RdNNsHwLrlCQRTSo__yH48U9VqilbeoCAiJXKTrlGpmG9MDUnGaZ4NzARG7mw__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js" defer="defer"></script>
# <script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.10/jquery.min.js'>\x3C/script>")
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__1YIht1y1Jlm9D0PyxEuhS3DlWdYAlEsNpsFDOaUsfRw__ZnC7278ZsqBG-1FOUqflDl8B3Y1kLiAWXAIkoLrHbYg__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# <script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# window.jQuery.ui || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/ui/ui/minified/jquery-ui.min.js'>\x3C/script>")
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__bFOh74rblCNfeAqBWGqF603OXHEBWOI8xUWm9gk-Mnw__uKP6bdssouSeSOO3xvX5BqOp2WaFmA0I2Uj15IUGujs__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__cZnNaEUgaOqC96SvU445sAJeM5GT4PaEBLbtXVfgwNk__wiRfuUQ3MSTV2_bzHOlQOZmSVQHIVUF8dLBWOlAMPHI__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__17JJ2VaQXibxqjgUhiYMJHCoE2TLTeoStCWDG_fROOU__49ab3mBVvSVEdtvOSKIO-pyAJGwihqYy0GWSbm0k6aM__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__35ndAGO2aJt7vC8XGQp_m9cAtDNakf860YYyu-c9kUg__VRA0OwWaRZZcMY3yH8DDhtetCN_3tBuxbYhF0dvTrss__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings,{"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"bf_theme","theme_token":"IyXKTdGNDlz-Ry_Y264dZJZ70nf-xS3gG7DJnYYzbP0","jquery_version":"1.10","css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.menu.css":1,"misc\/ui\/jquery.ui.autocomplete.css":1,"sites\/all\/modules\/contrib\/calendar\/css\/calendar_multiday.css":1,"sites\/all\/modules\/contrib\/colorbox_node\/colorbox_node.css":1,"modules\/comment\/comment.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/google_cse\/google_cse.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/workflow\/workflow_admin_ui\/workflow_admin_ui.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/themes\/bf_theme\/css\/font-family.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/custom\/custom_calculator\/css\/jquery.selectBox.css":1,"sites\/all\/modules\/contrib\/node_embed\/plugins\/node_embed\/node_embed.css":1,"sites\/all\/libraries\/mmenu\/dist\/jquery.mmenu.all.css":1,"sites\/all\/modules\/contrib\/better_search\/css\/background_fade.css":1,"sites\/all\/modules\/contrib\/responsive_menu\/css\/responsive_menu.css":1,"sites\/all\/modules\/contrib\/addtoany\/addtoany.css":1,"sites\/all\/modules\/contrib\/gd_infinite_scroll\/css\/gd_infinite_scroll.css":1,"\/\/maxcdn.bootstrapcdn.com\/font-awesome\/4.3.0\/css\/font-awesome.min.css":1,"sites\/all\/themes\/goodnex\/css\/style.css":1,"sites\/all\/themes\/goodnex\/css\/drupal.css":1,"sites\/all\/themes\/goodnex\/css\/skeleton.css":1,"sites\/all\/themes\/goodnex\/css\/layout.css":1,"sites\/all\/themes\/goodnex\/js\/fancybox\/jquery.fancybox-1.3.4.css":1,"sites\/all\/themes\/goodnex\/js\/flexslider\/css\/flexslider.css":1,"sites\/all\/themes\/goodnex\/js\/mediaelement\/jquery.mediaelementplayer.css":1,"sites\/all\/themes\/goodnex\/css\/font-awesome.css":1,"sites\/all\/themes\/bf_theme\/css\/custom.css":1,"sites\/all\/themes\/bf_theme\/css\/responsive.css":1},"js":{"sites\/all\/modules\/contrib\/responsive_menu\/js\/responsive_menu.config.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jquery\/1.10.2\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jqueryui\/1.10.2\/jquery-ui.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/contrib\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/contrib\/google_cse\/google_cse.js":1,"sites\/all\/modules\/contrib\/gss\/scripts\/autocomplete.js":1,"sites\/all\/modules\/contrib\/miniorange_saml\/js\/payment.js":1,"sites\/all\/modules\/contrib\/miniorange_saml\/js\/testconfig.js":1,"sites\/all\/modules\/custom\/rg_customizations\/bxslider_init.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/libraries\/jstorage\/jstorage.min.js":1,"sites\/all\/modules\/contrib\/better_exposed_filters\/better_exposed_filters.js":1,"sites\/all\/modules\/custom\/custom_calculator\/js\/jquery.selectBox.js":1,"sites\/all\/modules\/custom\/bf_animal_filter\/js\/bf_animal_filter.js":1,"sites\/all\/modules\/contrib\/views_selective_filters\/js\/attachBehaviours.js":1,"sites\/all\/libraries\/mmenu\/dist\/jquer ...
# //--><!]]>
# </script>
#
#   <!-- IE Fix for HTML5 Tags -->
#   <!--[if lt IE 9]>
#   <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
#
#   <!-- Google Web Fonts
#   ================================================== -->
#   <link
#     href='//fonts.googleapis.com/css?family=Open+Sans:300,400,600,600italic|Handlee'
#     rel='stylesheet'
#     type='text/css'>
#
#
#   <!-- User defined CSS --><style type='text/css'></style><!-- End user defined CSS -->
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
#
# <body
#   class="html not-front not-logged-in no-sidebars page-adopt page-adopt-adopt-our-sanctuary page-adopt-adopt-our-sanctuary-dogs wide normal pattern-1 custom " >
#   <div class="page-wrapper">
#   <div id="bfas_page">
# <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NMXDTP" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <div class="page-wrapper">
#
# <div id="wrapper">
#   <header id="header">
#     <div class="container">
#
#       <div class="eight columns">
#
#
#                     <div class="logo">
#                 <a href="/"
#                    title="Best Friends Animal Society" rel="home" id="logo">
#                     <img src="https://s3fs.bestfriends.org/s3fs-public/bfas.png" alt="Best Friends Animal Society"/>
#                 </a>
#             </div>
#             <div class="logo-responsive">
#                 <a href="/"
#                    title="Best Friends Animal Society" rel="home" id="logo">
#                     <img src="https://s3fs.bestfriends.org/s3fs-public/bfas_responsive.png" alt="Best Friends Animal Society"/>
#                 </a>
#             </div>
#
#                   <div
#             id="name-and-slogan">
#
#                           <div id="site-name" class="hidden">
#                 <a href="/"
#                    title="Home"
#                    rel="home"><span>Best Friends Animal Society</span></a>
#               </div>
#                                       <div id="site-slogan">
#                 Save Them All                <div id="slogan_c">&copy;</div>
#               </div>
#
#           </div> <!-- /#name-and-slogan -->
#
#       </div>
#
#               <div class="eight columns">
#             <div class="search-wrapper">
#
# <a id="toggle-icon" class="toggle responsive-menu-toggle-icon" title="Menu" href="#off-canvas">
#   <span class="icon"></span><span class="label">Menu</span>
# </a>
# <form class="google-cse gss" action="/adopt/adopt-our-sanctuary/dogs" method="post" id="search-block-form" accept-charset="UTF-8"><div><div class="container-inline">
#       <h2 class="element-invisible">Search form</h2>
#     <div class="icon"><i class="better_search"></i></div><div class="form-item form-type-textfield form-item-search-block-form">
#   <label class="element-invisible" for="edit-search-block-form--2">Search </label>
#  <input title="Enter the terms you wish to search for." placeholder="Search" type="text" id="edit-search-block-form--2" name="search_block_form" value="" size="30" maxlength="128" class="form-text" />
# </div>
# <div class="element-invisible form-actions form-wrapper" id="edit-actions"><input type="submit" id="edit-submit" name="op" value="Search" class="button default form-submit" /></div><input type="hidden" name="form_build_id" value="form-vXPnPpLnQlpuZMrbLoav3k_DvYaxprFwpvkupjUiK3E" />
# <input type="hidden" name="form_id" value="search_block_form" />
# </div>
# </div></form>            </div><!--/ .search-wrapper-->
#             </div>
#
#               <div class="eight columns">
#             <div class="region region-header-right">
#       <div class="region region-header-right">
#     <div id="block-block-24" class="block block-block">
#
#
#   <div class="content">
#     <div id="head-donate-block"><a href="https://support.bestfriends.org/site/Donation2?df_id=2460&amp;mfc_pref=T&amp;2460.donation=form1" id="head-donate-donate"><b>DONATE</b> <i class="fa fa-angle-double-right" style="color:#f58220;"></i> </a> <a class="head-donate-link" href="https://support.bestfriends.org/site/Donation2?df_id=2461&amp;mfc_pref=T&amp;2461.donation=form1"> One Time </a> <a class="head-donate-link" href="https://support.bestfriends.org/site/Donation2?df_id=2463&amp;mfc_pref=T&amp;2463.donation=form1"> Monthly </a> <a class="head-donate-link" href="https://bestfriends.org/donate/make-gift-memory/make-gift-memory-donate"> In Memory </a> <a class="head-donate-link" href="https://bestfriends.org/donate/make-gift-memory/make-gift-honor-donate"> In Honor </a></div>
#   </div>
# </div>
#   </div>
#   </div>
#
#         </div>
#
#       <div class="clear"></div>
#     </div>
#     <div class="menu-container clearfix">
#       <nav id="navigation" class="navigation">
#         <div class="menu">
#
# <ul><nav class="responsive-menu-block-wrapper responsive-menu-block menu-name-main-menu">
#   <ul id="horizontal-menu" class="horizontal-menu"><li class="first expanded menu-mlid-532"><a href="/about-best-friends" title="who we are">About</a><ul class="sub-nav menu-tree-mlid-532"><li class="first expanded menu-mlid-533"><a href="/about-best-friends/our-mission">Our Mission</a><ul class="sub-nav menu-tree-mlid-533"><li class="first last leaf menu-mlid-836"><a href="/about-best-friends/our-mission/save-them-all">Save Them All</a></li>
# </ul></li>
# <li class="expanded menu-mlid-543"><a href="/about-best-friends/our-story">Our Story</a><ul class="sub-nav menu-tree-mlid-543"><li class="first leaf menu-mlid-577"><a href="/about-best-friends/our-story/history-best-friends">History of Best Friends</a></li>
# <li class="leaf menu-mlid-578"><a href="/about/our-story/no-kill-timeline">No-Kill Timeline</a></li>
# <li class="last leaf has-children menu-mlid-579"><a href="/about/our-story/meet-the-founders">Meet the Founders</a></li>
# </ul></li>
# <li class="leaf menu-mlid-544"><a href="/about-best-friends/locations">Locations</a></li>
# <li class="leaf menu-mlid-545"><a href="/about-best-friends/faqs">FAQs</a></li>
# <li class="leaf menu-mlid-546"><a href="/about-best-friends/position-statements">Position Statements</a></li>
# <li class="leaf menu-mlid-547"><a href="/about/leadership">Leadership</a></li>
# <li class="expanded menu-mlid-548"><a href="/about-best-friends/our-partners">Our Partners</a><ul class="sub-nav menu-tree-mlid-548"><li class="first leaf has-children menu-mlid-673"><a href="/about-best-friends/our-partners/corporate-partners">Corporate Partners</a></li>
# <li class="leaf menu-mlid-2238"><a href="https://bestfriends.org/resources/general-pet-care/estate-planning-dogs-and-cats" title="">Estate Planning with Dogs and Cats</a></li>
# <li class="leaf menu-mlid-2304"><a href="/donate/planned-giving/planned-giving-officers" title="">Meet Your PG Officers</a></li>
# <li class="last leaf menu-mlid-2906"><a href="https://s3fs.bestfriends.org/s3fs-public/Planned-giving-fall-newsletter-09378-PG_Fall_FF_News (1).pdf" title="">Forever Friends Newsletter</a></li>
# </ul></li>
# <li class="expanded menu-mlid-621"><a href="/donate/other-ways-give">Other Ways to Help</a><ul class="sub-nav menu-tree-mlid-621"><li class="first leaf menu-mlid-2204"><a href="http://strutyourmutt.org" title="">Strut Your Mutt</a></li>
# <li class="leaf menu-mlid-695"><a href="/donate/other-ways-give/amazon-smile">Give with Amazon</a></li>
# <li class="leaf menu-mlid-694"><a href="/donate/other-ways-give/wish-list">Wish List</a></li>
# <li class="leaf menu-mlid-693"><a href="/donate/other-ways-give/workplace-giving">Workplace Giving</a></li>
# <li class="leaf menu-mlid-692"><a href="/donate/other-ways-give/donate-your-car-best-friends">Vehicle Donation</a></li>
# <li class="leaf menu-mlid-1934"><a href="/donate/other-ways-give/donor-advised-fund">Donor Advised Fund</a></li>
# <li class="last leaf menu-mlid-2246"><a href="https://bestfriends.org/donate/other-ways-give/create-fundraiser" title="">Create a Fundraiser</a></li>
# </ul></li>
# <li class="last leaf menu-mlid-2213"><a href="https://shop.bestfriends.org" title="">Shop Our Store</a></li>
# </ul></li>
# </ul></nav>
# </ul>        </div>
#       </nav>
#     </div>
#   </header>
#
#     <section id="content">
#     <div class="container">
#                     <section id="share-buttons" class="share-buttons">
#                   <div class="region region-share-buttons">
#     <div id="block-block-30" class="block block-block">
#
#
#   <div class="content">
#     <style type="text/css">
# <!--/*--><![CDATA[/* ><!--*/
# .share-buttons {
#     position: absolute;
#     display: inline;
#     left: -65px;
# }
#
# .region-share-buttons {
#     position: fixed;
#     background-color: none;
#     border: none;
#     padding-bottom: 5px;
#     display: inline-block;
#     top: 300px;
# }
#
# .social-share {
# 	height:35px;
# 	width: 35px;
# 	margin:8px;
# 	border-radius:50%;
# 	text-align:center;
# 	display:block;
# }
#
# .social-share  i {
# 	font-family: FontAwesome;
# 	color:#FFF;
# 	font-style: normal;
# 	font-size:24px;
# 	line-height:35px;
# }
#
# .fb {
# 	background: #4267b2;
# }
#
# .tw {
# 	background: #38a1f3;
# }
#
# .pin {
# 	height:40px;
# 	width: 40px;
# 	margin:8px;
# 	display:block;
# }
#
# .pin i {
# 	font-family:FontAwesome;
# 	font-size: 40px;
# 	line-height: 40px;
# 	color: #bd081c;
# 	font-style:normal;
# 	display:block;
# }
#
# .email {
# 	background: #f58220;
# }
#
# .print {
# 	background: #3d3d3e;
# }
#
# @media only screen and (max-width: 1105px) {
# .region-share-buttons {
#     position: fixed;
#     left: 0px;
#     top: auto;
#     bottom: 11px;
#     width: 100%;
#     background-color: rgba(255, 255, 255, .8);
#     padding-bottom: 5px;
#     z-index: 998;
#     text-align: center;
# }
#
#    var s = document.createElement('script'); s.async = true;
#    s.type = 'text/javascript';
#    s.src = '//' + disqus_shortname + '.disqus.com/count.js';
#    (document.getElementsByTagName('HEAD')[0] || document.getElementsByTagName('BODY')[0]).appendChild(s);
#   }());
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://s3fs.bestfriends.org/advagg_js/js__y7EmwjorvxB3nzFGxN3DoEGovztjIRsnpcpeta382RU__OPynAbuXtvpmBb-rtn72CpbmoInrgDLcyBAtwurRBDE__H5amiMaybuoOXTq2GFJEoTwKpaz7ERrqEMG9ifhEijA.js"></script>
# </div>
# </div>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"c72fbe0d5a","applicationID":"206872624","transactionName":"ZQBVZEcAWEYDWkVbDlxKdlNBCFlbTU9YVxZBOkdRUgQ=","queueTime":0,"applicationTime":523,"atts":"SUdWEg8aS0g=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
results = soup.find_all('div', class_="rg-animal")
# print(results)
# names = soup.find_all('span', class_= '_cpn')

for result in results:
    # Error handling
    try:
        name = result.find('span', class_= 'animalName').text
        link = result.a['href']
        breed = result.find('span', class_= 'animalBreed').text
        age = result.find('span', class_= 'animalAge').text
        
        if (name and link and breed and age):
            print('------------------')
            print(name)
            print(link)
            print(breed)
            print(age)
    
    except Exception as e:
        print(e)
# Out:
# ------------------
# Joy
# /adopt/adopt-our-sanctuary/9384898/joy
# American Pit Bull Terrier / Chinese Shar-Pei / Mixed (short coat)
# Senior
# ------------------
# Tarlton
# /adopt/adopt-our-sanctuary/9384877/tarlton
# Mastiff / Labrador Retriever / Mixed (short coat)
# Senior
# ------------------
# Avon
# /adopt/adopt-our-sanctuary/9384875/avon
# Cattle Dog (short coat)
# Senior
# ------------------
# Shocky
# /adopt/adopt-our-sanctuary/9384823/shocky
# American Pit Bull Terrier (short coat)
# Senior
# ------------------
# Kenya
# /adopt/adopt-our-sanctuary/9384967/kenya
# Labrador Retriever (short coat)
# Senior
# ------------------
# Bliss
# /adopt/adopt-our-sanctuary/9385093/bliss
# American Pit Bull Terrier / Mixed (short coat)
# Senior
# ------------------
# Moogan
# /adopt/adopt-our-sanctuary/9385337/moogan
# American Pit Bull Terrier (short coat)
# Adult
# ------------------
# Chaplin
# /adopt/adopt-our-sanctuary/9384952/chaplin
# American Pit Bull Terrier (short coat)
# Senior
# ------------------
# Fred
# /adopt/adopt-our-sanctuary/9385310/fred
# Red Heeler (medium coat)
# Senior
# ------------------
# Safira
# /adopt/adopt-our-sanctuary/9384957/safira
# Border Collie / American Pit Bull Terrier / Mixed (short coat)
# Senior
# ------------------
# Elwood
# /adopt/adopt-our-sanctuary/9385295/elwood
# Labrador Retriever / Hound / Mixed (long coat)
# Adult
# ------------------
# Raquel
# /adopt/adopt-our-sanctuary/9385283/raquel
# Cattle Dog (medium coat)
# Adult

# %%
# Out:
# <head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body></html>
